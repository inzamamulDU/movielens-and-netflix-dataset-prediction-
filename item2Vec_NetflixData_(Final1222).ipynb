# %% [markdown]
# # Item2Vec

# %% [markdown]
# # 0. Import Packages

# %%
import numpy as np
import pandas as pd
import keras as K
from keras.models import Sequential, Model
from keras.layers import Input, Embedding, Dense, Flatten, merge, Reshape, Dot, Add, Concatenate
from keras.preprocessing import sequence
from keras import optimizers
from keras.utils import np_utils, to_categorical, plot_model
from keras.regularizers import l2
import scipy
from sklearn.metrics import recall_score, roc_auc_score
from sklearn.manifold import TSNE
from collections import Counter
import matplotlib.pyplot as plt
import random
import operator

import gc
import time
import sys

import os
import warnings
warnings.simplefilter("ignore")
# Out:
# Using TensorFlow backend.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 1. Define utility and helper functions

# %% [markdown]
# ## 1. 1 Load and Parse the Data

# %% [markdown]
# First of all, we load the data and parse it in 2 different dictionaries.
#
# 1) Users: Items watched (not necessairly ranked high) by each user as a list
#
# 2) Names: Names of the movies according to their IDs in order to be able to connect numbers to names afterwards.

# %% [markdown]
# #Here is two function please run one

# %% [markdown]
# # 1. Movielens Data function

# %%
"""
def load_data(ratings_file_name, movies_file_name = None):
    user_dict = {}
    item_dict = {}
    
    with open(ratings_file_name, encoding='ISO-8859-1') as data:
        for line in data:
            line = line.split('::')
            user = line[0]
            item = line[1]
            
            if user in user_dict:
                user_dict[user].append(item)
            else:
                user_dict[user] = [item]
    
    if movies_file_name:
        with open(movies_file_name, encoding='ISO-8859-1') as data:
            for line in data:
                line = line.split('::')
                item_idx = line[0]
                item_name = line[1]
                item_dict[item_idx] = item_name
            
    
    return user_dict, item_dict
"""
# Out:
# "\ndef load_data(ratings_file_name, movies_file_name = None):\n    user_dict = {}\n    item_dict = {}\n    \n    with open(ratings_file_name, encoding='ISO-8859-1') as data:\n        for line in data:\n            line = line.split('::')\n            user = line[0]\n            item = line[1]\n            \n            if user in user_dict:\n                user_dict[user].append(item)\n            else:\n                user_dict[user] = [item]\n    \n    if movies_file_name:\n        with open(movies_file_name, encoding='ISO-8859-1') as data:\n            for line in data:\n                line = line.split('::')\n                item_idx = line[0]\n                item_name = line[1]\n                item_dict[item_idx] = item_name\n            \n    \n    return user_dict, item_dict\n"

# %%
"""
def get_genre_data(genres_file_name):
    #Get genre data
    flat_item_list = [item for item_list in filtered_item_lists for item in item_list]
    genres_by_idx = {}
    with open(genres_file_name, encoding='ISO-8859-1') as data:
        for line in data:
            line = line.split('::')
            item_genre = line[2][:-1].split('|')
            item = line[0]
            if item in flat_item_list:
                item_idx = items_to_idx[item]
                genres_by_idx[item_idx] =  item_genre
    return (genres_by_idx)
"""
# Out:
# "\ndef get_genre_data(genres_file_name):\n    #Get genre data\n    flat_item_list = [item for item_list in filtered_item_lists for item in item_list]\n    genres_by_idx = {}\n    with open(genres_file_name, encoding='ISO-8859-1') as data:\n        for line in data:\n            line = line.split('::')\n            item_genre = line[2][:-1].split('|')\n            item = line[0]\n            if item in flat_item_list:\n                item_idx = items_to_idx[item]\n                genres_by_idx[item_idx] =  item_genre\n    return (genres_by_idx)\n"

# %% [markdown]
# # 2. Netflix Data function

# %%
def NetFlix(ratings_file_name, movies_file_name = None):
    user_dict = {}
    item_dict = {}
    
    with open(ratings_file_name, encoding='latin1') as data:
        for line in data:
            line = [x.strip() for x in line.split(',')]
            user = line[0]
            item = line[2]
            
            if user in user_dict:
                user_dict[user].append(item)
            else:
                user_dict[user] = [item]
    
    if movies_file_name:
        with open(movies_file_name, encoding='latin1') as data:
            for line in data:
                line = [x.strip() for x in line.split(',')]
                item_idx = line[0]
                item_name = line[2]
                item_dict[item_idx] = item_name
            
    
    return user_dict, item_dict

# %%
"""
def get_genre_data(genres_file_name):
    #Get genre data
    flat_item_list = [item for item_list in filtered_item_lists for item in item_list]
    genres_by_idx = {}
    with open(genres_file_name, encoding='latin1') as data:
        for line in data:
            line = line.split(',')
            item_genre = line[2][:-1].split('\n')
            item = line[0]
            if item in flat_item_list:
                item_idx = items_to_idx[item]
                genres_by_idx[item_idx] =  item_genre
    return (genres_by_idx)
"""
# Out:
# "\ndef get_genre_data(genres_file_name):\n    #Get genre data\n    flat_item_list = [item for item_list in filtered_item_lists for item in item_list]\n    genres_by_idx = {}\n    with open(genres_file_name, encoding='latin1') as data:\n        for line in data:\n            line = line.split(',')\n            item_genre = line[2][:-1].split('\n')\n            item = line[0]\n            if item in flat_item_list:\n                item_idx = items_to_idx[item]\n                genres_by_idx[item_idx] =  item_genre\n    return (genres_by_idx)\n"

# %%
def count_items(item_lists):
    #Count each item in a given dataset
    #Dataset is assumed to be a list of lists
    item_count = Counter()
    for item_list in item_lists:
            item_count.update(item_list)
    return item_count

# %% [markdown]
# ## 1.2 Preprocessing

# %% [markdown]
# ### 1.2.1 Filtering

# %% [markdown]
# We know that there are movies that were watched very few times, so we will start filtering the data by removing those movies as it will not help us much for the model.
#
# The second filtering we do is to remove the users (lists of items) that watched more than a given count of movies or less than another given count of movies. The reason is simple:
#
# 1) The model will work with skipgrams - we need at least 2 items in each list
#
# 2) Uninformative - If a user watched more than a given amount of movies, then it is easy to assume that he/she is less picky. Harder for the model to actually decide which movies would be similar to each other with that many movies.

# %%
def filter_data(item_lists, item_counts, min_item_freq, max_items, min_items):   
    #filter out items that have frequency less than min_item_freq
    filtered_data = []
    for item_list in item_lists:
        item_list = [item for item in item_list if (item_counts[item] >= min_item_freq)]
        
        #Keep only the lists with more than "min_items" items (necessary for further use of skipgrams for Item2Vec model)
        #Filter out users that watched more than 'max_items' movies (not helpful for the model)
        if len(item_list) >= min_items and len(item_list) <= max_items:
            filtered_data.append(item_list)
            
    return filtered_data

# %% [markdown]
# ### 1.2.2 Formatting

# %% [markdown]
# Just like Word2Vec model, Item2Vec also works with indexes (numbers) and not names (strings) or IDs (random integers). That is why we will assign each item in the data an index.
#
# Of course, we will do the changes to the names dictionary for easier use later on.

# %%
def items_vs_index(data):
    #Map each item to indexes by popularity (counts)
    new_counts = count_items(data)
    counts_sorted = sorted(new_counts.items(), key = operator.itemgetter(1), reverse = True)
    item_as_idx = {}
    idx_as_item = {}
    for j, count in enumerate(counts_sorted):
        item_as_idx[count[0]] = j
        idx_as_item[j] = count[0]
        
    return item_as_idx, idx_as_item

# %%
def genre_to_idx(genres_as_df, genre_col_name):
    genres_idx ={}
    for k, g in enumerate(sorted(genres_as_df[genre_col_name].unique())):
        genres_idx[g] = k
    return genres_idx

# %% [markdown]
# ### 1.2.3 Train-Test Split

# %% [markdown]
# Like any other machine learning application we will split our data into train and test sets to evaluate afterwards. We will the last few items (hyperparameter) of each user as the test set.
#
# As we split the data, we will make sure that each item appears at least once in the trainset. This is important in order to learn the vector for each and every item (we won't be training on the test set, so if an item appears only in the test set we will not know it's embedding)

# %%
def train_test(data, test_size):
    trainset = []
    testset = []
    
    random.shuffle(data)
    num_test_items = int(len(data)*test_size)
    testset = data[:num_test_items]
    trainset = data[num_test_items:]
    
    trainset_count = count_items(trainset)   
    for item_list in testset:
        for item in item_list:
            if trainset_count[item] == 0:
                trainset.append(item_list)
                testset.remove(item_list)
                
            return trainset, testset

# %% [markdown]
# Just a quick check to make sure no item is missing in train set as explained above.

# %%
def find_missing_items(trainset, testset):
    #Check that each item in testset appears in trainset
    flat_train = [item for item_list in trainset for item in item_list]
    flat_test = [item for item_list in testset for item in item_list]
    
    missing_items = []
    for item in flat_test:
        if item not in flat_train and item not in missing_items:
            missing_items.append(item)
    if missing_items == []:
        print('No missing items in train set!')
    else: 
        print('Some items appear only in the test set, check again!')
    return missing_items

# %% [markdown]
# ## 1.3 Preparations for the Model

# %% [markdown]
# ### 1.3.1 Negative Samples List

# %% [markdown]
# According to the original paper, negative samples are chosen randomly from a unigram of items raised to the power of 3/4. It is claimed to have worked the best.
#
# We will also create a unigram of items (though leave ourselves the option to play around with different values) for the model to do negative sampling.

# %%
def create_item_unigram(item_counts, power = 0.75):
    #Create the unigram to the given power for negative sampling
    total_size = np.sum(list(item_counts.values()))   
    unigram = []
    for item, count in item_counts.items():
        prob = (float(count) / total_size) ** power
        unigram.extend([item] * int(round(prob * total_size)))
    
    return unigram

# %% [markdown]
# ### 1.3.2 Sampling Table

# %% [markdown]
# Another important part of the model is to decide how to sample from all the items of all the lists. For that reason, the authors decided on a custom sampling table and a threshold.
#
# We will create our own sampling table (using their threshold values with option to play around again)

# %%
def samplingtable(item_counts, rho = 1e-5):
    total_size = np.sum(list(item_counts.values()))
    probs = np.zeros(len(item_counts))
    rho_count = rho * total_size
    for item, count in item_counts.items():
        rho_div_item = count / rho_count
        probs[item] = 1 - (1 + np.sqrt(rho_div_item)) / rho_div_item

        return probs

# %% [markdown]
# ### 1.3.3 Create Skipgrams (with Negative Sampling)

# %% [markdown]
# This part is the heart of the model and the most important part. We will create skipgrams for the model to train on.
# According to what we created before, the items from the list will be chosen from the sampling table and negative sampling will be done according to the negative samples list (depending on the number of negative samples we want).
#
# The window size enables us to control how far we want to go from each given item. For our algorithm we will not want a very big window size as the effect of each item watched to a specific item reduces as we go further in list.
#
# Another important difference to word2vec is that here we only get skipgrams forward. Meaning, each item watched after a specific item is important to know about but the opposite is not as much. We will call the first item of a skipgram couple a "context" and the second item a"target". For us, there is one target and one context only for each item (for each user of course)
#
# We will create pairs of items, add label "1" for positive samples and label "0" for negative samples. This will let us solve a simpler binary classification problem, which will make it relatively easier and computationally lighter for the model.

# %%
def create_SGNS(item_list, num_neg_samples, window_size, sampling_table, shuffle, negative_samples_list, loss, use_st):
    couples = []
    labels = []
       
    for i, item_i in enumerate(item_list):
        #Positive sampling
        if not item_i:
            continue
        if use_st == True:
            if sampling_table[item_i] > random.random():
                continue
            
        begin = max(0, i) #begin = max(0, i- window_size) if we want also backward!
        end = min(len(item_list), i + window_size +1)
        
        for loc in range(begin, end):
            if loc != i:
                item_j = item_list[loc]
                if not item_j:
                    continue
                    
                couple = [item_i, item_j]
                couples.append(couple)
                labels.append(1)
        
                #Negative sampling
                while True:
                    neg_samples = random.sample(neg_samples_list, num_neg_samples)
                    neg_samples = list(set(neg_samples)) #remove duplicates to make sure we didnt choose the same sample
                    if (len(neg_samples) == num_neg_samples) and (len(set(item_list).intersection(set(neg_samples))) == 0):
                        for sample in neg_samples:
                            couples.append([item_i, sample])
                            if loss == 'binary_ce' or loss == 'categorical_ce':
                                labels.append(0)
                            elif loss == 'hinge':
                                labels.append(-1)
                        break
    
    if shuffle == True:
        seed = random.randint(0,100000)
        random.seed(seed)
        random.shuffle(couples)
        random.seed(seed)
        random.shuffle(labels)
        
    return couples, labels

# %%
def create_all_SGNS_data(all_data, num_neg_samples, window_size, sampling_table, shuffle, negative_samples_list, loss, use_st):
    all_couples = []
    all_labels = []
    for item_list in all_data:
        couples, labels = create_SGNS(item_list, 
                                      num_neg_samples, 
                                      window_size, 
                                      sampling_table, 
                                      shuffle, 
                                      negative_samples_list, 
                                      loss, 
                                      use_st)
        all_couples.extend(couples)
        all_labels.extend(labels)
    return all_couples, all_labels

# %% [markdown]
# ### 1.3.4 Format the Skipgrams

# %% [markdown]
# The model accepts the input as couples of (item_i, item_j) and the corresponding label. We will convert the skipgrams to a format ready to feed into the model.

# %%
def format_skipgram(couples,labels, model_loss):
    #Format the skipgram data for model training input
    item_i, item_j = zip(*couples)
    item_i = np.array(item_i)
    item_j = np.array(item_j)
    
    X_train = [item_i, item_j]
    Y_train = np.array(labels)
    if model_loss == 'categorical_ce':
        Y_train = to_categorical(Y_train, num_classes = 2)
    
    return X_train, Y_train

# %% [markdown]
# ### 1.3.5 Resampling the Data

# %% [markdown]
# We can sample the data for each epoch so that we can get the most of the result by showing it the most items as possible (and not just sampling once and showing always the same couples) and also make the runtime faster by not using all the couples at once.

# %%
def sample_sg(all_data, num_neg_samples, window_size, sampling_table, shuffle, negative_samples_list, loss, use_st):
    gc.disable()
    t = time.clock()
    print("Sampling data and creating skipgrams ...")
    sys.stdout.flush()
    
    couples, labels = create_all_SGNS_data(all_data, 
                                           num_neg_samples, 
                                           window_size, 
                                           sampling_table, 
                                           shuffle, 
                                           negative_samples_list, 
                                           loss, 
                                           use_st)
    print("{:.2f}s".format(time.clock() - t))
    t = time.clock()
    
    print("Creating couples and labels for model train ...", end = "")
    sys.stdout.flush()
    X_train, Y_train = format_skipgram(couples, labels, model_loss = loss)
    print("{:.2f}s".format(time.clock() - t))
    
    sys.stdout.flush()
    gc.enable()
    
    return X_train, Y_train

# %% [markdown]
# ## 1.4 Evaluation

# %%
def get_k_random_items(couple, all_items, k):
    random_items_list = []
    k = k-1 #item_j will be the part of random k items always, we need to sample only k-1
    item_i = couple[0]
    item_j = couple[1]
    random_items_list.append(item_j)
    while True:
        k_random_items = random.sample(all_items, k)
        k_random_items = list(set(k_random_items))
        if (len(k_random_items) == k) and (item_j not in k_random_items) and (item_i not in k_random_items):
            random_items_list.extend(k_random_items)
            break
            
    return random_items_list

# %% [markdown]
# ### 1.4.1 Metrics

# %% [markdown]
# #### Percentile Rank

# %%
#Percentile Rank calculation
def pr(actual, predicted): 
    #actual: real item_j of the couple
    #predicted: sampled k_randoms plus the real item_j (ordered by similarity - after random sampling of items)
    pr = 0
    for i,p in enumerate(predicted):
        if p == actual:
            pr = (float(i)/len(predicted))*100.0     #The lower the value - the better
            break
        
    return pr

# %% [markdown]
# #### Hit Rate

# %%
def hr(actual, predicted):
    #actual: real item_j of the couple
    #predicted: sampled k_randoms plus the real item_j (not necessarily ordered as it's not important for this metric)
    hr = 0
    if actual in predicted:
        hr = 1
        
    return hr

# %% [markdown]
# ### 1.4.2 Finding the closest items

# %% [markdown]
# In order to use (and evaluate) the model we need to be able to recommend (predict) the closest items to a given movie.
#
# We will create a a similarity matrix (size = num_ites X num_items) that shows the similarity of each item with the others.
# Once we have all the similarity values, we can easily choose the top K movies closest to a given movie.

# %%
def get_topk_similar2(spesific_item_emb, item_embeddings, k=None):
    #spesific_item_emb: the vector of the item we're looking for its similar items 
    #Depending on the direction, this can be from item_i_embeddings or item_j_embeddings
    
    #item_embeddings: all the embeddings of all the items to compare
    #Depending on the direction, this can be the item_i_embeddings or item_j_embeddings
    
    #k: top k most similar to return
    distances = np.dot(item_embeddings, spesific_item_emb)
    sorted_distances = list(reversed(np.argsort(distances)))
    if k:
        sorted_distances = sorted_distances[:k]
    
    return sorted_distances

# %%
def get_topk_each_genre(genre_data, top_k):
    # Gets the genre data of whole dataset and returns the top_k most popular movies of each genre
    
    #Turns the data into a pandas dataframe in order to easily process 
    genres_by_idx_df = pd.DataFrame(list(genre_data.items()), columns=['Item_Id', 'Genre']).set_index('Item_Id')
    
    #Explode the dataset - each movie will have one row for each genre it has
    #For example - Item_Id = 30 will have 3 rows witl item_id = 30, genre = Animation, genre = Children's, genre = Comedy
    genres_df = genres_by_idx_df['Genre'].apply(pd.Series).stack().reset_index(level=0).rename(columns = {0:'genre'})
    
    #Map genre names to index values - necessary for visualization
    genres_idx = genre_to_idx(genres_df, genre_col_name = 'genre')
    genres_df['genre_idx'] = genres_df['genre'].apply(lambda x: genres_idx[x])
    
    #Get the list of item_ids for each genre - sorted by popularity already
    genres_dict ={}
    for j in genres_df['genre_idx'].unique():
        genres_dict[j] = sorted(list(list(genres_df.groupby(by='genre_idx'))[j][1]['Item_Id']))
    
    #Get the top_k of the movies of each genre index
    genres_topk = {}
    for g_idx in genres_dict.keys():
        genres_topk[g_idx] = genres_dict[g_idx][:top_k]
    
    return genres_idx, genres_topk

# %% [markdown]
# ## 1.5 Model

# %%
def create_I2Vmodel(items_size, embed_dim, loss, model_optimizer, model_metric, dual_embedding = True, bias = True):
    #loss: binary cross entropy (binary_ce), hinge (hinge), categorical cross entropy (categorical_ce)
    #optimizer: all the optimizers of Keras suc as adam, rmsprop, adagrad, sgd... etc.
    #model_metric: metrics of Keras such as: accuracy, mse... etc.
    context = Input(name='context', shape=[1])
    target = Input(name='target', shape=[1])

    item_embedding_u = Embedding(input_dim = items_size + missing, 
                                 output_dim = embed_dim, 
                                 name = 'item_embedding_u')
    
    item_embedding_v = Embedding(input_dim = items_size + missing, 
                                 output_dim = embed_dim, 
                                 name = 'item_embedding_v')
        
    bias_embedding_v = Embedding(input_dim = items_size + missing, 
                                 output_dim = 1, 
                                 embeddings_initializer = 'zeros', 
                                 name = 'bias_embedding_v')
    
    bias_embedding_u = Embedding(input_dim = items_size + missing, 
                                 output_dim = 1, 
                                 embeddings_initializer = 'ones', 
                                 name = 'bias_embedding_u', 
                                 trainable = False)
    
    u = item_embedding_u(context)
    
    if dual_embedding:
        v = item_embedding_v(target)
    else:
        v = item_embedding_u(target)

#     merge_layer = Dot(name='dot_p',normalize = False, axes = 2)([u, v])
# #     print(dot_p_layer.shape)
#     merge_layer = Flatten()(merge_layer)
   
    if bias:
        b_v = bias_embedding_v(target)
#         b_v = Flatten()(b_v)
        b_u = bias_embedding_u(context)
#         b_u = Flatten()(b_u)
        u = Concatenate(name='u_concat', axis=-1)([u, b_u])
        v = Concatenate(name='v_concat', axis=-1)([v, b_v])
#         merge_layer = Add(name='add_bias')([merge_layer, b_v])
#         print(add_layer.shape)

    merge_layer = Dot(name='dot_p',normalize = False, axes = 2)([u, v])
    merge_layer = Flatten()(merge_layer)
    
    flattenned = Reshape(target_shape=[1])(merge_layer)
#     print(flattenned.shape)

    if loss == 'binary_ce':
        output_layer = Dense(1, 
                             activation = 'sigmoid',
                             kernel_regularizer=l2(0.01),
                             use_bias = False)(flattenned)
    if loss == 'hinge':
        output_layer = Dense(1,
                             activation = 'linear', 
                             kernel_regularizer=l2(0.001),
                             use_bias = False)(flattenned)
    if loss == 'categorical_ce':
        output_layer = Dense(2,
                             activation = 'softmax',
                             kernel_regularizer=l2(0.01),
                             use_bias = False)(flattenned)        
#     print (output_layer.shape)
    
    model = Model(inputs=[context, target], outputs=output_layer)
    
    #Compile model
    if loss == 'binary_ce':
        model.compile(loss='binary_crossentropy', optimizer = model_optimizer, metrics = [model_metric])
    if loss == 'hinge':
        model.compile(loss='hinge', optimizer = model_optimizer, metrics = [model_metric])
    if loss == 'categorical_ce':
        model.compile(loss='categorical_crossentropy', optimizer = model_optimizer, metrics = [model_metric])
    
    return model

# %% [markdown]
# ### 1.5.1 Train the Model

# %%
def train(model, traindata, num_epochs, batch_size, num_neg_samples, win_size, v, shuffle, neg_samples, s_t, loss, use_st):   
    #v: verbose
    #Initializations
    train_loss = []
    train_acc = []
    train_auc = []
    test_auc=[]

    item_i_embeddings = {}
    item_j_embeddings = {}
    bias_j_embeddings = {}
    bias_i_embeddings = {}
    
    #Create the first sampling of couples and labels to start the training
    X_train, Y_train = sample_sg(trainset,
                                 num_neg_samples = num_neg_samples, 
                                 window_size = win_size, 
                                 sampling_table = s_t, 
                                 shuffle = shuffle, 
                                 negative_samples_list = neg_samples_list, 
                                 loss = loss, 
                                 use_st = use_st)
    
    X_test, Y_test = sample_sg(testset,
                                 num_neg_samples = num_neg_samples, 
                                 window_size = win_size, 
                                 sampling_table = s_t, 
                                 shuffle = shuffle, 
                                 negative_samples_list = neg_samples_list, 
                                 loss = loss, 
                                 use_st = False)
    
    
    print("Training item2vec model on {} unique items and {} users".format(items_size, len(trainset)))
    sys.stdout.flush()
    for i in range(num_epochs):
        print("Epoch {}: ".format(i+1), end = "")
        sys.stdout.flush()
        hist = model.fit(X_train, Y_train, batch_size = batch_size, epochs = 1, shuffle = True, verbose = v)
        train_loss.append(hist.history['loss'])
        train_acc.append(hist.history['accuracy'])
        
        y_pred_train = model.predict(X_train)
        y_pred_test = model.predict(X_test)
        train_auc.append(roc_auc_score(Y_train, y_pred_train))
        test_auc.append(roc_auc_score(Y_test, y_pred_test))
    
        print('Saving item embeddings after epoch')
        item_i_embeddings[i] = model.layers[2].get_weights()[0]
        bias_i_embeddings[i] = model.layers[3].get_weights()[0]
        item_j_embeddings[i] = model.layers[4].get_weights()[0]
        bias_j_embeddings[i] = model.layers[5].get_weights()[0]

#         resample (?) - now no resampling       
#         print('Resampling skipgrams')
#         X_train, Y_train = sample_sg(trainset, 
#                                      num_neg_samples = num_neg_samples, 
#                                      window_size = win_size, 
#                                      sampling_table = s_t, 
#                                      shuffle = shuffle, 
#                                      negative_samples_list = neg_samples_list, 
#                                      loss = loss, 
#                                      use_st = use_st)
        
    return train_loss, train_acc, train_auc, test_auc, item_i_embeddings, item_j_embeddings, bias_j_embeddings, bias_i_embeddings

# %% [markdown]
# ### 1.5.2 Results of the Model

# %%
def plot_model_metrics(train_loss, train_acc, train_auc, test_auc):
    plt.subplot(3,1,1)
    plt.plot(train_loss)
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.show()

    plt.subplot(3,1,2)
    plt.plot(train_acc)
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.show()
    
    plt.subplot(3,1,3)
    plt.plot(train_auc, label = 'Train AUC')
    plt.plot(test_auc, label = 'Test AUC')
    plt.title('model AUC')
    plt.ylabel('AUC')
    plt.xlabel('epoch')
    plt.legend()
    plt.show()

# %% [markdown]
# # 2. Main

# %% [markdown]
# ## 2.1 Load and Parse the Data

# %% [markdown]
# # This is movielens data

# %%
#2.1 Hyperparameters
#ratings_data_name = '/content/drive/My Drive/Movie Project/rating.dat' # Shows all the items of all the users
#name_data_name = '/content/drive/My Drive/Movie Project/movies.dat' # Links between item_id and actual name of the item

# %%
#Load data
#user_dict, item_names = load_data(ratings_data_name, name_data_name)

# %% [markdown]
# # This is netflix data

# %%
ratings_data_name = '/content/drive/My Drive/Movie Project/combined_data_33.txt' # Shows all the items of all the users
name_data_name = '/content/drive/My Drive/Movie Project/movie_titles.csv' # Links between item_id and actual name of the item

# %%
df1=pd.read_csv(ratings_data_name,header = None, names = ['Cust_Id', 'Rating'], usecols = [0,1])

df2=pd.read_csv(name_data_name,header = None, 
                names = ['Movie_Id', 'Year','Movie_Name'], usecols = [0,1,2],encoding='latin1')

# %%
n=df1.loc[pd.isnull(df1.Rating)].index
df1['Movie_id']=np.zeros(df1.shape[0])
for i in range(len(n)-1):
    df1.iloc[np.arange(n[i],n[i+1]),-1]=int(df1.iloc[n[i],0][:-1])
df1.dropna(axis=0,inplace=True)
df1[['Cust_Id','Rating','Movie_id']]=df1[['Cust_Id','Rating','Movie_id']].astype('int32')

# %%
df1.to_csv('rating.txt',index=False, header=False)

df2.to_csv('Movie_data.txt',index=False, header=False)

# %%
ratings_data_name = '/content/rating.txt' # Shows all the items of all the users
name_data_name = '/content/Movie_data.txt' # Links between item_id and actual name of the item

# %%
#Load data
user_dict, item_names = NetFlix(ratings_data_name, name_data_name)

# %%
user_dict
# Out:
# {'1277134': ['9211', '9229', '9241', '9242', '9254', '9279', '9320', '9326'],
#  '2435457': ['9211', '9340'],
#  '2338545': ['9211', '9229', '9235', '9242', '9279', '9340'],
#  '2218269': ['9211',
#   '9217',
#   '9232',
#   '9234',
#   '9235',
#   '9240',
#   '9254',
#   '9265',
#   '9274',
#   '9298',
#   '9320',
#   '9326',
#   '9330',
#   '9340'],
#  '441153': ['9211', '9324', '9326', '9340'],
#  '1921624': ['9211', '9303', '9340'],
#  '2096652': ['9211',
#   '9217',
#   '9234',
#   '9240',
#   '9254',
#   '9262',
#   '9265',
#   '9298',
#   '9313',
#   '9323',
#   '9340'],
#  '818736': ['9211',
#   '9223',
#   '9229',
#   '9232',
#   '9233',
#   '9234',
#   '9235',
#   '9240',
#   '9242',
#   '9276',
#   '9279',
#   '9281',
#   '9294',
#   '9295',
#   '9298',
#   '9330',
#   '9339',
#   '9340'],
#  '284560': ['9211', '9254', '9340'],
#  '1211224': ['9211', '9306'],
#  '1984086': ['9211',
#   '9217',
#   '9218',
#   '9222',
#   '9224',
#   '9232',
#   '9234',
#   '9235',
#   '9241',
#   '9242',
#   '9254',
#   '9262',
#   '9265',
#   '9270',
#   '9279',
#   '9288',
#   '9292',
#   '9295',
#   '9298',
#   '9303',
#   '9307',
#   '9309',
#   '9310',
#   '9320',
#   '9322',
#   '9326',
#   '9334',
#   '9340'],
#  '1389539': ['9211', '9340'],
#  '454575': ['9211', '9298'],
#  '149028': ['9211',
#   '9224',
#   '9235',
#   '9241',
#   '9242',
#   '9254',
#   '9276',
#   '9292',
#   '9339',
#   '9340'],
#  '1105843': ['9211',
#   '9224',
#   '9235',
#   '9254',
#   '9265',
#   '9274',
#   '9278',
#   '9329',
#   '9340'],
#  '353813': ['9211', '9241', '9340'],
#  '903779': ['9211',
#   '9228',
#   '9234',
#   '9238',
#   '9241',
#   '9242',
#   '9279',
#   '9298',
#   '9326',
#   '9340'],
#  '639194': ['9211',
#   '9217',
#   '9228',
#   '9232',
#   '9235',
#   '9254',
#   '9257',
#   '9265',
#   '9271',
#   '9294',
#   '9295',
#   '9303',
#   '9310',
#   '9330',
#   '9340'],
#  '308031': ['9211',
#   '9234',
#   '9235',
#   '9236',
#   '9240',
#   '9265',
#   '9279',
#   '9295',
#   '9310',
#   '9331',
#   '9340'],
#  '1794933': ['9211', '9234', '9242', '9260', '9270', '9279', '9309', '9310'],
#  '625085': ['9211', '9320', '9340'],
#  '893673': ['9211', '9340'],
#  '1704675': ['9211', '9223', '9242', '9309', '9330', '9340'],
#  '2116614': ['9211', '9254', '9265', '9298', '9340'],
#  '371300': ['9211', '9218', '9238', '9254', '9272', '9274', '9290', '9340'],
#  '1172345': ['9211', '9234', '9270'],
#  '823026': ['9211'],
#  '2241971': ['9211', '9217', '9330', '9340'],
#  '1173009': ['9211', '9242'],
#  '440727': ['9211'],
#  '2443370': ['9211', '9228', '9242', '9322'],
#  '85279': ['9211', '9236', '9265'],
#  '1785621': ['9211', '9290'],
#  '1620439': ['9211', '9270', '9279', '9295'],
#  '1792790': ['9211', '9267'],
#  '155342': ['9211',
#   '9217',
#   '9229',
#   '9234',
#   '9235',
#   '9240',
#   '9249',
#   '9254',
#   '9262',
#   '9265',
#   '9267',
#   '9278',
#   '9279',
#   '9283',
#   '9298',
#   '9309',
#   '9322',
#   '9323',
#   '9340'],
#  '1583838': ['9211',
#   '9232',
#   '9242',
#   '9244',
#   '9254',
#   '9279',
#   '9300',
#   '9303',
#   '9326',
#   '9331',
#   '9340'],
#  '1503647': ['9211',
#   '9222',
#   '9232',
#   '9233',
#   '9235',
#   '9240',
#   '9254',
#   '9262',
#   '9288',
#   '9298',
#   '9330',
#   '9340'],
#  '737709': ['9211', '9326', '9330', '9340'],
#  '1559022': ['9211',
#   '9231',
#   '9233',
#   '9235',
#   '9238',
#   '9242',
#   '9245',
#   '9246',
#   '9273',
#   '9275',
#   '9276',
#   '9278',
#   '9279',
#   '9284',
#   '9298',
#   '9306',
#   '9309',
#   '9316',
#   '9319',
#   '9331',
#   '9333',
#   '9340',
#   '9341'],
#  '569379': ['9211', '9217', '9229', '9232', '9265', '9310', '9330'],
#  '690965': ['9211'],
#  '1873127': ['9211', '9340'],
#  '694791': ['9211', '9226'],
#  '791076': ['9211', '9340'],
#  '2041150': ['9211', '9222', '9236', '9240', '9254', '9265', '9298', '9340'],
#  '1864787': ['9211', '9340'],
#  '1147765': ['9211', '9340'],
#  '2396806': ['9211',
#   '9223',
#   '9224',
#   '9229',
#   '9235',
#   '9240',
#   '9298',
#   '9306',
#   '9340',
#   '0'],
#  '124810': ['9211',
#   '9224',
#   '9229',
#   '9241',
#   '9242',
#   '9254',
#   '9279',
#   '9309',
#   '9316',
#   '9329',
#   '9340'],
#  '2127114': ['9211', '9330', '9340'],
#  '2455949': ['9211', '9340'],
#  '727242': ['9211',
#   '9215',
#   '9217',
#   '9229',
#   '9231',
#   '9232',
#   '9234',
#   '9235',
#   '9236',
#   '9237',
#   '9238',
#   '9240',
#   '9241',
#   '9242',
#   '9249',
#   '9251',
#   '9252',
#   '9254',
#   '9261',
#   '9262',
#   '9265',
#   '9267',
#   '9268',
#   '9277',
#   '9279',
#   '9280',
#   '9285',
#   '9289',
#   '9290',
#   '9291',
#   '9292',
#   '9293',
#   '9295',
#   '9296',
#   '9298',
#   '9310',
#   '9316',
#   '9317',
#   '9319',
#   '9323',
#   '9325',
#   '9326',
#   '9331',
#   '9332',
#   '9335',
#   '9339',
#   '9340',
#   '9342',
#   '0'],
#  '981593': ['9211', '9235', '9241', '9309', '9340'],
#  '1725009': ['9211',
#   '9217',
#   '9232',
#   '9236',
#   '9237',
#   '9241',
#   '9251',
#   '9265',
#   '9298',
#   '9300',
#   '9320',
#   '9326',
#   '9338',
#   '9340'],
#  '1369550': ['9211',
#   '9226',
#   '9231',
#   '9241',
#   '9242',
#   '9243',
#   '9265',
#   '9274',
#   '9298',
#   '9320'],
#  '151048': ['9211', '9254', '9298', '9330'],
#  '235031': ['9211', '9234', '9239'],
#  '1120781': ['9211',
#   '9213',
#   '9229',
#   '9242',
#   '9279',
#   '9298',
#   '9316',
#   '9327',
#   '9340'],
#  '255960': ['9211', '9241', '9254', '9289', '9340'],
#  '162925': ['9211', '9277', '9340'],
#  '1054564': ['9211',
#   '9217',
#   '9220',
#   '9222',
#   '9224',
#   '9232',
#   '9234',
#   '9235',
#   '9240',
#   '9245',
#   '9254',
#   '9262',
#   '9265',
#   '9278',
#   '9288',
#   '9294',
#   '9298',
#   '9309',
#   '9320',
#   '9323',
#   '9329',
#   '9340'],
#  '2379278': ['9211'],
#  '2322224': ['9211', '9232', '9278', '9279', '9298'],
#  '2411610': ['9211',
#   '9234',
#   '9254',
#   '9265',
#   '9276',
#   '9298',
#   '9309',
#   '9320',
#   '9331',
#   '9339',
#   '9340'],
#  '555509': ['9211',
#   '9224',
#   '9234',
#   '9235',
#   '9254',
#   '9256',
#   '9265',
#   '9279',
#   '9298',
#   '9306',
#   '9339'],
#  '1794320': ['9211', '9241', '9279'],
#  '391799': ['9211', '9217', '9234', '9254', '9265', '9298', '9330', '9340'],
#  '2237185': ['9211',
#   '9217',
#   '9218',
#   '9222',
#   '9224',
#   '9228',
#   '9229',
#   '9235',
#   '9236',
#   '9237',
#   '9240',
#   '9242',
#   '9254',
#   '9262',
#   '9265',
#   '9267',
#   '9270',
#   '9276',
#   '9279',
#   '9289',
#   '9291',
#   '9294',
#   '9295',
#   '9298',
#   '9303',
#   '9306',
#   '9310',
#   '9314',
#   '9316',
#   '9327',
#   '9329',
#   '9330',
#   '9334',
#   '9338',
#   '9339',
#   '9340'],
#  '782611': ['9211',
#   '9228',
#   '9231',
#   '9240',
#   '9246',
#   '9254',
#   '9279',
#   '9303',
#   '9306',
#   '9310',
#   '9330',
#   '9331',
#   '9334',
#   '9340'],
#  '1970847': ['9211', '9236', '9326'],
#  '2197514': ['9211'],
#  '2173078': ['9211', '9231', '9240', '9254', '9279', '9317', '9320'],
#  '1139570': ['9211',
#   '9222',
#   '9228',
#   '9229',
#   '9232',
#   '9233',
#   '9235',
#   '9237',
#   '9239',
#   '9240',
#   '9246',
#   '9254',
#   '9265',
#   '9278',
#   '9288',
#   '9294',
#   '9295',
#   '9298',
#   '9303',
#   '9309',
#   '9310',
#   '9330',
#   '9339'],
#  '1842197': ['9211',
#   '9242',
#   '9265',
#   '9279',
#   '9298',
#   '9306',
#   '9309',
#   '9320',
#   '9340'],
#  '1003143': ['9211',
#   '9229',
#   '9235',
#   '9238',
#   '9242',
#   '9257',
#   '9265',
#   '9274',
#   '9276',
#   '9296',
#   '9298',
#   '9304',
#   '9320',
#   '9339',
#   '9340'],
#  '1383706': ['9211', '9298', '9340'],
#  '2439493': ['9211',
#   '9212',
#   '9213',
#   '9214',
#   '9215',
#   '9216',
#   '9217',
#   '9218',
#   '9219',
#   '9220',
#   '9221',
#   '9222',
#   '9223',
#   '9224',
#   '9225',
#   '9228',
#   '9229',
#   '9230',
#   '9231',
#   '9232',
#   '9233',
#   '9234',
#   '9235',
#   '9236',
#   '9237',
#   '9238',
#   '9239',
#   '9240',
#   '9241',
#   '9242',
#   '9243',
#   '9244',
#   '9245',
#   '9246',
#   '9248',
#   '9249',
#   '9251',
#   '9252',
#   '9253',
#   '9254',
#   '9255',
#   '9256',
#   '9257',
#   '9258',
#   '9259',
#   '9260',
#   '9261',
#   '9262',
#   '9263',
#   '9264',
#   '9265',
#   '9266',
#   '9267',
#   '9269',
#   '9270',
#   '9271',
#   '9272',
#   '9273',
#   '9274',
#   '9275',
#   '9276',
#   '9277',
#   '9278',
#   '9279',
#   '9280',
#   '9281',
#   '9283',
#   '9284',
#   '9285',
#   '9286',
#   '9287',
#   '9288',
#   '9289',
#   '9290',
#   '9291',
#   '9293',
#   '9294',
#   '9295',
#   '9296',
#   '9297',
#   '9298',
#   '9299',
#   '9300',
#   '9301',
#   '9302',
#   '9303',
#   '9304',
#   '9305',
#   '9306',
#   '9307',
#   '9308',
#   '9309',
#   '9310',
#   '9311',
#   '9312',
#   '9313',
#   '9314',
#   '9315',
#   '9316',
#   '9317',
#   '9318',
#   '9319',
#   '9320',
#   '9321',
#   '9322',
#   '9323',
#   '9324',
#   '9325',
#   '9326',
#   '9327',
#   '9328',
#   '9329',
#   '9330',
#   '9331',
#   '9332',
#   '9333',
#   '9334',
#   '9335',
#   '9336',
#   '9337',
#   '9338',
#   '9339',
#   '9340',
#   '9341',
#   '9342',
#   '0'],
#  '2615661': ['9211', '9340'],
#  '447282': ['9211',
#   '9231',
#   '9232',
#   '9241',
#   '9246',
#   '9290',
#   '9319',
#   '9326',
#   '9338',
#   '9340'],
#  '586257': ['9211', '9279', '9298'],
#  '1141213': ['9211', '9240', '9242', '9295', '9298', '9326', '9340'],
#  '8121': ['9211',
#   '9217',
#   '9230',
#   '9256',
#   '9262',
#   '9279',
#   '9291',
#   '9303',
#   '9310',
#   '9324',
#   '9328',
#   '9340'],
#  '97578': ['9211',
#   '9229',
#   '9232',
#   '9234',
#   '9235',
#   '9241',
#   '9254',
#   '9265',
#   '9298',
#   '9309',
#   '9320',
#   '9323',
#   '9326',
#   '9339',
#   '9340'],
#  '1914525': ['9211',
#   '9222',
#   '9224',
#   '9229',
#   '9235',
#   '9236',
#   '9241',
#   '9254',
#   '9265',
#   '9279',
#   '9288',
#   '9292',
#   '9298',
#   '9309',
#   '9320',
#   '9329',
#   '9340',
#   '0'],
#  '2055733': ['9211', '9232', '9237', '9254', '9274', '9298', '9320', '9340'],
#  '2532220': ['9211', '9298'],
#  '394622': ['9211', '9235', '9254', '9265', '9298', '9322', '9324', '9330'],
#  '869373': ['9211', '9241', '9340'],
#  '284489': ['9211', '9232', '9254', '9298', '9340'],
#  '833381': ['9211', '9241', '9295'],
#  '1310195': ['9211', '9309', '9325'],
#  '1959049': ['9211',
#   '9224',
#   '9232',
#   '9242',
#   '9254',
#   '9265',
#   '9298',
#   '9321',
#   '9330',
#   '9336'],
#  '932046': ['9211', '9298', '9317', '9340'],
#  '2015927': ['9211',
#   '9234',
#   '9235',
#   '9240',
#   '9242',
#   '9279',
#   '9309',
#   '9316',
#   '9330',
#   '9340'],
#  '2442581': ['9211', '9288', '9298', '9340'],
#  '2017364': ['9211', '9232', '9242', '9257', '9279', '9340'],
#  '632193': ['9211', '9232', '9276', '9320', '9323', '9340'],
#  '671743': ['9211', '9224'],
#  '42128': ['9211',
#   '9218',
#   '9235',
#   '9238',
#   '9241',
#   '9254',
#   '9265',
#   '9279',
#   '9298',
#   '9332',
#   '9340'],
#  '670205': ['9211'],
#  '52439': ['9211', '9241', '9242', '9254', '9298'],
#  '1409687': ['9211',
#   '9222',
#   '9229',
#   '9233',
#   '9234',
#   '9240',
#   '9254',
#   '9262',
#   '9265',
#   '9270',
#   '9271',
#   '9288',
#   '9298',
#   '9330',
#   '9331',
#   '9340'],
#  '735260': ['9211'],
#  '1473980': ['9211',
#   '9212',
#   '9215',
#   '9218',
#   '9219',
#   '9220',
#   '9222',
#   '9224',
#   '9226',
#   '9229',
#   '9230',
#   '9231',
#   '9232',
#   '9233',
#   '9234',
#   '9235',
#   '9237',
#   '9240',
#   '9242',
#   '9248',
#   '9254',
#   '9255',
#   '9256',
#   '9257',
#   '9259',
#   '9262',
#   '9265',
#   '9267',
#   '9270',
#   '9271',
#   '9272',
#   '9274',
#   '9276',
#   '9277',
#   '9278',
#   '9279',
#   '9281',
#   '9283',
#   '9285',
#   '9288',
#   '9291',
#   '9292',
#   '9294',
#   '9295',
#   '9298',
#   '9304',
#   '9306',
#   '9308',
#   '9309',
#   '9312',
#   '9316',
#   '9317',
#   '9320',
#   '9323',
#   '9327',
#   '9328',
#   '9329',
#   '9331',
#   '9333',
#   '9337',
#   '9340',
#   '0'],
#  '565510': ['9211',
#   '9234',
#   '9235',
#   '9237',
#   '9241',
#   '9254',
#   '9265',
#   '9276',
#   '9279',
#   '9288',
#   '9298',
#   '9320',
#   '9329',
#   '9330',
#   '9340'],
#  '1607747': ['9211',
#   '9231',
#   '9234',
#   '9276',
#   '9295',
#   '9298',
#   '9316',
#   '9330',
#   '9339',
#   '9340'],
#  '2509542': ['9211', '9235', '9265', '9270', '9340'],
#  '659285': ['9211', '9218', '9232', '9235', '9254', '9265', '9298', '9340'],
#  '83914': ['9211'],
#  '410402': ['9211', '9279', '9331'],
#  '862592': ['9211', '9235', '9254', '9261', '9323', '9340'],
#  '1316718': ['9211', '9232', '9235', '9295', '9340'],
#  '380673': ['9211', '9231', '9235', '9254', '9295', '9306', '9309', '9340'],
#  '1935614': ['9211', '9254'],
#  '44159': ['9211'],
#  '127671': ['9211', '9254', '9316', '9340'],
#  '1194698': ['9211',
#   '9222',
#   '9224',
#   '9235',
#   '9237',
#   '9254',
#   '9260',
#   '9262',
#   '9265',
#   '9274',
#   '9280',
#   '9298',
#   '9326'],
#  '1006570': ['9211', '9231', '9240', '9241', '9254', '9279'],
#  '1320684': ['9211'],
#  '367127': ['9211', '9232', '9339', '9340'],
#  '2420844': ['9211', '9236', '9240', '9265', '9271'],
#  '1903324': ['9211',
#   '9212',
#   '9218',
#   '9222',
#   '9235',
#   '9237',
#   '9238',
#   '9240',
#   '9241',
#   '9254',
#   '9257',
#   '9265',
#   '9270',
#   '9272',
#   '9276',
#   '9280',
#   '9283',
#   '9289',
#   '9294',
#   '9295',
#   '9296',
#   '9298',
#   '9310',
#   '9319',
#   '9320',
#   '9322',
#   '9326',
#   '9329',
#   '9330',
#   '9334',
#   '9340'],
#  '512490': ['9211'],
#  '2565600': ['9211', '9298'],
#  '1162050': ['9211', '9340'],
#  '1943605': ['9211',
#   '9218',
#   '9231',
#   '9235',
#   '9237',
#   '9238',
#   '9242',
#   '9254',
#   '9265',
#   '9298',
#   '9323',
#   '9340'],
#  '943817': ['9211', '9241', '9242', '9279', '9340'],
#  '882543': ['9211', '9236', '9279', '9330'],
#  '501823': ['9211',
#   '9224',
#   '9241',
#   '9254',
#   '9265',
#   '9279',
#   '9283',
#   '9288',
#   '9298',
#   '9337',
#   '9340'],
#  '1922072': ['9211',
#   '9223',
#   '9234',
#   '9235',
#   '9245',
#   '9265',
#   '9276',
#   '9279',
#   '9295',
#   '9298',
#   '9309',
#   '9330',
#   '9331',
#   '9334'],
#  '2457095': ['9211',
#   '9213',
#   '9218',
#   '9221',
#   '9228',
#   '9229',
#   '9231',
#   '9233',
#   '9234',
#   '9235',
#   '9237',
#   '9239',
#   '9244',
#   '9247',
#   '9254',
#   '9255',
#   '9256',
#   '9257',
#   '9259',
#   '9262',
#   '9265',
#   '9266',
#   '9267',
#   '9268',
#   '9270',
#   '9274',
#   '9275',
#   '9276',
#   '9277',
#   '9285',
#   '9288',
#   '9290',
#   '9293',
#   '9294',
#   '9295',
#   '9298',
#   '9303',
#   '9305',
#   '9306',
#   '9309',
#   '9310',
#   '9312',
#   '9314',
#   '9317',
#   '9321',
#   '9326',
#   '9328',
#   '9330',
#   '9334',
#   '9338',
#   '9340'],
#  '269316': ['9211', '9279', '9340'],
#  '1876520': ['9211',
#   '9234',
#   '9237',
#   '9239',
#   '9240',
#   '9241',
#   '9242',
#   '9249',
#   '9252',
#   '9253',
#   '9255',
#   '9257',
#   '9258',
#   '9269',
#   '9272',
#   '9279',
#   '9285',
#   '9287',
#   '9288',
#   '9290',
#   '9296',
#   '9299',
#   '9303',
#   '9309',
#   '9313',
#   '9316',
#   '9320',
#   '9323',
#   '9326',
#   '9328',
#   '9330',
#   '9331',
#   '9336',
#   '9340',
#   '9342',
#   '0'],
#  '1933832': ['9211', '9234', '9241', '9270', '9279', '9295', '9303', '9310'],
#  '34092': ['9211', '9340'],
#  '2451907': ['9211',
#   '9224',
#   '9232',
#   '9234',
#   '9241',
#   '9254',
#   '9265',
#   '9267',
#   '9295',
#   '9306'],
#  '1611056': ['9211',
#   '9218',
#   '9229',
#   '9234',
#   '9240',
#   '9241',
#   '9242',
#   '9254',
#   '9272',
#   '9279',
#   '9295',
#   '9298',
#   '9303',
#   '9310',
#   '9314',
#   '9320',
#   '9323',
#   '9330',
#   '9334',
#   '9340'],
#  '902293': ['9211', '9254', '9317', '9332'],
#  '1200651': ['9211', '9242'],
#  '590607': ['9211',
#   '9217',
#   '9224',
#   '9228',
#   '9234',
#   '9235',
#   '9242',
#   '9254',
#   '9257',
#   '9270',
#   '9275',
#   '9276',
#   '9279',
#   '9295',
#   '9298',
#   '9316',
#   '9317',
#   '9330',
#   '9331',
#   '9340'],
#  '2157535': ['9211', '9340'],
#  '1997212': ['9211'],
#  '2190310': ['9211', '9232', '9254', '9265', '9279', '9298', '9340', '0'],
#  '554137': ['9211',
#   '9218',
#   '9222',
#   '9224',
#   '9240',
#   '9242',
#   '9246',
#   '9254',
#   '9262',
#   '9265',
#   '9267',
#   '9272',
#   '9298',
#   '9306',
#   '9317',
#   '9329',
#   '9337',
#   '9340',
#   '9341'],
#  '1554887': ['9211', '9217', '9334'],
#  '975712': ['9211', '9234', '9254', '9298', '9320', '9340'],
#  '196716': ['9211', '9326', '9327'],
#  '2112141': ['9211',
#   '9229',
#   '9235',
#   '9240',
#   '9254',
#   '9265',
#   '9276',
#   '9295',
#   '9298',
#   '9309',
#   '9310',
#   '9340'],
#  '1488776': ['9211'],
#  '1586546': ['9211',
#   '9235',
#   '9240',
#   '9254',
#   '9295',
#   '9298',
#   '9317',
#   '9330',
#   '9340'],
#  '1120581': ['9211', '9266', '9284', '9302', '9319', '9330', '9331', '9340'],
#  '494200': ['9211', '9224', '9254', '9306', '9323'],
#  '1268483': ['9211',
#   '9216',
#   '9222',
#   '9228',
#   '9235',
#   '9237',
#   '9242',
#   '9254',
#   '9265',
#   '9272',
#   '9295',
#   '9303',
#   '9331',
#   '9334',
#   '9340'],
#  '1575729': ['9211', '9254', '9340'],
#  '1548355': ['9211'],
#  '1061993': ['9211', '9326'],
#  '671859': ['9211', '9235', '9265', '9298'],
#  '2432474': ['9211',
#   '9224',
#   '9229',
#   '9232',
#   '9234',
#   '9235',
#   '9240',
#   '9254',
#   '9265',
#   '9288',
#   '9298',
#   '9320',
#   '9340'],
#  '998502': ['9211',
#   '9218',
#   '9228',
#   '9234',
#   '9235',
#   '9240',
#   '9241',
#   '9254',
#   '9256',
#   '9265',
#   '9276',
#   '9279',
#   '9295',
#   '9296',
#   '9298',
#   '9303',
#   '9310',
#   '9322',
#   '9330'],
#  '1297706': ['9211',
#   '9217',
#   '9234',
#   '9241',
#   '9242',
#   '9254',
#   '9265',
#   '9267',
#   '9279',
#   '9323',
#   '9340'],
#  '1754537': ['9211',
#   '9224',
#   '9235',
#   '9240',
#   '9241',
#   '9242',
#   '9243',
#   '9279',
#   '9280',
#   '9295',
#   '9310',
#   '9340'],
#  '1346837': ['9211', '9240', '9265', '9279', '9340'],
#  '1994646': ['9211',
#   '9236',
#   '9241',
#   '9242',
#   '9254',
#   '9265',
#   '9279',
#   '9298',
#   '9330'],
#  '2273948': ['9211', '9236', '9254', '9265', '9274', '9320', '9327'],
#  '1191743': ['9211', '9218', '9228'],
#  '452494': ['9211', '9234', '9237', '9254', '9298', '9316', '9340'],
#  '1552084': ['9211',
#   '9229',
#   '9232',
#   '9234',
#   '9235',
#   '9245',
#   '9254',
#   '9265',
#   '9271',
#   '9273',
#   '9278',
#   '9288',
#   '9298',
#   '9320',
#   '9329',
#   '9340'],
#  '437840': ['9211', '9330', '9340'],
#  '176853': ['9211'],
#  '2047178': ['9211',
#   '9229',
#   '9234',
#   '9235',
#   '9238',
#   '9240',
#   '9254',
#   '9265',
#   '9271',
#   '9288',
#   '9298',
#   '9309',
#   '9320',
#   '9340'],
#  '1551018': ['9211', '9241', '9298', '9315', '9340'],
#  '363777': ['9211', '9340'],
#  '613651': ['9211',
#   '9229',
#   '9233',
#   '9234',
#   '9235',
#   '9241',
#   '9246',
#   '9254',
#   '9265',
#   '9279',
#   '9320',
#   '9330',
#   '9340'],
#  '776126': ['9211', '9232', '9235', '9275', '9280'],
#  '838584': ['9211',
#   '9240',
#   '9241',
#   '9242',
#   '9252',
#   '9265',
#   '9279',
#   '9330',
#   '9340'],
#  '2052290': ['9211', '9298', '9340'],
#  '1957786': ['9211',
#   '9217',
#   '9224',
#   '9229',
#   '9232',
#   '9234',
#   '9235',
#   '9240',
#   '9254',
#   '9262',
#   '9265',
#   '9271',
#   '9274',
#   '9278',
#   '9288',
#   '9298',
#   '9308',
#   '9309',
#   '9320',
#   '9326',
#   '9337',
#   '9339',
#   '9340',
#   '0'],
#  '2417531': ['9211',
#   '9217',
#   '9229',
#   '9232',
#   '9234',
#   '9235',
#   '9237',
#   '9240',
#   '9241',
#   '9254',
#   '9262',
#   '9265',
#   '9270',
#   '9278',
#   '9279',
#   '9287',
#   '9295',
#   '9298',
#   '9323',
#   '9329',
#   '9340'],
#  '1349656': ['9211', '9234', '9238', '9273', '9278', '9340'],
#  '701443': ['9211',
#   '9234',
#   '9235',
#   '9237',
#   '9238',
#   '9240',
#   '9254',
#   '9262',
#   '9265',
#   '9271',
#   '9272',
#   '9295',
#   '9298',
#   '9320',
#   '9323',
#   '9329',
#   '9331',
#   '9340'],
#  '1362004': ['9211', '9229'],
#  '900992': ['9211', '9235', '9254', '9295', '9329', '9340'],
#  '9557': ['9211',
#   '9222',
#   '9234',
#   '9235',
#   '9236',
#   '9239',
#   '9254',
#   '9260',
#   '9265',
#   '9272',
#   '9293',
#   '9298',
#   '9323',
#   '9332'],
#  '1664010': ['9211',
#   '9212',
#   '9213',
#   '9214',
#   '9215',
#   '9216',
#   '9217',
#   '9218',
#   '9219',
#   '9220',
#   '9221',
#   '9222',
#   '9223',
#   '9224',
#   '9225',
#   '9226',
#   '9227',
#   '9228',
#   '9229',
#   '9230',
#   '9231',
#   '9232',
#   '9233',
#   '9234',
#   '9235',
#   '9236',
#   '9237',
#   '9238',
#   '9239',
#   '9240',
#   '9241',
#   '9242',
#   '9243',
#   '9244',
#   '9245',
#   '9247',
#   '9248',
#   '9249',
#   '9251',
#   '9252',
#   '9253',
#   '9254',
#   '9255',
#   '9256',
#   '9257',
#   '9259',
#   '9260',
#   '9261',
#   '9262',
#   '9263',
#   '9264',
#   '9265',
#   '9266',
#   '9267',
#   '9268',
#   '9269',
#   '9270',
#   '9271',
#   '9272',
#   '9274',
#   '9275',
#   '9276',
#   '9277',
#   '9278',
#   '9279',
#   '9280',
#   '9281',
#   '9282',
#   '9283',
#   '9284',
#   '9285',
#   '9286',
#   '9287',
#   '9288',
#   '9289',
#   '9290',
#   '9291',
#   '9292',
#   '9293',
#   '9294',
#   '9295',
#   '9296',
#   '9298',
#   '9299',
#   '9300',
#   '9301',
#   '9303',
#   '9304',
#   '9305',
#   '9306',
#   '9307',
#   '9308',
#   '9309',
#   '9311',
#   '9312',
#   '9313',
#   '9314',
#   '9315',
#   '9316',
#   '9317',
#   '9318',
#   '9319',
#   '9320',
#   '9321',
#   '9322',
#   '9325',
#   '9326',
#   '9327',
#   '9328',
#   '9329',
#   '9330',
#   '9331',
#   '9332',
#   '9333',
#   '9334',
#   '9335',
#   '9337',
#   '9339',
#   '9340',
#   '9341',
#   '9342',
#   '0'],
#  '2125415': ['9211', '9279', '9340'],
#  '2296108': ['9211',
#   '9217',
#   '9236',
#   '9239',
#   '9241',
#   '9254',
#   '9260',
#   '9265',
#   '9298',
#   '9340'],
#  '305343': ['9211', '9235', '9240', '9265', '9310', '9340'],
#  '1563783': ['9211', '9279', '9298', '9340'],
#  '511942': ['9211',
#   '9234',
#   '9235',
#   '9240',
#   '9254',
#   '9288',
#   '9309',
#   '9320',
#   '9340'],
#  '776905': ['9211',
#   '9234',
#   '9235',
#   '9240',
#   '9254',
#   '9265',
#   '9276',
#   '9279',
#   '9288',
#   '9298',
#   '9320',
#   '9340'],
#  '943538': ['9211',
#   '9218',
#   '9231',
#   '9238',
#   '9244',
#   '9254',
#   '9265',
#   '9270',
#   '9279',
#   '9295',
#   '9298',
#   '9306',
#   '9326',
#   '9331',
#   '9340'],
#  '2334472': ['9211', '9235', '9241', '9265', '9340'],
#  '985372': ['9211', '9224', '9279', '9330'],
#  '1848257': ['9211', '9236', '9242', '9298', '9340'],
#  '156898': ['9211', '9257', '9316', '9340'],
#  '550341': ['9211', '9217', '9224', '9269', '9316', '9329', '9330', '9340'],
#  '1502539': ['9211',
#   '9231',
#   '9234',
#   '9235',
#   '9240',
#   '9254',
#   '9265',
#   '9272',
#   '9279',
#   '9298',
#   '9330',
#   '9331',
#   '9340'],
#  '619027': ['9211', '9340'],
#  '1811248': ['9211', '9223', '9232', '9242', '9331'],
#  '1377382': ['9211', '9340'],
#  '2180934': ['9211', '9290', '9316', '9340'],
#  '751829': ['9211',
#   '9223',
#   '9234',
#   '9236',
#   '9241',
#   '9254',
#   '9265',
#   '9296',
#   '9298',
#   '9327',
#   '9337',
#   '9340'],
#  '285330': ['9211',
#   '9217',
#   '9231',
#   '9234',
#   '9254',
#   '9265',
#   '9298',
#   '9327',
#   '9330',
#   '9340'],
#  '491739': ['9211', '9217', '9224', '9234', '9241', '9295', '9303', '9330'],
#  '919160': ['9211',
#   '9224',
#   '9228',
#   '9234',
#   '9235',
#   '9241',
#   '9254',
#   '9265',
#   '9274',
#   '9279',
#   '9295',
#   '9303',
#   '9310',
#   '9339',
#   '9340'],
#  '1677588': ['9211',
#   '9228',
#   '9240',
#   '9252',
#   '9279',
#   '9298',
#   '9303',
#   '9309',
#   '9323',
#   '9330',
#   '9331',
#   '9340'],
#  '2553038': ['9211', '9235', '9242', '9254', '9279', '9298'],
#  '1725751': ['9211', '9234', '9241', '9254', '9326', '9340'],
#  '25049': ['9211',
#   '9217',
#   '9229',
#   '9265',
#   '9294',
#   '9295',
#   '9298',
#   '9310',
#   '9320',
#   '9327',
#   '9331',
#   '9339',
#   '9340'],
#  '2509048': ['9211',
#   '9212',
#   '9218',
#   '9229',
#   '9232',
#   '9235',
#   '9237',
#   '9254',
#   '9265',
#   '9280',
#   '9295',
#   '9303',
#   '9320',
#   '9330',
#   '9340'],
#  '1733851': ['9211', '9235', '9240', '9254', '9265', '9274', '9309'],
#  '1325847': ['9211', '9232', '9276', '9278', '9298'],
#  '1749706': ['9211',
#   '9217',
#   '9229',
#   '9235',
#   '9254',
#   '9265',
#   '9279',
#   '9288',
#   '9298',
#   '9320',
#   '9330',
#   '9340'],
#  '2273061': ['9211', '9232', '9276', '9340'],
#  '1965022': ['9211', '9241', '9242', '9295', '9326', '9340'],
#  '1780748': ['9211', '9232', '9242', '9254', '9340'],
#  '2326523': ['9211'],
#  '956510': ['9211',
#   '9234',
#   '9235',
#   '9240',
#   '9241',
#   '9254',
#   '9265',
#   '9320',
#   '9326',
#   '9340'],
#  '1568841': ['9211', '9217', '9236', '9254', '9260', '9326', '9330'],
#  '285400': ['9211', '9236', '9260', '9340'],
#  '2497577': ['9211',
#   '9217',
#   '9222',
#   '9229',
#   '9232',
#   '9234',
#   '9235',
#   '9236',
#   '9237',
#   '9238',
#   '9254',
#   '9265',
#   '9276',
#   '9298',
#   '9320',
#   '9340'],
#  '828349': ['9211',
#   '9217',
#   '9224',
#   '9232',
#   '9234',
#   '9235',
#   '9254',
#   '9257',
#   '9265',
#   '9274',
#   '9278',
#   '9298',
#   '9316',
#   '9320',
#   '9330',
#   '9340'],
#  '2076738': ['9211',
#   '9235',
#   '9240',
#   '9241',
#   '9265',
#   '9279',
#   '9295',
#   '9310',
#   '9327',
#   '9330',
#   '9340'],
#  '1051931': ['9211', '9254', '9298'],
#  '2100306': ['9211',
#   '9217',
#   '9236',
#   '9237',
#   '9254',
#   '9265',
#   '9278',
#   '9279',
#   '9298',
#   '9308',
#   '9320',
#   '9329',
#   '9338'],
#  '1275931': ['9211'],
#  '2019240': ['9211',
#   '9217',
#   '9222',
#   '9229',
#   '9233',
#   '9234',
#   '9235',
#   '9236',
#   '9237',
#   '9254',
#   '9262',
#   '9265',
#   '9271',
#   '9276',
#   '9279',
#   '9288',
#   '9298',
#   '9304',
#   '9308',
#   '9320',
#   '9338',
#   '9340'],
#  '710049': ['9211', '9241', '9254', '9276', '9279'],
#  '1664033': ['9211', '9254'],
#  '1270278': ['9211', '9296', '9298'],
#  '1961656': ['9211', '9265', '9279'],
#  '644154': ['9211', '9276', '9340'],
#  '2251124': ['9211', '9242'],
#  '2291306': ['9211',
#   '9217',
#   '9223',
#   '9224',
#   '9228',
#   '9229',
#   '9232',
#   '9234',
#   '9235',
#   '9236',
#   '9237',
#   '9241',
#   '9242',
#   '9247',
#   '9249',
#   '9255',
#   '9256',
#   '9261',
#   '9265',
#   '9267',
#   '9272',
#   '9278',
#   '9279',
#   '9288',
#   '9290',
#   '9295',
#   '9296',
#   '9298',
#   '9309',
#   '9320',
#   '9326',
#   '9328',
#   '9330',
#   '9333',
#   '9334',
#   '9338',
#   '9339',
#   '9340'],
#  '2456905': ['9211', '9254', '9320', '9340'],
#  '604661': ['9211', '9235', '9254', '9280', '9329', '9340'],
#  '1523169': ['9211',
#   '9236',
#   '9240',
#   '9254',
#   '9265',
#   '9274',
#   '9295',
#   '9298',
#   '9320',
#   '9323'],
#  '677888': ['9211', '9298', '9307', '9330', '9331'],
#  '2088567': ['9211'],
#  '1087376': ['9211', '9236', '9298', '9340'],
#  '2524717': ['9211', '9241', '9323'],
#  '1238184': ['9211',
#   '9218',
#   '9228',
#   '9229',
#   '9236',
#   '9237',
#   '9240',
#   '9254',
#   '9262',
#   '9265',
#   '9288',
#   '9298',
#   '9303',
#   '9314',
#   '9319',
#   '9334',
#   '9340',
#   '0'],
#  '991810': ['9211', '9217'],
#  '1122906': ['9211', '9327'],
#  '418550': ['9211',
#   '9234',
#   '9235',
#   '9238',
#   '9241',
#   '9254',
#   '9262',
#   '9265',
#   '9320',
#   '9340'],
#  '2385512': ['9211', '9229', '9298', '9330', '9340'],
#  '914940': ['9211',
#   '9229',
#   '9235',
#   '9236',
#   '9254',
#   '9265',
#   '9271',
#   '9274',
#   '9298',
#   '9304',
#   '9306',
#   '9317',
#   '9338',
#   '9340'],
#  '2301108': ['9211', '9252'],
#  '2002198': ['9211',
#   '9234',
#   '9235',
#   '9240',
#   '9254',
#   '9265',
#   '9288',
#   '9298',
#   '9320',
#   '9323',
#   '9340'],
#  '448086': ['9211',
#   '9218',
#   '9229',
#   '9254',
#   '9265',
#   '9278',
#   '9295',
#   '9298',
#   '9340'],
#  '1184029': ['9211',
#   '9228',
#   '9229',
#   '9242',
#   '9251',
#   '9263',
#   '9279',
#   '9295',
#   '9300',
#   '9326',
#   '9328'],
#  '1042584': ['9211', '9235', '9340'],
#  '2433610': ['9211',
#   '9222',
#   '9224',
#   '9232',
#   '9235',
#   '9240',
#   '9246',
#   '9254',
#   '9256',
#   '9262',
#   '9265',
#   '9279',
#   '9298',
#   '9340'],
#  '2394704': ['9211',
#   '9229',
#   '9234',
#   '9235',
#   '9240',
#   '9246',
#   '9254',
#   '9262',
#   '9265',
#   '9271',
#   '9276',
#   '9279',
#   '9298',
#   '9309',
#   '9320',
#   '9340'],
#  '529889': ['9211',
#   '9224',
#   '9228',
#   '9242',
#   '9265',
#   '9279',
#   '9295',
#   '9298',
#   '9330',
#   '9340'],
#  '700049': ['9211', '9237', '9240', '9242', '9254', '9279'],
#  '491531': ['9211',
#   '9212',
#   '9216',
#   '9218',
#   '9222',
#   '9223',
#   '9224',
#   '9227',
#   '9228',
#   '9231',
#   '9232',
#   '9234',
#   '9235',
#   '9236',
#   '9237',
#   '9240',
#   '9241',
#   '9245',
#   '9246',
#   '9248',
#   '9253',
#   '9254',
#   '9255',
#   '9257',
#   '9262',
#   '9263',
#   '9265',
#   '9271',
#   '9272',
#   '9273',
#   '9274',
#   '9276',
#   '9277',
#   '9278',
#   '9279',
#   '9281',
#   '9283',
#   '9287',
#   '9290',
#   '9291',
#   '9293',
#   '9295',
#   '9298',
#   '9299',
#   '9303',
#   '9304',
#   '9308',
#   '9309',
#   '9310',
#   '9314',
#   '9317',
#   '9320',
#   '9322',
#   '9323',
#   '9326',
#   '9328',
#   '9330',
#   '9334',
#   '9338',
#   '9339',
#   '9340',
#   '9342'],
#  '341933': ['9211', '9295', '9298', '9339', '9340'],
#  '1811259': ['9211', '9236', '9267', '9274', '9279', '9295'],
#  '2413595': ['9211', '9222', '9228', '9229', '9234', '9235', '9254', '9265'],
#  '411852': ['9211'],
#  '1348456': ['9211',
#   '9215',
#   '9224',
#   '9232',
#   '9234',
#   '9240',
#   '9254',
#   '9265',
#   '9279',
#   '9298',
#   '9320',
#   '9339',
#   '9340'],
#  '1950613': ['9211'],
#  '2649308': ['9211', '9218', '9279', '9294', '9324', '9340'],
#  '1726040': ['9211', '9232', '9254', '9280', '9339', '9340'],
#  '2034012': ['9211'],
#  '1623198': ['9211', '9254', '9340'],
#  '812119': ['9211'],
#  '2144716': ['9211', '9242'],
#  '111690': ['9211', '9224', '9326', '9340'],
#  '1409036': ['9211', '9223', '9224', '9232', '9285', '9309'],
#  '438814': ['9211'],
#  '119601': ['9211'],
#  '2501510': ['9211', '9340'],
#  '1041253': ['9211', '9242', '9279', '9295', '9340'],
#  '2510970': ['9211', '9215', '9236', '9254', '9265', '9298'],
#  '352712': ['9211', '9235'],
#  '318235': ['9211',
#   '9232',
#   '9240',
#   '9254',
#   '9279',
#   '9290',
#   '9320',
#   '9323',
#   '9340'],
#  '2302920': ['9211', '9241', '9254', '9326', '9340'],
#  '1048813': ['9211', '9237', '9240', '9241', '9256', '9279', '9339'],
#  '1431136': ['9211'],
#  '1539884': ['9211', '9240', '9265', '9279', '9310'],
#  '360005': ['9211',
#   '9223',
#   '9228',
#   '9229',
#   '9230',
#   '9234',
#   '9236',
#   '9254',
#   '9264',
#   '9265',
#   '9279',
#   '9310',
#   '9329',
#   '9340'],
#  '2513067': ['9211', '9232', '9233', '9246', '9298', '9309', '9340'],
#  '789014': ['9211',
#   '9217',
#   '9218',
#   '9222',
#   '9223',
#   '9229',
#   '9232',
#   '9233',
#   '9234',
#   '9235',
#   '9240',
#   '9245',
#   '9248',
#   '9254',
#   '9256',
#   '9257',
#   '9258',
#   '9259',
#   '9265',
#   '9267',
#   '9272',
#   '9274',
#   '9276',
#   '9279',
#   '9288',
#   '9290',
#   '9293',
#   '9298',
#   '9301',
#   '9309',
#   '9316',
#   '9317',
#   '9320',
#   '9323',
#   '9327',
#   '9328',
#   '9329',
#   '9330',
#   '9336',
#   '9337',
#   '9340'],
#  '2295594': ['9211',
#   '9217',
#   '9224',
#   '9232',
#   '9234',
#   '9237',
#   '9239',
#   '9240',
#   '9242',
#   '9245',
#   '9265',
#   '9273',
#   '9278',
#   '9288',
#   '9298',
#   '9302',
#   '9308',
#   '9309',
#   '9316',
#   '9319',
#   '9330',
#   '9331',
#   '9333',
#   '9339'],
#  '798296': ['9211',
#   '9212',
#   '9213',
#   '9217',
#   '9223',
#   '9224',
#   '9229',
#   '9233',
#   '9234',
#   '9237',
#   '9239',
#   '9240',
#   '9241',
#   '9242',
#   '9243',
#   '9244',
#   '9249',
#   '9252',
#   '9253',
#   '9254',
#   '9257',
#   '9258',
#   '9264',
#   '9265',
#   '9267',
#   '9269',
#   '9270',
#   '9276',
#   '9278',
#   '9279',
#   '9285',
#   '9288',
#   '9294',
#   '9298',
#   '9300',
#   '9301',
#   '9303',
#   '9304',
#   '9307',
#   '9308',
#   '9310',
#   '9313',
#   '9316',
#   '9320',
#   '9321',
#   '9322',
#   '9323',
#   '9326',
#   '9329',
#   '9334',
#   '9336',
#   '9339',
#   '9340',
#   '9342'],
#  '2308465': ['9211'],
#  '1933656': ['9211',
#   '9222',
#   '9234',
#   '9236',
#   '9254',
#   '9265',
#   '9279',
#   '9298',
#   '9327',
#   '9340'],
#  '2105815': ['9211', '9241', '9242', '9265'],
#  '399971': ['9211',
#   '9212',
#   '9218',
#   '9223',
#   '9229',
#   '9234',
#   '9236',
#   '9237',
#   '9240',
#   '9241',
#   '9242',
#   '9254',
#   '9260',
#   '9265',
#   '9274',
#   '9279',
#   '9295',
#   '9298',
#   '9303',
#   '9306',
#   '9310',
#   '9323',
#   '9326',
#   '9340'],
#  '848891': ['9211', '9298', '9340'],
#  '1240950': ['9211', '9309', '9340'],
#  '1635121': ['9211', '9309'],
#  '957156': ['9211'],
#  '515016': ['9211'],
#  '2266937': ['9211', '9218', '9238', '9274', '9279', '9323', '9330', '9340'],
#  '508927': ['9211',
#   '9229',
#   '9232',
#   '9235',
#   '9240',
#   '9254',
#   '9265',
#   '9279',
#   '9280',
#   '9288',
#   '9294',
#   '9309',
#   '9320',
#   '9323',
#   '9330',
#   '9340'],
#  '1627955': ['9211',
#   '9218',
#   '9223',
#   '9232',
#   '9235',
#   '9236',
#   '9237',
#   '9254',
#   '9262',
#   '9265',
#   '9285',
#   '9290',
#   '9295',
#   '9296',
#   '9317',
#   '9319',
#   '9322',
#   '9334'],
#  '1389358': ['9211', '9298'],
#  '2646347': ['9211',
#   '9217',
#   '9218',
#   '9234',
#   '9235',
#   '9240',
#   '9265',
#   '9277',
#   '9295',
#   '9303',
#   '9320',
#   '9324',
#   '9334',
#   '9340'],
#  '1301942': ['9211', '9238', '9240', '9254', '9331'],
#  '1608476': ['9211', '9235', '9254', '9326', '9340'],
#  '229716': ['9211', '9235', '9240', '9242', '9279'],
#  '305344': ['9211',
#   '9212',
#   '9213',
#   '9214',
#   '9215',
#   '9216',
#   '9217',
#   '9218',
#   '9219',
#   '9220',
#   '9221',
#   '9222',
#   '9223',
#   '9224',
#   '9225',
#   '9226',
#   '9227',
#   '9228',
#   '9229',
#   '9230',
#   '9231',
#   '9232',
#   '9233',
#   '9234',
#   '9235',
#   '9236',
#   '9237',
#   '9238',
#   '9239',
#   '9240',
#   '9241',
#   '9242',
#   '9243',
#   '9244',
#   '9245',
#   '9246',
#   '9247',
#   '9248',
#   '9249',
#   '9250',
#   '9251',
#   '9252',
#   '9253',
#   '9254',
#   '9255',
#   '9256',
#   '9257',
#   '9258',
#   '9259',
#   '9260',
#   '9261',
#   '9262',
#   '9263',
#   '9264',
#   '9265',
#   '9266',
#   '9267',
#   '9268',
#   '9269',
#   '9270',
#   '9271',
#   '9272',
#   '9273',
#   '9274',
#   '9275',
#   '9276',
#   '9277',
#   '9278',
#   '9279',
#   '9280',
#   '9281',
#   '9282',
#   '9283',
#   '9284',
#   '9285',
#   '9286',
#   '9287',
#   '9288',
#   '9289',
#   '9290',
#   '9291',
#   '9292',
#   '9293',
#   '9294',
#   '9295',
#   '9296',
#   '9297',
#   '9298',
#   '9299',
#   '9300',
#   '9301',
#   '9302',
#   '9303',
#   '9304',
#   '9305',
#   '9306',
#   '9307',
#   '9308',
#   '9309',
#   '9310',
#   '9311',
#   '9312',
#   '9313',
#   '9314',
#   '9315',
#   '9316',
#   '9317',
#   '9318',
#   '9319',
#   '9320',
#   '9321',
#   '9322',
#   '9323',
#   '9324',
#   '9325',
#   '9326',
#   '9327',
#   '9328',
#   '9329',
#   '9330',
#   '9331',
#   '9332',
#   '9333',
#   '9334',
#   '9335',
#   '9336',
#   '9337',
#   '9338',
#   '9339',
#   '9340',
#   '9341',
#   '9342'],
#  '372888': ['9211', '9231', '9242', '9298', '9340'],
#  '427379': ['9211'],
#  '73988': ['9211',
#   '9232',
#   '9234',
#   '9235',
#   '9254',
#   '9265',
#   '9306',
#   '9320',
#   '9326'],
#  '349905': ['9211', '9274', '9340'],
#  '1068647': ['9211'],
#  '637596': ['9211', '9231', '9232', '9272', '9279', '9340'],
#  '2118771': ['9211', '9298'],
#  '1444817': ['9211', '9235', '9236', '9241', '9242', '9340'],
#  '1075294': ['9211'],
#  '853266': ['9211', '9340'],
#  '1104415': ['9211', '9231', '9232', '9234', '9254', '9265', '9316'],
#  '261806': ['9211', '9235', '9236', '9254', '9265'],
#  '718565': ['9211', '9242', '9243', '9255', '9330'],
#  '1988735': ['9211',
#   '9212',
#   '9217',
#   '9218',
#   '9229',
#   '9232',
#   '9233',
#   '9234',
#   '9235',
#   '9237',
#   '9238',
#   '9239',
#   '9240',
#   '9254',
#   '9265',
#   '9270',
#   '9271',
#   '9273',
#   '9274',
#   '9276',
#   '9278',
#   '9288',
#   '9298',
#   '9304',
#   '9306',
#   '9309',
#   '9340'],
#  '851211': ['9211', '9217', '9254', '9340'],
#  '649017': ['9211',
#   '9217',
#   '9229',
#   '9233',
#   '9234',
#   '9235',
#   '9240',
#   '9254',
#   '9276',
#   '9329',
#   '9330',
#   '9340'],
#  '2372703': ['9211', '9238', '9277', '9326'],
#  '2640278': ['9211',
#   '9217',
#   '9229',
#   '9232',
#   '9234',
#   '9235',
#   '9236',
#   '9240',
#   '9246',
#   '9254',
#   '9257',
#   '9260',
#   '9265',
#   '9279',
#   '9288',
#   '9298',
#   '9304',
#   '9308',
#   '9319',
#   '9320',
#   '9329',
#   '9338',
#   '9340'],
#  '2586088': ['9211', '9309', '9331'],
#  '1214492': ['9211', '9224', '9279', '9340'],
#  '1851166': ['9211', '9309'],
#  '2584676': ['9211',
#   '9215',
#   '9217',
#   '9222',
#   '9223',
#   '9229',
#   '9232',
#   '9233',
#   '9234',
#   '9235',
#   '9238',
#   '9239',
#   '9240',
#   '9254',
#   '9262',
#   '9265',
#   '9271',
#   '9274',
#   '9278',
#   '9279',
#   '9280',
#   '9283',
#   '9286',
#   '9288',
#   '9294',
#   '9298',
#   '9301',
#   '9306',
#   '9309',
#   '9316',
#   '9320',
#   '9329',
#   '9330',
#   '9331',
#   '9339',
#   '9340'],
#  '1087451': ['9211',
#   '9240',
#   '9241',
#   '9242',
#   '9279',
#   '9294',
#   '9295',
#   '9310',
#   '9340'],
#  '1985315': ['9211', '9234', '9240', '9254', '9265', '9298', '9330'],
#  '1586276': ['9211',
#   '9232',
#   '9233',
#   '9251',
#   '9265',
#   '9278',
#   '9298',
#   '9319',
#   '9340'],
#  '161081': ['9211', '9232', '9235', '9254', '9340'],
#  '2451635': ['9211', '9224', '9232', '9254', '9274', '9338'],
#  '2155529': ['9211', '9241', '9254', '9265', '9340'],
#  '108936': ['9211',
#   '9223',
#   '9232',
#   '9235',
#   '9236',
#   '9237',
#   '9246',
#   '9254',
#   '9265',
#   '9279',
#   '9288',
#   '9298',
#   '9319',
#   '9320',
#   '9330',
#   '9340'],
#  '411512': ['9211',
#   '9229',
#   '9231',
#   '9233',
#   '9235',
#   '9240',
#   '9254',
#   '9265',
#   '9279',
#   '9294',
#   '9295',
#   '9298',
#   '9303',
#   '9330',
#   '9331',
#   '9339',
#   '9340'],
#  '159159': ['9211',
#   '9223',
#   '9228',
#   '9232',
#   '9237',
#   '9242',
#   '9244',
#   '9256',
#   '9261',
#   '9265',
#   '9272',
#   '9276',
#   '9279',
#   '9295',
#   '9298',
#   '9306',
#   '9310',
#   '9330',
#   '9334'],
#  '1898553': ['9211', '9256', '9279', '9298', '9316', '9340'],
#  '2287125': ['9211',
#   '9234',
#   '9235',
#   '9241',
#   '9242',
#   '9246',
#   '9254',
#   '9265',
#   '9298',
#   '9306',
#   '9320',
#   '9326',
#   '9331',
#   '9340'],
#  '2644945': ['9211',
#   '9231',
#   '9237',
#   '9240',
#   '9254',
#   '9265',
#   '9298',
#   '9309',
#   '9323',
#   '9340'],
#  '1283171': ['9211',
#   '9231',
#   '9232',
#   '9236',
#   '9237',
#   '9254',
#   '9265',
#   '9267',
#   '9270',
#   '9274',
#   '9279',
#   '9298',
#   '9326',
#   '9327',
#   '9339'],
#  '2224330': ['9211', '9267'],
#  '2044154': ['9211'],
#  '1891929': ['9211', '9254', '9298', '9340'],
#  '743654': ['9211'],
#  '752642': ['9211',
#   '9212',
#   '9217',
#   '9218',
#   '9220',
#   '9221',
#   '9222',
#   '9223',
#   '9224',
#   '9228',
#   '9229',
#   '9230',
#   '9233',
#   '9234',
#   '9235',
#   '9236',
#   '9237',
#   '9238',
#   '9239',
#   '9240',
#   '9242',
#   '9245',
#   '9248',
#   '9249',
#   '9254',
#   '9256',
#   '9258',
#   '9262',
#   '9265',
#   '9269',
#   '9270',
#   '9271',
#   '9272',
#   '9276',
#   '9278',
#   '9279',
#   '9285',
#   '9287',
#   '9291',
#   '9294',
#   '9295',
#   '9298',
#   '9299',
#   '9301',
#   '9303',
#   '9304',
#   '9306',
#   '9308',
#   '9309',
#   '9310',
#   '9313',
#   '9314',
#   '9316',
#   '9317',
#   '9320',
#   '9322',
#   '9328',
#   '9330',
#   '9334',
#   '9338',
#   '9339',
#   '9340'],
#  '105864': ['9211', '9240', '9254', '9298', '9340'],
#  '878468': ['9211', '9340'],
#  '1075444': ['9211', '9237', '9241', '9254', '9265', '9298', '9322', '9340'],
#  '1158274': ['9211', '9279'],
#  '1449064': ['9211', '9242', '9254'],
#  '1279037': ['9211',
#   '9228',
#   '9235',
#   '9254',
#   '9256',
#   '9270',
#   '9295',
#   '9310',
#   '9340'],
#  '949243': ['9211', '9340'],
#  '579100': ['9211', '9254', '9340'],
#  '558852': ['9211', '9232', '9234', '9240', '9254', '9292', '9320', '9340'],
#  '1394605': ['9211', '9265', '9340'],
#  '983702': ['9211', '9235', '9278', '9298', '9335'],
#  '1107588': ['9211',
#   '9222',
#   '9238',
#   '9249',
#   '9259',
#   '9262',
#   '9265',
#   '9274',
#   '9294',
#   '9296',
#   '9298',
#   '9309',
#   '9310',
#   '9322',
#   '9324',
#   '9330',
#   '9337',
#   '9340'],
#  '1582190': ['9211'],
#  '826696': ['9211',
#   '9217',
#   '9228',
#   '9229',
#   '9231',
#   '9234',
#   '9235',
#   '9236',
#   '9237',
#   '9241',
#   '9242',
#   '9254',
#   '9256',
#   '9265',
#   '9279',
#   '9298',
#   '9331',
#   '9338'],
#  '1318530': ['9211', '9240', '9254', '9274', '9279', '9295', '9298', '9310'],
#  '924886': ['9211', '9234', '9235', '9254', '9320', '9340'],
#  '2232952': ['9211', '9234', '9340'],
#  '2242346': ['9211',
#   '9235',
#   '9279',
#   '9298',
#   '9309',
#   '9326',
#   '9330',
#   '9331',
#   '9340'],
#  '950079': ['9211', '9229', '9242', '9331'],
#  '2056022': ['9211',
#   '9212',
#   '9217',
#   '9218',
#   '9219',
#   '9220',
#   '9224',
#   '9229',
#   '9231',
#   '9232',
#   '9233',
#   '9234',
#   '9235',
#   '9237',
#   '9238',
#   '9240',
#   '9241',
#   '9242',
#   '9243',
#   '9245',
#   '9246',
#   '9249',
#   '9254',
#   '9255',
#   '9257',
#   '9259',
#   '9265',
#   '9267',
#   '9271',
#   '9272',
#   '9273',
#   '9275',
#   '9276',
#   '9278',
#   '9279',
#   '9280',
#   '9285',
#   '9288',
#   '9290',
#   '9292',
#   '9293',
#   '9295',
#   '9296',
#   '9298',
#   '9304',
#   '9306',
#   '9307',
#   '9309',
#   '9316',
#   '9317',
#   '9319',
#   '9320',
#   '9323',
#   '9327',
#   '9328',
#   '9329',
#   '9330',
#   '9331',
#   '9332',
#   '9333',
#   '9337',
#   '9339',
#   '9340',
#   '9341'],
#  '1660384': ['9211',
#   '9234',
#   '9235',
#   '9240',
#   '9241',
#   '9254',
#   '9261',
#   '9298',
#   '9306',
#   '9326',
#   '9337',
#   '9339',
#   '9340'],
#  '201405': ['9211', '9234', '9235', '9240', '9265', '9340'],
#  '2141091': ['9211'],
#  '1958917': ['9211', '9326'],
#  '478261': ['9211', '9331'],
#  '2529418': ['9211',
#   '9218',
#   '9235',
#   '9241',
#   '9279',
#   '9306',
#   '9320',
#   '9323',
#   '9340'],
#  '1757056': ['9211',
#   '9217',
#   '9222',
#   '9232',
#   '9236',
#   '9240',
#   '9241',
#   '9298',
#   '9326',
#   '9340'],
#  '812125': ['9211', '9232'],
#  '2528285': ['9211', '9331'],
#  '465414': ['9211',
#   '9232',
#   '9234',
#   '9235',
#   '9240',
#   '9254',
#   '9306',
#   '9309',
#   '9326',
#   '9340'],
#  '1793809': ['9211',
#   '9232',
#   '9241',
#   '9242',
#   '9300',
#   '9313',
#   '9326',
#   '9331',
#   '9340'],
#  '2226220': ['9211', '9241', '9242', '9276', '9279', '9298'],
#  '29687': ['9211'],
#  '795658': ['9211', '9232', '9234', '9235', '9270', '9330', '9340'],
#  '1354717': ['9211',
#   '9217',
#   '9218',
#   '9232',
#   '9236',
#   '9237',
#   '9238',
#   '9240',
#   '9254',
#   '9265',
#   '9274',
#   '9279',
#   '9298',
#   '9338'],
#  '374967': ['9211', '9236', '9340'],
#  '411290': ['9211',
#   '9215',
#   '9217',
#   '9223',
#   '9228',
#   '9229',
#   '9236',
#   '9240',
#   '9241',
#   '9242',
#   '9246',
#   '9259',
#   '9260',
#   '9265',
#   '9271',
#   '9279',
#   '9288',
#   '9295',
#   '9298',
#   '9309',
#   '9310',
#   '9314',
#   '9319',
#   '9327',
#   '9329',
#   '9330',
#   '9337',
#   '9340'],
#  '479481': ['9211',
#   '9218',
#   '9241',
#   '9242',
#   '9254',
#   '9256',
#   '9265',
#   '9267',
#   '9298',
#   '9303',
#   '9306',
#   '9326',
#   '9329'],
#  '1221408': ['9211', '9217', '9265', '9340'],
#  '1228644': ['9211', '9234', '9270'],
#  '1447172': ['9211', '9222', '9254'],
#  '415605': ['9211',
#   '9234',
#   '9235',
#   '9240',
#   '9262',
#   '9298',
#   '9320',
#   '9329',
#   '9340'],
#  '2031314': ['9211', '9298', '9327'],
#  '908626': ['9211',
#   '9234',
#   '9241',
#   '9254',
#   '9265',
#   '9282',
#   '9286',
#   '9288',
#   '9319',
#   '9323',
#   '9328',
#   '9330',
#   '9334',
#   '9340'],
#  '1516350': ['9211',
#   '9222',
#   '9223',
#   '9228',
#   '9229',
#   '9234',
#   '9235',
#   '9236',
#   '9237',
#   '9241',
#   '9242',
#   '9254',
#   '9260',
#   '9265',
#   '9276',
#   '9279',
#   '9283',
#   '9295',
#   '9296',
#   '9298',
#   '9306',
#   '9309',
#   '9317',
#   '9323',
#   '9331',
#   '9338',
#   '9340'],
#  '746375': ['9211',
#   '9231',
#   '9265',
#   '9276',
#   '9279',
#   '9288',
#   '9294',
#   '9298',
#   '9330',
#   '9331',
#   '9340'],
#  '1519378': ['9211',
#   '9217',
#   '9218',
#   '9222',
#   '9224',
#   '9229',
#   '9232',
#   '9234',
#   '9235',
#   '9236',
#   '9237',
#   '9240',
#   '9241',
#   '9254',
#   '9256',
#   '9265',
#   '9271',
#   '9274',
#   '9278',
#   '9279',
#   '9292',
#   '9295',
#   '9296',
#   '9298',
#   '9306',
#   '9309',
#   '9314',
#   '9326',
#   '9327',
#   '9339',
#   '9340'],
#  '84737': ['9211', '9340'],
#  '1080875': ['9211', '9229', '9236', '9254', '9265', '9327', '9330', '9340'],
#  '201579': ['9211',
#   '9218',
#   '9241',
#   '9242',
#   '9244',
#   '9251',
#   '9268',
#   '9300',
#   '9317',
#   '9326',
#   '9340'],
#  '2118461': ['9211',
#   '9212',
#   '9214',
#   '9215',
#   '9216',
#   '9217',
#   '9218',
#   '9219',
#   '9220',
#   '9222',
#   '9223',
#   '9224',
#   '9225',
#   '9226',
#   '9227',
#   '9228',
#   '9229',
#   '9230',
#   '9231',
#   '9232',
#   '9233',
#   '9234',
#   '9235',
#   '9236',
#   '9237',
#   '9238',
#   '9239',
#   '9240',
#   '9241',
#   '9242',
#   '9243',
#   '9244',
#   '9246',
#   '9248',
#   '9252',
#   '9253',
#   '9254',
#   '9256',
#   '9257',
#   '9259',
#   '9260',
#   '9261',
#   '9262',
#   '9263',
#   '9264',
#   '9265',
#   '9266',
#   '9267',
#   '9268',
#   '9269',
#   '9270',
#   '9271',
#   '9272',
#   '9274',
#   '9275',
#   '9276',
#   '9277',
#   '9278',
#   '9279',
#   '9280',
#   '9281',
#   '9282',
#   '9283',
#   '9284',
#   '9285',
#   '9286',
#   '9287',
#   '9288',
#   '9289',
#   '9290',
#   '9291',
#   '9292',
#   '9293',
#   '9294',
#   '9295',
#   '9296',
#   '9298',
#   '9299',
#   '9300',
#   '9301',
#   '9302',
#   '9303',
#   '9304',
#   '9305',
#   '9306',
#   '9307',
#   '9308',
#   '9309',
#   '9310',
#   '9311',
#   '9312',
#   '9313',
#   '9314',
#   '9316',
#   '9317',
#   '9318',
#   '9319',
#   '9320',
#   '9321',
#   '9322',
#   '9323',
#   '9325',
#   '9326',
#   '9327',
#   '9328',
#   '9329',
#   '9330',
#   '9331',
#   '9332',
#   '9333',
#   '9334',
#   '9335',
#   '9337',
#   '9338',
#   '9339',
#   '9340',
#   '9341',
#   '9342'],
#  '2636145': ['9211',
#   '9241',
#   '9242',
#   '9254',
#   '9278',
#   '9295',
#   '9298',
#   '9306',
#   '9340'],
#  '98300': ['9211', '9231', '9236', '9254', '9260', '9265'],
#  '2412878': ['9211',
#   '9224',
#   '9229',
#   '9230',
#   '9235',
#   '9240',
#   '9254',
#   '9262',
#   '9265',
#   '9298',
#   '9309',
#   '9327',
#   '9340'],
#  '1860304': ['9211', '9294', '9340'],
#  '2598035': ['9211', '9234', '9235', '9254', '9265', '9271', '9298', '9320'],
#  '2593295': ['9211', '9231', '9235', '9236', '9241', '9298', '9314'],
#  '2061495': ['9211',
#   '9218',
#   '9223',
#   '9224',
#   '9229',
#   '9232',
#   '9234',
#   '9235',
#   '9240',
#   '9241',
#   '9254',
#   '9259',
#   '9265',
#   '9267',
#   '9272',
#   '9279',
#   '9283',
#   '9294',
#   '9295',
#   '9298',
#   '9310',
#   '9314',
#   '9317',
#   '9320',
#   '9329',
#   '9330',
#   '9335',
#   '9338',
#   '9340',
#   '9341'],
#  '2179594': ['9211',
#   '9218',
#   '9238',
#   '9241',
#   '9242',
#   '9256',
#   '9257',
#   '9265',
#   '9268',
#   '9270',
#   '9290',
#   '9331',
#   '9340'],
#  '1548363': ['9211',
#   '9229',
#   '9235',
#   '9237',
#   '9241',
#   '9242',
#   '9246',
#   '9254',
#   '9256',
#   '9259',
#   '9265',
#   '9270',
#   '9272',
#   '9279',
#   '9285',
#   '9293',
#   '9296',
#   '9298',
#   '9309',
#   '9322',
#   '9327',
#   '9337',
#   '9340'],
#  '74501': ['9211', '9340'],
#  '1460630': ['9211',
#   '9217',
#   '9232',
#   '9240',
#   '9242',
#   '9254',
#   '9257',
#   '9279',
#   '9295',
#   '9298',
#   '9309',
#   '9316',
#   '9340'],
#  '2254751': ['9211',
#   '9217',
#   '9223',
#   '9224',
#   '9231',
#   '9234',
#   '9235',
#   '9240',
#   '9241',
#   '9242',
#   '9254',
#   '9256',
#   '9276',
#   '9278',
#   '9279',
#   '9289',
#   '9298',
#   '9309',
#   '9316',
#   '9330',
#   '9339',
#   '9340'],
#  '387418': ['9211',
#   '9212',
#   '9213',
#   '9214',
#   '9215',
#   '9216',
#   '9217',
#   '9218',
#   '9219',
#   '9220',
#   '9221',
#   '9222',
#   '9223',
#   '9224',
#   '9225',
#   '9226',
#   '9227',
#   '9228',
#   '9229',
#   '9230',
#   '9231',
#   '9232',
#   '9233',
#   '9234',
#   '9235',
#   '9236',
#   '9237',
#   '9238',
#   '9239',
#   '9240',
#   '9241',
#   '9242',
#   '9243',
#   '9244',
#   '9245',
#   '9246',
#   '9247',
#   '9248',
#   '9249',
#   '9251',
#   '9252',
#   '9253',
#   '9254',
#   '9255',
#   '9256',
#   '9257',
#   '9258',
#   '9259',
#   '9260',
#   '9261',
#   '9262',
#   '9263',
#   '9264',
#   '9265',
#   '9266',
#   '9267',
#   '9268',
#   '9269',
#   '9270',
#   '9271',
#   '9272',
#   '9273',
#   '9274',
#   '9275',
#   '9276',
#   '9277',
#   '9278',
#   '9279',
#   '9280',
#   '9281',
#   '9282',
#   '9283',
#   '9284',
#   '9285',
#   '9286',
#   '9287',
#   '9288',
#   '9289',
#   '9290',
#   '9291',
#   '9292',
#   '9293',
#   '9294',
#   '9295',
#   '9296',
#   '9297',
#   '9298',
#   '9299',
#   '9300',
#   '9301',
#   '9302',
#   '9303',
#   '9304',
#   '9305',
#   '9306',
#   '9307',
#   '9308',
#   '9309',
#   '9310',
#   '9311',
#   '9312',
#   '9313',
#   '9314',
#   '9315',
#   '9316',
#   '9317',
#   '9318',
#   '9319',
#   '9320',
#   '9321',
#   '9322',
#   '9323',
#   '9324',
#   '9325',
#   '9326',
#   '9327',
#   '9328',
#   '9329',
#   '9330',
#   '9331',
#   '9332',
#   '9333',
#   '9334',
#   '9335',
#   '9336',
#   '9337',
#   '9338',
#   '9339',
#   '9340',
#   '9341',
#   '9342'],
#  '721443': ['9211', '9229', '9242', '9257', '9319', '9332'],
#  '1607539': ['9211', '9235', '9265', '9279', '9298', '9340'],
#  '853156': ['9211', '9340'],
#  '1121618': ['9211', '9331'],
#  '2508312': ['9211',
#   '9221',
#   '9228',
#   '9229',
#   '9234',
#   '9240',
#   '9254',
#   '9269',
#   '9276',
#   '9278',
#   '9279',
#   '9288',
#   '9309',
#   '9316',
#   '9322',
#   '9330',
#   '9339',
#   '9340'],
#  '1382559': ['9211', '9298', '9323'],
#  '2085318': ['9211', '9340'],
#  '2503236': ['9211', '9218', '9265', '9340'],
#  '1114324': ['9211',
#   '9215',
#   '9217',
#   '9218',
#   '9222',
#   '9223',
#   '9224',
#   '9225',
#   '9229',
#   '9230',
#   '9232',
#   '9233',
#   '9234',
#   '9235',
#   '9236',
#   '9238',
#   '9239',
#   '9240',
#   '9241',
#   '9242',
#   '9245',
#   '9246',
#   '9249',
#   '9251',
#   '9254',
#   '9259',
#   '9260',
#   '9262',
#   '9264',
#   '9265',
#   '9267',
#   '9268',
#   '9270',
#   '9271',
#   '9273',
#   '9274',
#   '9275',
#   '9276',
#   '9278',
#   '9279',
#   '9282',
#   '9283',
#   '9285',
#   '9286',
#   '9287',
#   '9288',
#   '9292',
#   '9295',
#   '9298',
#   '9303',
#   '9304',
#   '9306',
#   '9308',
#   '9309',
#   '9312',
#   '9313',
#   '9314',
#   '9315',
#   '9316',
#   '9318',
#   '9319',
#   '9320',
#   '9323',
#   '9326',
#   '9330',
#   '9333',
#   '9334',
#   '9337',
#   '9338',
#   '9339',
#   '9340',
#   '9341'],
#  '930061': ['9211', '9235', '9254', '9295', '9298', '9310', '9340'],
#  '1306863': ['9211', '9274', '9332'],
#  '2158527': ['9211',
#   '9240',
#   '9242',
#   '9279',
#   '9309',
#   '9320',
#   '9330',
#   '9334',
#   '9340'],
#  '2077456': ['9211', '9340'],
#  '340968': ['9211', '9254'],
#  '1945029': ['9211', '9231', '9242', '9254', '9303', '9317', '9326', '9340'],
#  '873478': ['9211',
#   '9212',
#   '9217',
#   '9218',
#   '9224',
#   '9231',
#   '9238',
#   '9240',
#   '9265',
#   '9290',
#   '9324',
#   '9332',
#   '9340'],
#  '2107068': ['9211',
#   '9218',
#   '9222',
#   '9224',
#   '9229',
#   '9235',
#   '9240',
#   '9246',
#   '9254',
#   '9262',
#   '9265',
#   '9270',
#   '9279',
#   '9298',
#   '9303',
#   '9306',
#   '9320',
#   '9323',
#   '9329',
#   '9334',
#   '9338',
#   '9339',
#   '9340'],
#  '581089': ['9211'],
#  '772337': ['9211',
#   '9218',
#   '9235',
#   '9238',
#   '9254',
#   '9265',
#   '9278',
#   '9298',
#   '9300',
#   '9306',
#   '9326',
#   '9340'],
#  '2619337': ['9211', '9235', '9236', '9265', '9288', '9298', '9340'],
#  '2305283': ['9211', '9340'],
#  '1321549': ['9211', '9265', '9330', '9340'],
#  '756162': ['9211',
#   '9217',
#   '9224',
#   '9229',
#   '9231',
#   '9240',
#   '9241',
#   '9254',
#   '9256',
#   '9265',
#   '9272',
#   '9298',
#   '9309',
#   '9326',
#   '9331'],
#  '2356240': ['9211', '9242'],
#  '2364743': ['9211', '9231', '9256', '9276', '9340'],
#  '909164': ['9211', '9229', '9236', '9246', '9254', '9265', '9331', '9340'],
#  '2572690': ['9211',
#   '9224',
#   '9235',
#   '9238',
#   '9265',
#   '9269',
#   '9276',
#   '9298',
#   '9340'],
#  '1028541': ['9211',
#   '9235',
#   '9240',
#   '9242',
#   '9254',
#   '9265',
#   '9279',
#   '9298',
#   '9327'],
#  '1843888': ['9211', '9331', '9340'],
#  '74273': ['9211', '9254', '9340'],
#  '1436116': ['9211', '9234', '9254', '9265'],
#  '1369362': ['9211', '9254'],
#  '1950312': ['9211', '9224', '9235', '9329', '9340'],
#  '673305': ['9211', '9231', '9241', '9263', '9331'],
#  '1093270': ['9211', '9216', '9241', '9256', '9270', '9309', '9310', '9327'],
#  '1674535': ['9211',
#   '9229',
#   '9232',
#   '9235',
#   '9241',
#   '9276',
#   '9279',
#   '9320',
#   '9340'],
#  '462444': ['9211', '9228', '9254', '9265', '9295'],
#  '1334775': ['9211', '9254', '9279', '9289', '9296', '9298', '9340'],
#  '1109887': ['9211', '9319', '9340'],
# ...
#   '9232',
#   '9234',
#   '9240',
#   '9254',
#   '9262',
#   '9274',
#   '9314',
#   '9337',
#   '9340'],
#  '2398923': ['9212',
#   '9217',
#   '9229',
#   '9232',
#   '9236',
#   '9254',
#   '9257',
#   '9260',
#   '9265',
#   '9270',
#   '9271',
#   '9278',
#   '9280',
#   '9296',
#   '9298',
#   '9304',
#   '9308',
#   '9322',
#   '9323',
#   '9340'],
#  '1385788': ['9212',
#   '9217',
#   '9229',
#   '9234',
#   '9235',
#   '9236',
#   '9254',
#   '9260',
#   '9265',
#   '9268',
#   '9279',
#   '9280',
#   '9296',
#   '9298',
#   '9319',
#   '9320',
#   '9322',
#   '9324',
#   '9330',
#   '9340',
#   '0'],
#  '2432155': ['9212', '9237', '9265', '9285', '9296', '9320', '9327', '9329'],
#  '2011258': ['9212',
#   '9222',
#   '9232',
#   '9233',
#   '9234',
#   '9235',
#   '9237',
#   '9240',
#   '9254',
#   '9265',
#   '9267',
#   '9274',
#   '9288',
#   '9303',
#   '9320',
#   '9323',
#   '9329',
#   '9340'],
#  '204177': ['9212', '9254', '9296', '9299'],
#  '2483851': ['9212', '9254', '9265', '9298'],
#  '1542686': ['9212'],
#  '1660196': ['9212', '9254', '9288', '9340'],
#  '404854': ['9212', '9296'],
#  '443572': ['9212',
#   '9234',
#   '9235',
#   '9237',
#   '9254',
#   '9257',
#   '9265',
#   '9276',
#   '9320',
#   '9340'],
#  '28258': ['9212', '9236', '9254', '9265', '9340'],
#  '1995832': ['9212',
#   '9217',
#   '9229',
#   '9234',
#   '9254',
#   '9265',
#   '9294',
#   '9295',
#   '9298'],
#  '120762': ['9212', '9340'],
#  '580145': ['9212', '9223', '9231', '9295'],
#  '1905560': ['9212', '9236', '9297', '9299', '9321'],
#  '2368807': ['9212', '9340'],
#  '579917': ['9212', '9255'],
#  '1724818': ['9212',
#   '9217',
#   '9234',
#   '9240',
#   '9254',
#   '9265',
#   '9288',
#   '9296',
#   '9298',
#   '9299',
#   '9327',
#   '9330'],
#  '1997148': ['9212', '9295', '9298', '9314', '9338'],
#  '775171': ['9212',
#   '9222',
#   '9234',
#   '9235',
#   '9240',
#   '9254',
#   '9288',
#   '9298',
#   '9320',
#   '9330',
#   '9340',
#   '0'],
#  '440964': ['9212'],
#  '1263008': ['9212',
#   '9223',
#   '9224',
#   '9234',
#   '9235',
#   '9236',
#   '9240',
#   '9254',
#   '9265',
#   '9320',
#   '9326',
#   '9340'],
#  '1413633': ['9212', '9234', '9254', '9296', '9320', '9327'],
#  '1954678': ['9212', '9331'],
#  '1928961': ['9212', '9232', '9236', '9254', '9265', '9326'],
#  '741977': ['9212', '9265', '9298'],
#  '1015048': ['9212',
#   '9229',
#   '9236',
#   '9237',
#   '9240',
#   '9254',
#   '9262',
#   '9265',
#   '9271',
#   '9298',
#   '9304',
#   '9306',
#   '9326'],
#  '2505164': ['9212', '9254'],
#  '1860768': ['9212', '9240', '9254', '9265', '9274', '9306', '9340'],
#  '2588759': ['9212', '9297'],
#  '958657': ['9212', '9281'],
#  '1753736': ['9212', '9292', '9321', '9340'],
#  '1067376': ['9212',
#   '9218',
#   '9235',
#   '9240',
#   '9254',
#   '9295',
#   '9298',
#   '9309',
#   '9323'],
#  '1740987': ['9212',
#   '9217',
#   '9224',
#   '9229',
#   '9236',
#   '9254',
#   '9265',
#   '9296',
#   '9298',
#   '9320',
#   '9337',
#   '9340'],
#  '1752657': ['9212'],
#  '2453959': ['9212', '9251', '9326'],
#  '1640354': ['9212', '9236', '9296'],
#  '41893': ['9212'],
#  '2436585': ['9212', '9232', '9254', '9340'],
#  '801884': ['9212', '9224', '9232', '9235', '9340'],
#  '1943141': ['9212', '9258', '9270', '9277', '9303', '9309', '9330', '9340'],
#  '81700': ['9212', '9298'],
#  '2610745': ['9212', '9254'],
#  '74175': ['9212',
#   '9222',
#   '9234',
#   '9235',
#   '9254',
#   '9262',
#   '9265',
#   '9271',
#   '9320',
#   '9329',
#   '9340'],
#  '529545': ['9212', '9232', '9246', '9274', '9337'],
#  '588285': ['9212',
#   '9216',
#   '9224',
#   '9232',
#   '9248',
#   '9254',
#   '9276',
#   '9281',
#   '9291',
#   '9293',
#   '9296',
#   '9307',
#   '9317',
#   '9328',
#   '9329',
#   '9331'],
#  '655818': ['9212', '9237', '9238', '9254', '9265', '9340'],
#  '1421916': ['9212'],
#  '2209307': ['9212', '9236', '9254', '9327'],
#  '1573738': ['9212'],
#  '2359767': ['9212', '9234', '9235', '9254', '9265', '9288', '9320', '9340'],
#  '129975': ['9212', '9254', '9340'],
#  '2552319': ['9212',
#   '9223',
#   '9231',
#   '9254',
#   '9257',
#   '9270',
#   '9274',
#   '9285',
#   '9291',
#   '9296',
#   '9305',
#   '9307',
#   '9317',
#   '9319',
#   '9320',
#   '9327',
#   '9332',
#   '9340'],
#  '540307': ['9212', '9236', '9254', '9298', '9340'],
#  '1812408': ['9212'],
#  '2332659': ['9212', '9241', '9292'],
#  '2083367': ['9212',
#   '9217',
#   '9223',
#   '9229',
#   '9232',
#   '9233',
#   '9234',
#   '9235',
#   '9239',
#   '9241',
#   '9242',
#   '9244',
#   '9253',
#   '9255',
#   '9257',
#   '9258',
#   '9264',
#   '9265',
#   '9269',
#   '9279',
#   '9285',
#   '9288',
#   '9294',
#   '9298',
#   '9299',
#   '9303',
#   '9304',
#   '9308',
#   '9313',
#   '9315',
#   '9316',
#   '9320',
#   '9321',
#   '9322',
#   '9330',
#   '9331',
#   '9340',
#   '9342',
#   '0'],
#  '1572525': ['9212', '9232', '9234', '9254', '9265', '9296', '9298', '9320'],
#  '33074': ['9212', '9254', '9340'],
#  '2212128': ['9212'],
#  '1447381': ['9212',
#   '9229',
#   '9235',
#   '9237',
#   '9265',
#   '9285',
#   '9288',
#   '9298',
#   '9320',
#   '9330',
#   '9340'],
#  '964881': ['9212', '9321'],
#  '1302673': ['9212', '9229', '9296', '9298', '9321'],
#  '477988': ['9212', '9217', '9224', '9236', '9254', '9265', '9340'],
#  '1960595': ['9212'],
#  '400674': ['9212'],
#  '1418443': ['9212'],
#  '477923': ['9212', '9236', '9271', '9296', '9298', '9321', '9338'],
#  '2640853': ['9212', '9254'],
#  '1094381': ['9212'],
#  '1998723': ['9212', '9234', '9237', '9254', '9298', '9340'],
#  '1531183': ['9212'],
#  '346036': ['9212', '9232'],
#  '1643021': ['9212', '9254'],
#  '818416': ['9212',
#   '9234',
#   '9254',
#   '9265',
#   '9294',
#   '9295',
#   '9296',
#   '9311',
#   '9320',
#   '9321',
#   '9330',
#   '9340'],
#  '506953': ['9212',
#   '9229',
#   '9236',
#   '9254',
#   '9265',
#   '9279',
#   '9298',
#   '9309',
#   '9340'],
#  '2597667': ['9212', '9254'],
#  '1101797': ['9212', '9226'],
#  '1758606': ['9212', '9223', '9224', '9298', '9321', '9340'],
#  '835473': ['9212',
#   '9228',
#   '9236',
#   '9254',
#   '9288',
#   '9296',
#   '9310',
#   '9330',
#   '9340'],
#  '1497593': ['9212', '9232', '9234', '9235', '9274', '9321', '9340'],
#  '2632722': ['9212', '9217', '9254', '9296', '9340'],
#  '2126441': ['9212', '9254', '9340'],
#  '2227665': ['9212'],
#  '614402': ['9212'],
#  '1804473': ['9212'],
#  '784914': ['9212', '9340'],
#  '1317690': ['9212', '9340'],
#  '908882': ['9212', '9254', '9340'],
#  '1403167': ['9212'],
#  '1665204': ['9212', '9327', '9340'],
#  '1642678': ['9212',
#   '9217',
#   '9224',
#   '9231',
#   '9232',
#   '9242',
#   '9254',
#   '9262',
#   '9265',
#   '9279',
#   '9292',
#   '9298',
#   '9320',
#   '9323',
#   '9327',
#   '9329',
#   '9330',
#   '9340'],
#  '1683604': ['9212', '9240', '9242', '9254', '9274', '9320', '9340'],
#  '507094': ['9212',
#   '9217',
#   '9218',
#   '9223',
#   '9230',
#   '9233',
#   '9235',
#   '9236',
#   '9237',
#   '9246',
#   '9247',
#   '9254',
#   '9262',
#   '9265',
#   '9274',
#   '9288',
#   '9294',
#   '9295',
#   '9296',
#   '9298',
#   '9304',
#   '9314',
#   '9320',
#   '9323',
#   '9330',
#   '9334',
#   '9338'],
#  '1905364': ['9212', '9297', '9321'],
#  '2124728': ['9212'],
#  '2635011': ['9212',
#   '9234',
#   '9235',
#   '9237',
#   '9254',
#   '9265',
#   '9288',
#   '9320',
#   '9329',
#   '9340'],
#  '1798940': ['9212', '9280', '9327'],
#  '806605': ['9212',
#   '9217',
#   '9218',
#   '9236',
#   '9240',
#   '9254',
#   '9274',
#   '9279',
#   '9294',
#   '9296',
#   '9298',
#   '9316',
#   '9321',
#   '9322',
#   '9330',
#   '9331',
#   '9339',
#   '9340'],
#  '2111332': ['9212', '9234', '9242', '9254', '9265', '9280', '9298', '9340'],
#  '688997': ['9212', '9340'],
#  '2211241': ['9212'],
#  '382989': ['9212', '9236'],
#  '1476270': ['9212', '9237', '9254', '9298'],
#  '862596': ['9212',
#   '9215',
#   '9217',
#   '9229',
#   '9231',
#   '9232',
#   '9233',
#   '9234',
#   '9235',
#   '9236',
#   '9237',
#   '9248',
#   '9254',
#   '9262',
#   '9265',
#   '9271',
#   '9274',
#   '9277',
#   '9281',
#   '9288',
#   '9296',
#   '9298',
#   '9301',
#   '9307',
#   '9319',
#   '9320',
#   '9326',
#   '9329',
#   '9340'],
#  '2414326': ['9212', '9255', '9298', '9303', '9327'],
#  '1035723': ['9212', '9235', '9254', '9323', '9340'],
#  '2488021': ['9212', '9330', '9340'],
#  '630964': ['9212',
#   '9232',
#   '9234',
#   '9235',
#   '9236',
#   '9254',
#   '9265',
#   '9296',
#   '9298',
#   '9299',
#   '9331',
#   '9340'],
#  '1628597': ['9212', '9234', '9240', '9254', '9265'],
#  '307612': ['9212', '9254', '9320', '9323', '9340'],
#  '2429098': ['9212',
#   '9234',
#   '9246',
#   '9254',
#   '9274',
#   '9278',
#   '9320',
#   '9323',
#   '9326',
#   '9340'],
#  '1996307': ['9212',
#   '9218',
#   '9231',
#   '9237',
#   '9242',
#   '9254',
#   '9265',
#   '9298',
#   '9329',
#   '9340'],
#  '1075147': ['9212', '9340'],
#  '1197905': ['9212'],
#  '590547': ['9212', '9254'],
#  '2409499': ['9212', '9254', '9340'],
#  '1968862': ['9212',
#   '9224',
#   '9229',
#   '9234',
#   '9235',
#   '9240',
#   '9254',
#   '9262',
#   '9298',
#   '9340'],
#  '2519958': ['9212'],
#  '2175395': ['9212', '9232', '9340'],
#  '2479857': ['9212',
#   '9224',
#   '9234',
#   '9237',
#   '9246',
#   '9254',
#   '9265',
#   '9279',
#   '9298',
#   '9340'],
#  '1284686': ['9212', '9340'],
#  '1677818': ['9212', '9320', '9340'],
#  '14164': ['9212',
#   '9224',
#   '9232',
#   '9234',
#   '9235',
#   '9236',
#   '9237',
#   '9254',
#   '9265',
#   '9274',
#   '9298',
#   '9329',
#   '9340',
#   '0'],
#  '1435891': ['9212',
#   '9217',
#   '9224',
#   '9229',
#   '9233',
#   '9254',
#   '9265',
#   '9279',
#   '9288',
#   '9294',
#   '9296',
#   '9298',
#   '9330'],
#  '2467784': ['9212',
#   '9222',
#   '9224',
#   '9229',
#   '9232',
#   '9236',
#   '9242',
#   '9254',
#   '9265',
#   '9274',
#   '9283',
#   '9293',
#   '9298',
#   '9326',
#   '9327',
#   '9329',
#   '9339',
#   '9340'],
#  '1552059': ['9212', '9237', '9298'],
#  '648585': ['9212', '9236', '9243', '9254', '9255', '9296', '9331'],
#  '1921661': ['9212', '9254', '9326', '9340'],
#  '970269': ['9212', '9232', '9236', '9242', '9254', '9321', '9340'],
#  '2051139': ['9212'],
#  '160449': ['9212',
#   '9236',
#   '9242',
#   '9254',
#   '9265',
#   '9298',
#   '9303',
#   '9306',
#   '9334'],
#  '1474258': ['9212'],
#  '2438256': ['9212', '9237', '9254', '9265', '9329', '9340'],
#  '2430907': ['9212', '9236', '9260', '9274', '9296', '9322', '9327'],
#  '505171': ['9212',
#   '9228',
#   '9232',
#   '9236',
#   '9254',
#   '9260',
#   '9265',
#   '9276',
#   '9298',
#   '9320',
#   '9327',
#   '9340'],
#  '691722': ['9212', '9340'],
#  '1854658': ['9212',
#   '9234',
#   '9235',
#   '9236',
#   '9237',
#   '9246',
#   '9254',
#   '9262',
#   '9265',
#   '9271',
#   '9274',
#   '9278',
#   '9285',
#   '9298',
#   '9303',
#   '9320',
#   '9323',
#   '9327',
#   '9329',
#   '9338',
#   '9340'],
#  '2366024': ['9212', '9236', '9254'],
#  '66417': ['9212', '9340'],
#  '2216966': ['9212', '9296', '9340'],
#  '1678750': ['9212', '9254'],
#  '1319554': ['9212', '9229', '9240', '9265'],
#  '2137979': ['9212', '9232', '9234'],
#  '2395915': ['9212', '9234', '9236', '9237', '9254', '9327'],
#  '1650584': ['9212'],
#  '332627': ['9212',
#   '9224',
#   '9231',
#   '9236',
#   '9243',
#   '9274',
#   '9279',
#   '9298',
#   '9326',
#   '9340',
#   '9342'],
#  '1298511': ['9212',
#   '9213',
#   '9216',
#   '9217',
#   '9218',
#   '9223',
#   '9224',
#   '9228',
#   '9229',
#   '9233',
#   '9234',
#   '9235',
#   '9236',
#   '9237',
#   '9240',
#   '9242',
#   '9253',
#   '9254',
#   '9258',
#   '9270',
#   '9272',
#   '9274',
#   '9276',
#   '9278',
#   '9279',
#   '9294',
#   '9295',
#   '9299',
#   '9303',
#   '9309',
#   '9310',
#   '9317',
#   '9319',
#   '9321',
#   '9322',
#   '9323',
#   '9328',
#   '9330',
#   '9340',
#   '0'],
#  '533713': ['9212', '9254', '9288', '9296', '9321', '9330', '9340'],
#  '1896666': ['9212', '9340'],
#  '1629440': ['9212',
#   '9234',
#   '9235',
#   '9236',
#   '9240',
#   '9254',
#   '9260',
#   '9265',
#   '9271',
#   '9274',
#   '9279',
#   '9280',
#   '9285',
#   '9288',
#   '9294',
#   '9296',
#   '9298',
#   '9304',
#   '9308',
#   '9320',
#   '9327',
#   '9329',
#   '9330',
#   '9340'],
#  '744458': ['9212', '9296'],
#  '711215': ['9212', '9340'],
#  '757582': ['9212', '9254', '9296', '9340'],
#  '2006011': ['9212', '9254', '9274', '9320'],
#  '60343': ['9212'],
#  '722222': ['9212'],
#  '532323': ['9212'],
#  '1776917': ['9212', '9274'],
#  '860716': ['9212', '9254'],
#  '1935793': ['9212',
#   '9223',
#   '9224',
#   '9228',
#   '9231',
#   '9232',
#   '9233',
#   '9238',
#   '9240',
#   '9241',
#   '9242',
#   '9253',
#   '9254',
#   '9255',
#   '9274',
#   '9279',
#   '9283',
#   '9288',
#   '9290',
#   '9292',
#   '9295',
#   '9298',
#   '9307',
#   '9309',
#   '9310',
#   '9314',
#   '9319',
#   '9328',
#   '9330',
#   '9334',
#   '9340'],
#  '2517727': ['9212', '9265', '9326'],
#  '1095761': ['9212', '9234', '9235', '9254', '9340'],
#  '1110254': ['9212', '9224', '9327'],
#  '21377': ['9212', '9224', '9254'],
#  '1773601': ['9212', '9254'],
#  '1764017': ['9212'],
#  '354296': ['9212'],
#  '262611': ['9212', '9265', '9340'],
#  '2487779': ['9212', '9242', '9279', '9296'],
#  '1399457': ['9212',
#   '9237',
#   '9254',
#   '9296',
#   '9297',
#   '9298',
#   '9304',
#   '9337',
#   '9338'],
#  '299601': ['9212', '9234', '9237', '9254', '9265', '9340'],
#  '1029847': ['9212', '9232', '9254', '9320'],
#  '1144332': ['9212', '9254', '9265'],
#  '2462852': ['9212'],
#  '545664': ['9212', '9279'],
#  '2055928': ['9212', '9242', '9254', '9298', '9340'],
#  '78595': ['9212', '9309'],
#  '1608091': ['9212', '9217', '9232', '9236', '9254', '9298', '9340'],
#  '104462': ['9212',
#   '9228',
#   '9235',
#   '9265',
#   '9279',
#   '9295',
#   '9322',
#   '9329',
#   '9340'],
#  '1882078': ['9212', '9234', '9254', '9320', '9327'],
#  '472334': ['9212', '9254', '9340'],
#  '384107': ['9212'],
#  '2356782': ['9212', '9296', '9340'],
#  '2586121': ['9212', '9232', '9236', '9242', '9265', '9340', '9342'],
#  '1361279': ['9212', '9258', '9288'],
#  '1491102': ['9212', '9234', '9235', '9254', '9265', '9279', '9298', '9340'],
#  '1276071': ['9212'],
#  '1860383': ['9212', '9224', '9236', '9296', '9320', '9321', '9340'],
#  '236043': ['9212', '9254', '9298', '9340'],
#  '2194471': ['9212', '9297'],
#  '1709867': ['9212'],
#  '1730533': ['9212', '9254', '9274', '9340'],
#  '1232892': ['9212', '9296'],
#  '196062': ['9212',
#   '9224',
#   '9246',
#   '9254',
#   '9265',
#   '9274',
#   '9296',
#   '9298',
#   '9330'],
#  '1179373': ['9212', '9222', '9233', '9288', '9298', '9313'],
#  '2534061': ['9212',
#   '9213',
#   '9217',
#   '9224',
#   '9234',
#   '9236',
#   '9237',
#   '9254',
#   '9265',
#   '9274',
#   '9285',
#   '9288',
#   '9294',
#   '9299',
#   '9320',
#   '9321',
#   '9322',
#   '9323',
#   '9326',
#   '9330',
#   '9331',
#   '9340',
#   '0'],
#  '1857889': ['9212',
#   '9229',
#   '9232',
#   '9234',
#   '9236',
#   '9254',
#   '9265',
#   '9280',
#   '9296',
#   '9299',
#   '9319',
#   '9326',
#   '9327',
#   '9340'],
#  '1666213': ['9212',
#   '9235',
#   '9254',
#   '9265',
#   '9288',
#   '9298',
#   '9303',
#   '9320',
#   '9330',
#   '9340'],
#  '989264': ['9212', '9236', '9288', '9296', '9340'],
#  '1193715': ['9212', '9254', '9265', '9340'],
#  '2528497': ['9212'],
#  '1242854': ['9212', '9224', '9234', '9235', '9254', '9323'],
#  '182134': ['9212',
#   '9236',
#   '9237',
#   '9246',
#   '9254',
#   '9296',
#   '9322',
#   '9327',
#   '9330'],
#  '1446054': ['9212',
#   '9217',
#   '9234',
#   '9254',
#   '9265',
#   '9285',
#   '9296',
#   '9327',
#   '9337',
#   '9340'],
#  '2367141': ['9212', '9235', '9265', '9274', '9327', '9340'],
#  '1858927': ['9212', '9234', '9254', '9265', '9296', '9298', '9320', '9340'],
#  '455984': ['9212', '9224', '9298'],
#  '454204': ['9212'],
#  '90682': ['9212',
#   '9234',
#   '9235',
#   '9240',
#   '9254',
#   '9265',
#   '9288',
#   '9298',
#   '9329',
#   '9340'],
#  '1181795': ['9212'],
#  '2606799': ['9212',
#   '9215',
#   '9217',
#   '9219',
#   '9220',
#   '9221',
#   '9222',
#   '9223',
#   '9224',
#   '9225',
#   '9229',
#   '9230',
#   '9231',
#   '9232',
#   '9233',
#   '9234',
#   '9235',
#   '9236',
#   '9237',
#   '9239',
#   '9240',
#   '9241',
#   '9242',
#   '9245',
#   '9246',
#   '9247',
#   '9254',
#   '9257',
#   '9262',
#   '9264',
#   '9265',
#   '9269',
#   '9270',
#   '9271',
#   '9273',
#   '9274',
#   '9276',
#   '9277',
#   '9279',
#   '9280',
#   '9282',
#   '9283',
#   '9285',
#   '9286',
#   '9288',
#   '9289',
#   '9290',
#   '9292',
#   '9293',
#   '9294',
#   '9295',
#   '9296',
#   '9298',
#   '9306',
#   '9307',
#   '9309',
#   '9313',
#   '9319',
#   '9320',
#   '9321',
#   '9322',
#   '9323',
#   '9327',
#   '9329',
#   '9330',
#   '9335',
#   '9338',
#   '9340'],
#  '1438031': ['9212',
#   '9234',
#   '9235',
#   '9254',
#   '9265',
#   '9285',
#   '9292',
#   '9320',
#   '9329',
#   '9337',
#   '9340'],
#  '2248476': ['9212', '9340'],
#  '1536218': ['9212'],
#  '106870': ['9212',
#   '9217',
#   '9234',
#   '9254',
#   '9260',
#   '9262',
#   '9298',
#   '9330',
#   '9340'],
#  '1787038': ['9212', '9236', '9254', '9298', '9340'],
#  '539278': ['9212'],
#  '2468178': ['9212', '9254'],
#  '1514430': ['9212'],
#  '1123387': ['9212', '9234', '9307'],
#  '1204448': ['9212', '9296'],
#  '2319768': ['9212', '9265'],
#  '482904': ['9212', '9340'],
#  '2559537': ['9212',
#   '9223',
#   '9224',
#   '9229',
#   '9234',
#   '9235',
#   '9265',
#   '9283',
#   '9314',
#   '9319',
#   '9327',
#   '9329'],
#  '707095': ['9212', '9254', '9324'],
#  '1347966': ['9212'],
#  '749593': ['9212', '9234', '9254', '9265', '9297', '9320', '9340'],
#  '924687': ['9212', '9340'],
#  '2409183': ['9212', '9340'],
#  ...}

# %%
item_names
# Out:
# {'1': 'Dinosaur Planet',
#  '2': 'Isle of Man TT 2004 Review',
#  '3': 'Character',
#  '4': "Paula Abdul's Get Up & Dance",
#  '5': 'The Rise and Fall of ECW',
#  '6': 'Sick',
#  '7': '8 Man',
#  '8': 'What the #$*! Do We Know!?',
#  '9': "Class of Nuke 'Em High 2",
#  '10': 'Fighter',
#  '11': 'Full Frame: Documentary Shorts',
#  '12': 'My Favorite Brunette',
#  '13': 'Lord of the Rings: The Return of the King: Extended Edition: Bonus Material',
#  '14': 'Nature: Antarctica',
#  '15': 'Neil Diamond: Greatest Hits Live',
#  '16': 'Screamers',
#  '17': '7 Seconds',
#  '18': 'Immortal Beloved',
#  '19': "By Dawn's Early Light",
#  '20': 'Seeta Aur Geeta',
#  '21': 'Strange Relations',
#  '22': 'Chump Change',
#  '23': "Clifford: Clifford Saves the Day! / Clifford's Fluffiest Friend Cleo",
#  '24': 'My Bloody Valentine',
#  '25': 'Inspector Morse 31: Death Is Now My Neighbour',
#  '26': 'Never Die Alone',
#  '27': "Sesame Street: Elmo's World: The Street We Live On",
#  '28': 'Lilo and Stitch',
#  '29': 'Boycott',
#  '30': "Something's Gotta Give",
#  '31': 'Classic Albums: Meat Loaf: Bat Out of Hell',
#  '32': "ABC Primetime: Mel Gibson's The Passion of the Christ",
#  '33': 'Aqua Teen Hunger Force: Vol. 1',
#  '34': "Ashtanga Yoga: Beginner's Practice with Nicki Doane",
#  '35': 'Ferngully 2: The Magical Rescue',
#  '36': 'Lady Chatterley',
#  '37': "Zatoichi's Conspiracy",
#  '38': 'Daydream Obsession',
#  '39': 'Love Reinvented',
#  '40': 'Pitcher and the Pin-Up',
#  '41': 'Horror Vision',
#  '42': 'Searching for Paradise',
#  '43': 'Silent Service',
#  '44': 'Spitfire Grill',
#  '45': 'The Love Letter',
#  '46': 'Rudolph the Red-Nosed Reindeer',
#  '47': 'The Bad and the Beautiful',
#  '48': 'Justice League',
#  '49': 'Devo: The Complete Truth About De-evolution',
#  '50': 'A Yank in the R.A.F.',
#  '51': 'Jonah: A VeggieTales Movie: Bonus Material',
#  '52': 'The Weather Underground',
#  '53': 'The Bonesetter',
#  '54': "We're Not Married",
#  '55': 'Jade',
#  '56': 'Carandiru',
#  '57': 'Richard III',
#  '58': 'Dragonheart',
#  '59': 'Sex and the Beauties',
#  '60': 'The Libertine',
#  '61': 'Ricky Martin: One Night Only',
#  '62': "Ken Burns' America: Empire of the Air",
#  '63': 'Crash Dive',
#  '64': 'Outside the Law',
#  '65': 'Lost in the Pershing Point Hotel',
#  '66': 'Barbarian Queen 2',
#  '67': 'Vampire Journals',
#  '68': 'Invader Zim',
#  '69': 'WWE: Armageddon 2003',
#  '70': 'Tai Chi: The 24 Forms',
#  '71': 'Maya Lin: A Strong Clear Vision',
#  '72': 'Avengers',
#  '73': 'Davy Crockett: 50th Anniversary Double Feature',
#  '74': '6ixtynin9',
#  '75': 'Grind',
#  '76': 'I Love Lucy: Season 2',
#  '77': 'Congo',
#  '78': 'Jingle All the Way',
#  '79': 'The Killing',
#  '80': 'Winter Kills',
#  '81': 'Antarctica: IMAX',
#  '82': 'The Frogmen',
#  '83': 'Silkwood',
#  '84': 'The Powerpuff Girls Movie',
#  '85': 'Elfen Lied',
#  '86': 'Iron Monkey 2',
#  '87': 'Louder Than Bombs',
#  '88': 'Record of Lodoss War: Chronicles of the Heroic Knight',
#  '89': 'Chain of Command',
#  '90': 'The Lemon Drop Kid',
#  '91': 'WWE: Royal Rumble 2005',
#  '92': "ECW: Cyberslam '99",
#  '93': 'They Came Back',
#  '94': 'G3: Live in Concert',
#  '95': 'Dona Herlinda and Her Son',
#  '96': 'Inside the Space Station',
#  '97': 'Mostly Martha',
#  '98': 'The Battle of Algiers: Bonus Material',
#  '99': 'A Fishy Story',
#  '100': 'Sam the Iron Bridge',
#  '101': 'Complete Shamanic Princess',
#  '102': 'Notre Musique',
#  '103': 'Sanford and Son: Season 6',
#  '104': 'The Great Race',
#  '105': 'Obsessed',
#  '106': 'Stevie Ray Vaughan and Double Trouble: Live at Montreux 1982 & 1985',
#  '107': 'Magnolia: Bonus Material',
#  '108': 'Spartan',
#  '109': 'No Way Back',
#  '110': 'Scandal',
#  '111': 'Duplex (Widescreen)',
#  '112': 'The Eye of Vichy',
#  '113': "Bruce Lee: A Warrior's Journey",
#  '114': 'Dominion Tank Police Part 1 & 2',
#  '115': 'Lord Peter Wimsey: Murder Must Advertise',
#  '116': 'Bear Cub',
#  '117': 'Silk Stockings',
#  '118': 'Rambo: First Blood Part II',
#  '119': 'Travel the World by Train: Africa',
#  '120': 'Plain Dirty',
#  '121': 'Beyonce: Live at Wembley',
#  '122': 'Cube 2: Hypercube',
#  '123': 'Chain of Fools',
#  '124': 'Cold Blooded',
#  '125': 'Nighthawks',
#  '126': 'Vampire Effect (aka Twins Effect)',
#  '127': 'Fatal Beauty',
#  '128': 'Mr. Vampire',
#  '129': 'Darkwolf',
#  '130': 'Drowning on Dry Land',
#  '131': 'Arachnid',
#  '132': 'Lucio Fulci: The Beyond',
#  '133': 'Viva La Bam: Season 1',
#  '134': 'Spirit Lost',
#  '135': 'GTO: Great Teacher Onizuka: Set 2',
#  '136': 'Cat and the Canary',
#  '137': 'Naked Lies',
#  '138': 'Star Trek: Voyager: Season 1',
#  '139': 'Allergies: A Natural Approach',
#  '140': 'Lost in the Wild',
#  '141': 'Goddess of Mercy',
#  '142': 'The Tricky Master',
#  '143': 'The Game',
#  '144': 'Deepak Chopra: The Way of the Wizard & Alchemy',
#  '145': 'Get Out Your Handkerchiefs',
#  '146': 'Cannibal Women in the Avocado Jungle of Death',
#  '147': 'Where Sleeping Dogs Lie',
#  '148': 'Sweet November',
#  '149': 'The Edward R. Murrow Collection',
#  '150': 'Firetrap',
#  '151': 'Sleepover Nightmare',
#  '152': 'A Little Princess',
#  '153': 'MTV Yoga',
#  '154': 'Demon Warrior Koji',
#  '155': 'The Strongest Man in the World',
#  '156': 'Husbands and Wives',
#  '157': 'Laird: White Knuckle Extreme',
#  '158': 'A Killer Within',
#  '159': 'Gentlemen of Fortune',
#  '160': 'Gormenghast',
#  '161': 'Ninotchka',
#  '162': 'John Cleese on How to Irritate People',
#  '163': 'MTV: Making the Band 2: Best of Season 1',
#  '164': 'One Last Dance',
#  '165': 'Richard Pryor: Live on the Sunset Strip',
#  '166': 'Fame',
#  '167': 'The Chorus',
#  '168': 'Smokey and the Bandit Part 3',
#  '169': 'Cartoon Network Halloween: 9 Creepy Cartoon Capers',
#  '170': 'Tomorrow',
#  '171': 'Funny Face',
#  '172': 'Jack',
#  '173': "The Devil's Brigade",
#  '174': 'Adam-12: Season 1',
#  '175': 'Reservoir Dogs',
#  '176': 'The History Channel Presents: Troy: Unearthing the Legend',
#  '177': 'Pressure',
#  '178': 'Regular Guys',
#  '179': 'Bollywood Bound',
#  '180': 'Scratch',
#  '181': 'The Last Shot',
#  '182': 'Moby: Play',
#  '183': 'IFilm: Deranged',
#  '184': 'Billy Blanks: Tae Bo: Cardio Circuit 1',
#  '185': 'Missing in Action 2: The Beginning / Missing in Action 3: Braddock',
#  '186': 'Panic in the Streets',
#  '187': 'Death to Smoochy',
#  '188': 'Dead Birds',
#  '189': 'Airplane II: The Sequel',
#  '190': 'Blood and Sand',
#  '191': 'X2: X-Men United',
#  '192': 'The SoulTaker',
#  '193': 'Marilyn Manson: Fear of a Satanic Planet',
#  '194': 'Arliss: The Best of Arliss',
#  '195': 'Chasing Freedom',
#  '196': 'Peter Tosh: Stepping Razor: Red X',
#  '197': 'Taking Lives',
#  '198': 'Gupt',
#  '199': 'The Deer Hunter',
#  '200': 'The Fall of the Roman Empire',
#  '201': 'Home Movie',
#  '202': "Ruby's Bucket of Blood",
#  '203': 'Sports Illustrated Swimsuit Edition: 1997',
#  '204': 'Venus Boyz',
#  '205': 'Troy: Bonus Material',
#  '206': 'Unconstitutional: The War on Our Civil Liberties',
#  '207': 'Denise Austin: Ultimate Fat Burner',
#  '208': 'The Three Stooges: Sing a Song of Six Pants',
#  '209': 'Star Trek: Deep Space Nine: Season 5',
#  '210': 'Onmyoji',
#  '211': 'The Agronomist',
#  '212': 'Querelle',
#  '213': 'Dinner Rush',
#  '214': 'Read-Along: Beauty and the Beast',
#  '215': "That '70s Show: Season 1",
#  '216': 'Impostor',
#  '217': 'Cherry 2000',
#  '218': 'Triumph: Live at the US Festival',
#  '219': 'Neon Bible',
#  '220': 'Winston Churchill: The Wilderness Years',
#  '221': 'Voyage to the Planets and Beyond',
#  '222': 'Yellow',
#  '223': "Chappelle's Show: Season 1",
#  '224': 'Midsomer Murders: Blood Will Out',
#  '225': 'The Cookout',
#  '226': 'Henry: Portrait of a Serial Killer 2',
#  '227': 'The Carol Burnett Show: Show Stoppers',
#  '228': 'Butch and Sundance: The Early Days',
#  '229': 'Peter Gabriel: Growing Up Live',
#  '230': 'Unsolved Mysteries: Psychics',
#  '231': 'Marooned in Iraq',
#  '232': 'Gross Anatomy',
#  '233': "Chato's Land",
#  '234': 'Animation Legend: Winsor McCay',
#  '235': 'Unhook the Stars',
#  '236': 'Cartoon Crazys Sci-Fi',
#  '237': 'Broken Blossoms',
#  '238': 'Led Zeppelin: The Song Remains the Same',
#  '239': 'Winnie the Pooh: Springtime with Roo',
#  '240': 'Woman of the Year',
#  '241': 'North by Northwest',
#  '242': 'Neon Genesis Evangelion: The End of Evangelion',
#  '243': 'Pressure Point',
#  '244': 'Stellvia',
#  '245': 'Road Dogz',
#  '246': 'The Boston Strangler',
#  '247': 'Oleanna',
#  '248': "Michael Moore's The Awful Truth: Season 2",
#  '249': 'The Hunters',
#  '250': 'Cast a Giant Shadow',
#  '251': "Midsomer Murders: Strangler's Wood",
#  '252': 'Stuart Little 2',
#  '253': 'A Night at the Opera',
#  '254': 'Westender',
#  '255': 'The Hunchback of Notre Dame II',
#  '256': 'Ghost Dog: The Way of the Samurai',
#  '257': "Charlotte's Web",
#  '258': 'Mann',
#  '259': 'Animal',
#  '260': 'Marat / Sade',
#  '261': 'The Big Clock',
#  '262': 'Herbie Rides Again',
#  '263': 'Dragon Ball: Tournament Saga',
#  '264': 'Angelina Ballerina: Lights',
#  '265': 'The Jeff Corwin Experience: Costa Rica and the Amazon',
#  '266': 'Saudade Do Futuro',
#  '267': 'Touched by an Angel: Season 1',
#  '268': 'The Final Countdown',
#  '269': 'Parenthood',
#  '270': 'Sex and the City: Season 4',
#  '271': 'Saludos Amigos',
#  '272': 'Female Yakuza Tale',
#  '273': 'Taxi',
#  '274': 'Crazy as Hell',
#  '275': 'Evelyn',
#  '276': 'Cold Harvest',
#  '277': 'Enigma: MCMXC A.D',
#  '278': '100 Days Before the Command',
#  '279': 'Micki and Maude',
#  '280': 'Sarah Brightman: In Concert',
#  '281': 'The Legend',
#  '282': 'Blue Seed: Beyond',
#  '283': 'If These Walls Could Talk',
#  '284': 'Sasquatch Hunters',
#  '285': "The Devil's Own",
#  '286': 'Thunderbirds Are Go',
#  '287': 'Luther Vandross: Always and Forever: An Evening of Songs',
#  '288': 'Saturday Night Live: The Best of Chris Kattan',
#  '289': 'The Avengers',
#  '290': 'Harold and Kumar Go to White Castle',
#  '291': 'Chained Heat 3: Hell Mountain',
#  '292': 'Saturday Night Live: The Best of Gilda Radner',
#  '293': 'Lennon Legend: The Very Best of John Lennon',
#  '294': 'Oasis',
#  '295': 'Ace Ventura: When Nature Calls',
#  '296': 'In His Life: The John Lennon Story',
#  '297': 'The Hebrew Hammer',
#  '298': 'Crunch: Pick Your Spot Pilates',
#  '299': "Bridget Jones's Diary",
#  '300': 'Option Zero',
#  '301': 'Hard Ground',
#  '302': 'The Isle',
#  '303': 'Les Liaisons Dangereuses',
#  '304': 'King of the Hill: Season 1',
#  '305': 'Jack',
#  '306': 'Sesame Street: Sing Yourself Silly!',
#  '307': 'Godsmack: Smack This!',
#  '308': 'The Legend of the 7 Golden Vampires/7 Brothers of Dracula',
#  '309': 'The Day of the Locust',
#  '310': 'Leila',
#  '311': 'Ed Wood',
#  '312': 'High Fidelity',
#  '313': 'Pay It Forward',
#  '314': 'Saturday Night Live: The Best of Jon Lovitz',
#  '315': 'Combat! Season 3: Operation 2',
#  '316': 'Futurama: Monster Robot Maniac Fun Collection',
#  '317': 'Mandela and de Klerk',
#  '318': 'Beyond Suspicion',
#  '319': 'Straight to Hell',
#  '320': 'Eat Your Heart Out',
#  '321': 'Ju-Rei: The Uncanny',
#  '322': 'Flesh Gordon',
#  '323': 'Modern Vampires',
#  '324': "Mother's Boys",
#  '325': 'Ghosts of Rwanda: Frontline',
#  '326': 'The Plainsman',
#  '327': 'Storefront Hitchcock',
#  '328': 'Deftones: Live in Hawaii',
#  '329': 'Dogma',
#  '330': 'Wild Things',
#  '331': 'Chasing Amy',
#  '332': 'They Crawl',
#  '333': 'Mail Call: The Best of Season 2',
#  '334': 'The Pacifier',
#  '335': 'Fear No Evil',
#  '336': 'The Driver',
#  '337': 'Star 80',
#  '338': 'The Three Stooges: Three Smart Saps',
#  '339': 'Rolling Stones: Rock and Roll Circus',
#  '340': 'Midnight: 2000 Seen By...',
#  '341': 'Tremors 4: The Legend Begins',
#  '342': 'Noir',
#  '343': 'French and Saunders: Live',
#  '344': 'The Taming of the Shrew',
#  '345': 'Star Trek: Voyager: Season 5',
#  '346': 'Up and Down',
#  '347': 'Iceman Cometh',
#  '348': 'The Last Temptation of Christ',
#  '349': 'The Swarm',
#  '350': 'Dr. Quinn',
#  '351': 'Guns of the Magnificent Seven',
#  '352': 'Pick a Card',
#  '353': 'Life or Something Like It',
#  '354': 'Sadomania',
#  '355': 'Sinful Nuns of St. Valentine',
#  '356': 'Look at Me',
#  '357': 'House of Sand and Fog',
#  '358': 'The Onion Field',
#  '359': 'Absolutely Fabulous: Series 5',
#  '360': 'Lies',
#  '361': 'The Phantom of the Opera: Special Edition',
#  '362': 'The Flintstones in Viva Rock Vegas',
#  '363': 'Stark Raving Mad',
#  '364': 'Billy Blanks: Tae Bo: Contact 2',
#  '365': 'R.E.M.: Tourfilm',
#  '366': 'Still',
#  '367': 'Spun',
#  '368': 'The Best of Designing Women',
#  '369': 'Playing Mona Lisa',
#  '370': 'Chaplin',
#  '371': 'The Trouble with Angels',
#  '372': 'Jeans',
#  '373': 'Third World Cop',
#  '374': 'The Little Girl Who Lives Down the Lane',
#  '375': 'Nine Dead Gay Guys',
#  '376': 'Genesis: The Way We Walk: Live in Concert',
#  '377': 'Dick Francis: The Racing Game',
#  '378': 'Party Monster',
#  '379': 'Crash Dive',
#  '380': 'Live Wire',
#  '381': 'Out for Justice',
#  '382': 'Buried in the Sand: The Deception of America',
#  '383': 'Hit Team',
#  '384': 'Crossroads',
#  '385': 'The Santa Clause 2',
#  '386': 'Princess Caraboo',
#  '387': "Bizet's Carmen",
#  '388': 'Body Chemistry',
#  '389': 'Steal',
#  '390': 'The Fan',
#  '391': 'The Monkees: Season 2',
#  '392': "Danielle Steel's Heartbeat",
#  '393': 'The Replacement Killers',
#  '394': '20',
#  '395': 'Captain Blood',
#  '396': 'Arjuna: Complete Collection',
#  '397': 'A Night in Casablanca',
#  '398': 'In the Realm of the Senses',
#  '399': 'Fangs',
#  '400': 'Rio Lobo',
#  '401': 'Halloween 5: The Revenge of Michael Myers',
#  '402': 'Pan Tadeusz',
#  '403': 'Substitute 4: Failure is Not an Option',
#  '404': 'The Shaft',
#  '405': 'Wings of Desire',
#  '406': 'Hostage',
#  '407': 'The Abductors',
#  '408': 'Nightbreed',
#  '409': 'Godzilla vs. The Sea Monster',
#  '410': 'Frank Lloyd Wright',
#  '411': 'Vendetta',
#  '412': 'Jay Jay the Jet Plane: Adventures in Learning',
#  '413': 'Igby Goes Down',
#  '414': 'Girl',
#  '415': 'Reign in Darkness',
#  '416': 'Elephant',
#  '417': 'Transformers: Season 3: Part 1',
#  '418': 'The Deal',
#  '419': 'George Lopez: Why You Crying?',
#  '420': 'Saturday Night Live: The Best of Dana Carvey',
#  '421': "Agatha Christie's Poirot: Sad Cypress",
#  '422': 'The Unsinkable Molly Brown',
#  '423': 'My Favorite Martian #1',
#  '424': 'Happiness',
#  '425': 'The 10th Kingdom',
#  '426': "Recess: School's Out",
#  '427': 'Graveyard Shift',
#  '428': "Barney: Barney's Colorful World: Live",
#  '429': 'Zeus and Roxanne',
#  '430': 'Chobits',
#  '431': 'Millennium Actress',
#  '432': 'Les Miserables in Concert',
#  '433': 'Untamed Heart',
#  '434': "Extreme Engineering: Tokyo's Sky City",
#  '435': 'Love Can Seriously Damage Your Health',
#  '436': 'Girls Just Want to Have Fun',
#  '437': 'Beyblade: Fierce Battle',
#  '438': 'Bean: The Movie',
#  '439': 'Town Without Pity',
#  '440': 'Just 4 Kicks',
#  '441': 'Dark Shadows: Vol. 9',
#  '442': 'Mississippi Burning',
#  '443': 'Rabbit-Proof Fence',
#  '444': 'The Inner Tour',
#  '445': 'Michael Collins',
#  '446': 'The Underneath',
#  '447': 'The Making of Fanny and Alexander',
#  '448': 'Oswald: Welcome to the Big City!',
#  '449': 'Jimmy Buffett: MiniMatinee #1',
#  '450': "Isaac Stern: Life's Virtuoso",
#  '451': 'Batman the Animated Series: Vol. 3',
#  '452': 'Scorched',
#  '453': 'Simple Men',
#  '454': 'Xena: Warrior Princess: Season 3',
#  '455': 'Cardcaptor Sakura: The Movie',
#  '456': 'Emma (Miniseries)',
#  '457': 'Kill Bill: Vol. 2',
#  '458': 'Blast',
#  '459': 'Basquiat',
#  '460': 'Pink Narcissus',
#  '461': 'Nightwalker #1: Midnight Detective',
#  '462': 'Classic Cartoon Favorites: Starring Donald',
#  '463': 'The Twilight Zone: Vol. 12',
#  '464': 'The Return of Ruben Blades',
#  '465': 'Coolie No.1',
#  '466': 'Doogie Howser',
#  '467': 'Topper Returns',
#  '468': 'The Matrix: Revolutions',
#  '469': 'First Night of My Life: 2000 Seen By...',
#  '470': 'Beneath Loch Ness',
#  '471': 'City Lights',
#  '472': 'Mr. Jealousy',
#  '473': 'Princess Mononoke',
#  '474': 'Legend of 1900',
#  '475': 'Surf Ninjas',
#  '476': "VeggieTales Classics: Where's God When I'm Scared?",
#  '477': 'George Carlin: Personal Favorites',
#  '478': 'The Beverly Hillbillies',
#  '479': 'George Carlin: What Am I Doing in New Jersey?',
#  '480': 'Flypaper',
#  '481': 'Building the Great Pyramid',
#  '482': 'Frida',
#  '483': 'Rush Hour 2',
#  '484': "Danielle Steel's Jewels",
#  '485': "The Avengers '67",
#  '486': 'Journey to the Center of the Earth',
#  '487': 'Doctor Who: Lost in Time: The Patrick Troughton Years',
#  '488': 'His Secret Life',
#  '489': 'Return to Paradise',
#  '490': 'The Passion of Ayn Rand',
#  '491': 'Torn Curtain',
#  '492': 'Mrs. Soffel',
#  '493': 'The Giallo Collection: Who Saw Her Die?',
#  '494': "Monty Python's The Meaning of Life: Special Edition",
#  '495': 'Mission Kashmir',
#  '496': 'Primus: Hallucino-Genetics Live 2004',
#  '497': "Broadway's Lost Treasures",
#  '498': 'Glory: Bonus Material',
#  '499': 'Under Suspicion',
#  '500': 'Mail Call: The Best of Season 1',
#  '501': 'Three Days of the Condor',
#  '502': 'Mitch Hedberg: Mitch All Together',
#  '503': 'Max and Ruby: Springtime for Max and Ruby',
#  '504': 'The Twilight Zone: Vol. 27',
#  '505': 'A Thousand Acres',
#  '506': "Blank Generation / Dancin' Barefoot",
#  '507': 'Nevada Smith',
#  '508': 'Saint Jack',
#  '509': 'The Volcano Disaster',
#  '510': "Blue's Clues: Blue's Room: It's Hug Day",
#  '511': 'Avenging Angelo',
#  '512': 'Bubblegum Crisis: Hurricane Live!',
#  '513': 'Butterfly Kiss',
#  '514': 'Santana: Supernatural Live',
#  '515': 'Avia Vampire Hunter',
#  '516': 'Monsoon Wedding',
#  '517': 'Two Can Play That Game',
#  '518': 'The Prime of Miss Jean Brodie',
#  '519': 'From Mao to Mozart: Isaac Stern in China',
#  '520': "E's Otherwise",
#  '521': 'Presenting Felix the Cat',
#  '522': 'Love Songs',
#  '523': 'My Side of the Mountain',
#  '524': 'Mumford',
#  '525': 'The Last Seduction II',
#  '526': 'Angie',
#  '527': 'Barbarian Queen',
#  '528': "The Hitchhiker's Guide to the Galaxy",
#  '529': 'Summer of the Monkeys',
#  '530': 'Return to Horror High',
#  '531': "You're Invited to Mary-Kate and Ashley's Vacation Parties",
#  '532': 'Young Einstein',
#  '533': 'Drop Dead Fred',
#  '534': 'With a Friend Like Harry',
#  '535': 'The Alamo',
#  '536': 'Sol Goode',
#  '537': 'Here is Greenwood',
#  '538': 'A Crime of Passion',
#  '539': 'Rumpole of the Bailey: Series 4',
#  '540': 'Ghosts of the Abyss: Bonus Material',
#  '541': 'King Cobra',
#  '542': 'The Blackout',
#  '543': 'Roughnecks: The Starship Troopers Chronicles: The Pluto Campaign',
#  '544': 'Maurice: Bonus Material',
#  '545': 'Bob the Builder: The Big Game',
#  '546': 'The Strip Game',
#  '547': 'Kuffs',
#  '548': 'Hudson Hawk',
#  '549': 'Rage at Dawn',
#  '550': 'First Knight',
#  '551': 'The Santa Clause',
#  '552': 'Radioland Murders',
#  '553': 'Rangeela',
#  '554': 'Solaris',
#  '555': 'Cadfael: A Morbid Taste for Bones',
#  '556': 'New Waterford Girl',
#  '557': 'Liebestraum',
#  '558': 'Fantastic Four',
#  '559': 'Rebecca: Bonus Material',
#  '560': 'Star Trek: Enterprise: Season 3',
#  '561': 'High and Low',
#  '562': 'Bloody Mallory',
#  '563': 'Jimmy Neutron: Boy Genius',
#  '564': 'Predator 2',
#  '565': 'Tom Petty and the Heartbreakers: Live at the Olympic: The Last DJ',
#  '566': 'Bullet',
#  '567': 'Dunsmore',
#  '568': 'Knights of Ramune',
#  '569': 'The In-Laws',
#  '570': 'The Visit',
#  '571': 'American Beauty',
#  '572': 'The Masque of the Red Death / The Premature Burial',
#  '573': 'Winners & Sinners',
#  '574': 'Strangers When We Meet',
#  '575': 'Highlander: Season 4',
#  '576': 'Popular: Season 2',
#  '577': 'The Twilight Zone: Vol. 36',
#  '578': 'The Terror',
#  '579': 'The Autobiography of Miss Jane Pittman',
#  '580': 'THX 1138: Special Edition',
#  '581': 'Black Jack: The Movie',
#  '582': 'Jo Jo Dancer',
#  '583': 'Third Man on the Mountain',
#  '584': 'The Curve',
#  '585': 'My Family',
#  '586': 'Shanghai Triad',
#  '587': 'The Scarlet and the Black',
#  '588': 'Blue Planet: IMAX',
#  '589': 'Northanger Abbey',
#  '590': 'Michael McDonald: A Gathering of Friends',
#  '591': 'Particles of Truth',
#  '592': 'House of Whipcord',
#  '593': 'Baby Genius: Mozart and Friends',
#  '594': 'By Hook or By Crook',
#  '595': 'Monarch of the Glen: Series 2',
#  '596': 'Alice in Wonderland (TV Version)',
#  '597': 'The Brady Bunch Variety Hour',
#  '598': 'Bobby Darin: Mack is Back',
#  '599': 'Sea of Love',
#  '600': "What's Up",
#  '601': 'The Smiths: The Complete Picture',
#  '602': 'Tokyo Raiders',
#  '603': 'Burn Up Excess: Vol. 1: To Serve and Protect',
#  '604': "Walt Disney's Timeless Tales: Vol. 2",
#  '605': 'The Secrets of the Dead Sea Scrolls',
#  '606': 'Quatermass and the Pit',
#  '607': 'Speed',
#  '608': 'The Lickerish Quartet',
#  '609': 'Jimmy Neutron: Attack of the Twonkies',
#  '610': 'Offspring: Americana',
#  '611': 'Spooks & Creeps',
#  '612': 'Cloak and Dagger',
#  '613': 'The Dr. Who Collection',
#  '614': 'Bad Boy Bubby',
#  '615': 'An Ideal Husband',
#  '616': 'SCTV Network 90: Vol. 4',
#  '617': 'UFC: Ultimate Fighting Championship: Ultimate Knockouts 3',
#  '618': 'Totally F***ed Up',
#  '619': 'Doctor Who: The Leisure Hive',
#  '620': 'Hot Wheels: World Race',
#  '621': 'Armageddon',
#  '622': "Talkin' Dirty After Dark",
#  '623': 'Dario Argento Collection: Vol. 2: Demons 2',
#  '624': 'My Mother Likes Women',
#  '625': 'Underground Comedy Movie',
#  '626': 'They Died with Their Boots On',
#  '627': 'Beware of a Holy Whore',
#  '628': 'Rescue Heroes: The Movie',
#  '629': 'Firestarter',
#  '630': 'Empire of the Ants',
#  '631': 'Unleashed',
#  '632': "Shaft's Big Score!",
#  '633': 'Baazigar',
#  '634': 'Christmas with The Simpsons',
#  '635': 'The Fassbinder Collection: Pioneer in Ingolstadt',
#  '636': 'Stir Crazy',
#  '637': 'National Geographic: Inside American Power: Air Force One',
#  '638': 'The Last Dragon',
#  '639': 'Jim Brown: All-American',
#  '640': 'To Catch a Killer',
#  '641': 'Charly',
#  '642': 'Mystery Science Theater 3000: The Hellcats',
#  '643': 'Buying the Cow',
#  '644': 'Cheyenne Warrior',
#  '645': 'Dear Frankie',
#  '646': 'Matewan',
#  '647': 'Cinderfella',
#  '648': 'John Mayall & The Bluesbreakers and Friends: 70th Birthday Concert',
#  '649': 'Ricky Martin: The Ricky Martin Video Collection',
#  '650': "Elvira's Haunted Hills",
#  '651': 'The Rainbow Fish / Dazzle the Dinosaur',
#  '652': "Marvin's Room",
#  '653': 'American Tragedy',
#  '654': 'Return of the Chinese Boxer',
#  '655': 'Green Acres: Season 1',
#  '656': 'Veronica 2030',
#  '657': 'Highlander: Season 5',
#  '658': 'Robin Hood: Prince of Thieves',
#  '659': 'The Last House on the Left',
#  '660': 'Saving Grace',
#  '661': 'Who is Cletis Tout?',
#  '662': 'Rob Roy',
#  '663': 'La Femme Nikita: Season 3',
#  '664': 'Office Killer',
#  '665': 'Lipstick',
#  '666': 'The Man Who Came to Dinner',
#  '667': "Gilligan's Island: Season 2",
#  '668': 'Saturday Night Live: The Best of Will Ferrell 2',
#  '669': 'Real Kung Fu of Shaolin',
#  '670': 'He Loves Me',
#  '671': 'The Winter People',
#  '672': 'He Said',
#  '673': 'Fight Club: Bonus Material',
#  '674': 'Hellbound: Hellraiser II',
#  '675': "Rugrats All Grown Up: O' Brother!",
#  '676': 'Mafia!',
#  '677': 'In the Mood for Love',
#  '678': 'Loves of a Blonde',
#  '679': 'R.E.M.: Pop Screen',
#  '680': 'Better Than Sex',
#  '681': 'Police Academy 3: Back in Training',
#  '682': 'The Mighty',
#  '683': 'Cavalry Charge',
#  '684': 'Visitors of the Night',
#  '685': 'Running Out of Time',
#  '686': 'Bedazzled',
#  '687': 'Peter Jennings Reports: The Kennedy Assassination: Beyond Conspiracy',
#  '688': 'The History Channel Presents: The Alamo',
#  '689': 'One True Thing',
#  '690': 'Baby Einstein: Baby Da Vinci',
#  '691': "Angel's Dance",
#  '692': 'The Hand that Rocks the Cradle',
#  '693': 'The Quest',
#  '694': 'When Dinosaurs Roamed America',
#  '695': 'Koma',
#  '696': 'Last Man Standing',
#  '697': "Caillou: Caillou's Treasure Hunt and Other Adventures",
#  '698': 'Daud',
#  '699': 'Mahoromatic: Automatic Maiden: Summer Special',
#  '700': "Todd McFarlane's Spawn",
#  '701': 'Nine Lives',
#  '702': 'For the Moment',
#  '703': 'Japan: Memoirs of a Secret Empire',
#  '704': 'A Change of Heart',
#  '705': 'Major League',
#  '706': 'Mobsters',
#  '707': 'The Return',
#  '708': 'The Perfect Storm',
#  '709': "Africans in America: America's Journey Through Slavery",
#  '710': 'Inspector Morse 9: The Last Enemy',
#  '711': 'Dolores Claiborne',
#  '712': 'Homicide: Life on the Street: Season 7',
#  '713': 'Cause Celebre',
#  '714': 'Whisper Kill',
#  '715': 'Film Noir Collection: D.O.A.',
#  '716': 'The Bravados',
#  '717': 'Testosterone',
#  '718': '44 Minutes',
#  '719': 'City of Industry',
#  '720': 'Roger & Me',
#  '721': 'Royal Deceit',
#  '722': 'The Wire: Season 1',
#  '723': 'Curly Sue',
#  '724': 'Yu Yu Hakusho',
#  '725': 'Woman Thou Art Loosed',
#  '726': 'The Haunting of Morella',
#  '727': 'Carlton-Browne of the F.O.',
#  '728': "Abigail's Party",
#  '729': 'Fast Food',
#  '730': 'Bagdad Cafe',
#  '731': 'Mr. Magoo',
#  '732': '11:14',
#  '733': 'Dead Ringers',
#  '734': 'Indochine',
#  '735': 'Hillary & Tenzing: Climbing to the Roof of World',
#  '736': 'The Last Man',
#  '737': 'Great Pas de Deux',
#  '738': 'A Slipping Down Life',
#  '739': 'Treading Water',
#  '740': 'The House on Carroll Street',
#  '741': "Ken Burns' America: The Congress",
#  '742': 'Sherlock: Case of Evil',
#  '743': "Widows' Peak",
#  '744': 'Hot War',
#  '745': 'Fantasy Mission Force',
#  '746': 'Domestic Disturbance',
#  '747': 'Saber Marionette J',
#  '748': 'I Can Do Bad All By Myself',
#  '749': 'Ernest Goes to Jail',
#  '750': 'The Librarian: Quest for the Spear',
#  '751': 'Halloween: H2O',
#  '752': 'Star Trek: The Next Generation: Season 7',
#  '753': 'Mary Poppins: Bonus Material',
#  '754': 'The Lonely Guy',
#  '755': 'Music Box',
#  '756': 'The Best of MusikLaden: Classic Rock',
#  '757': 'Sherlock Hound',
#  '758': 'Mean Girls',
#  '759': 'Fifteen Minutes',
#  '760': "Pooh's Heffalump Movie",
#  '761': 'O Fantasma',
#  '762': 'End of the Century: The Story of the Ramones',
#  '763': 'The Poseidon Adventure',
#  '764': 'Scarface: 20th Anniversary Edition: Bonus Material',
#  '765': 'Grief',
#  '766': 'A Hole in the Head',
#  '767': 'Edges of the Lord',
#  '768': 'The Star Maker',
#  '769': 'The Crawling Eye',
#  '770': 'A Perfect Candidate',
#  '771': 'Man in the Iron Mask',
#  '772': "Gloria Estefan: Don't Stop!",
#  '773': 'He Died with a Felafel in His Hand',
#  '774': "Foyle's War: Set 2",
#  '775': 'Man Ray: Prophet of the Avant Garde',
#  '776': "Dr. Seuss's The 5",
#  '777': 'Sherlock Holmes and the Spider Woman',
#  '778': 'A Touch of Frost: Seasons 7 & 8',
#  '779': 'Loving Jezebel',
#  '780': 'Churchill',
#  '781': 'Care Bears: Journey to Joke-a-Lot',
#  '782': 'Soldier of Fortune',
#  '783': 'For Love or Country',
#  '784': 'The Outer Limits: The New Series: Aliens Among Us',
#  '785': 'American Pop',
#  '786': 'Tokyo Drifter',
#  '787': 'La Vallee',
#  '788': 'Clerks',
#  '789': 'Boyz N the Hood',
#  '790': 'A Single Girl',
#  '791': 'Don Henley: Live Inside Job',
#  '792': 'Unsolved History: Salem Witch Trials',
#  '793': 'By Brakhage: An Anthology',
#  '794': 'A Stranger Among Us',
#  '795': 'Landmarks of Early Film',
#  '796': 'Rabid',
#  '797': 'Look Back in Anger',
#  '798': 'Jaws',
#  '799': 'Teen Titans: Season 1',
#  '800': 'Dracula Vs. Frankenstein',
#  '801': 'We Know Where You Live. Live!',
#  '802': 'Spies',
#  '803': 'Soul Assassin',
#  '804': 'Sherlock Holmes: The Scarlet Claw',
#  '805': 'Dark Shadows: Vol. 11',
#  '806': 'Eyes Without a Face',
#  '807': 'The Mouse That Roared',
#  '808': 'Dead Man on Campus',
#  '809': 'Left Behind II: Tribulation Force',
#  '810': 'The Matchmaker',
#  '811': 'The Lawnmower Man',
#  '812': 'The Saddle Club: Horse Crazy',
#  '813': 'On Cukor',
#  '814': 'Ruin Explorers',
#  '815': 'Tiger Bay',
#  '816': 'Marlene Dietrich: Her Own Song',
#  '817': 'My Bodyguard',
#  '818': "Logan's Run",
#  '819': 'The Faculty',
#  '820': 'Predator Island',
#  '821': 'Slaughter',
#  '822': 'Star Trek: Enterprise: Season 1',
#  '823': 'Sleepaway Camp II: Unhappy Campers',
#  '824': 'A Piece of the Action',
#  '825': 'Bill Cosby: Himself',
#  '826': 'Goosebumps: Cry of the Cat',
#  '827': "C'est La Vie",
#  '828': 'Atlantis',
#  '829': 'Serial Mom',
#  '830': 'Return to a Better Tomorrow',
#  '831': 'Mannequin',
#  '832': 'Tupac: Resurrection',
#  '833': 'White Squall',
#  '834': 'Niagara: Miracles',
#  '835': 'Cirque du Soleil: A Baroque Odyssey',
#  '836': 'Incident at Oglala: The Leonard Peltier Story',
#  '837': 'All in the Family: Season 3',
#  '838': 'Gang of Roses',
#  '839': 'The Thin Man Goes Home',
#  '840': 'The Lady Eve',
#  '841': 'There Goes My Baby',
#  '842': 'Reap the Wild Wind',
#  '843': 'Mansfield Park',
#  '844': 'La Cienaga',
#  '845': 'If We Had No Moon',
#  '846': 'Enduring Love',
#  '847': 'Shania Twain: The Platinum Collection',
#  '848': 'La Separation',
#  '849': 'Mr. & Mrs. Bridge',
#  '850': 'Stoked: The Rise and Fall of Gator',
#  '851': 'Back to the Future Part III',
#  '852': 'Disorganized Crime',
#  '853': 'Dragonball: The Magic Begins',
#  '854': "Wes Craven's Invitation to Hell",
#  '855': 'Bruiser',
#  '856': 'Devil in the Flesh 2',
#  '857': 'The Three Stooges Go Around the World in a Daze',
#  '858': 'Sports Illustrated Swimsuit Edition: 2002',
#  '859': 'Creepshow',
#  '860': 'Crime Partners',
#  '861': 'Rush: Rush in Rio',
#  '862': 'Tuck Everlasting',
#  '863': 'King of New York: Special Edition (Full-screen)',
#  '864': 'Laughing Out Loud: Vol. 1',
#  '865': 'Elvis by the Presleys',
#  '866': 'Starsky & Hutch: Season 1',
#  '867': 'My Dream Girl',
#  '868': 'La Promesse',
#  '869': 'Without Limits: NASA Test Projects',
#  '870': 'H.G. Wells and the War of the Worlds: A Documentary',
#  '871': 'The Jewel in the Crown',
#  '872': 'Seven Samurai',
#  '873': 'Boys Life 4: Four Play',
#  '874': 'Elvis Costello & the Imposters: Live in Memphis',
#  '875': 'Zakhm',
#  '876': 'Super Gals',
#  '877': 'A Love Divided',
#  '878': 'Short: International Release #2',
#  '879': 'Mikey and Nicky',
#  '880': "Sharpe 4: Sharpe's Enemy",
#  '881': 'Mating Habits of the Earthbound Human',
#  '882': 'Gloria Estefan: Evolution Tour: Live in Miami',
#  '883': 'Deep Cover',
#  '884': 'Cup Final',
#  '885': 'The Maldonado Miracle',
#  '886': 'Ray',
#  '887': 'Monster-in-Law: Bonus Material',
#  '888': 'Discovering Australia',
#  '889': 'Reno 911: Season 2',
#  '890': 'Harsh Realm: The Complete Series',
#  '891': "Zakk Wylde's Black Label Society: Boozed",
#  '892': 'The Bedford Incident',
#  '893': "Blue's Clues: Classic Clues",
#  '894': 'The Muse',
#  '895': 'Dersu Uzala',
#  '896': 'Dangerous Minds',
#  '897': 'Bride and Prejudice',
#  '898': 'The Body',
#  '899': 'Out of Ireland: The Hit Songs and Artists of Irish Music',
#  '900': 'Eat Drink Man Woman',
#  '901': 'Diary of a Country Priest',
#  '902': 'Fascination',
#  '903': 'Hamlet',
#  '904': 'Gargoyles',
#  '905': 'Remedy',
#  '906': 'Benny Hill: Complete and Unadulterated: The Naughty Early Years: Set 1',
#  '907': 'Animal Crackers',
#  '908': 'Sense and Sensibility',
#  '909': 'Too Young to Die',
#  '910': 'Santa Fe Trail',
#  '911': 'Buck Rogers',
#  '912': 'Angelina Ballerina: Friends Forever',
#  '913': 'Dead Kennedys: In God We Trust',
#  '914': 'R.E.M.: Road Movie',
#  '915': 'Haven',
#  '916': 'Earth 2: The Complete Series',
#  '917': 'String Cheese Incident: Live at the Fillmore',
#  '918': "A Hard Day's Night: Collector's Series",
#  '919': 'Comedian',
#  '920': "Satanis: The Devil's Mass / Sinthia: The Devil's Doll: Double Feature",
#  '921': "Don't Bother to Knock",
#  '922': 'Gojoe: Spirit War Chronicle',
#  '923': 'Giant Robo',
#  '924': 'Taxi Zum Klo',
#  '925': 'Dodsworth',
#  '926': 'Fear Of A Punk Planet',
#  '927': "Danielle Steel's Changes",
#  '928': 'The Night That Never Happened',
#  '929': 'Journeys with George',
#  '930': 'Back to the Beach',
#  '931': 'Another Day in Paradise',
#  '932': 'Where Are We?',
#  '933': "Backyardigans: It's Great to Be a Ghost",
#  '934': 'River of No Return',
#  '935': 'Read Or Die',
#  '936': 'A Dangerous Man: Lawrence After Arabia',
#  '937': 'Fallen',
#  '938': 'Scarecrow',
#  '939': 'Midsomer Murders: A Tale of Two Hamlets',
#  '940': 'Hercules',
#  '941': 'Screw Loose',
#  '942': 'The Pagemaster',
#  '943': "Dave Chappelle: For What It's Worth",
#  '944': 'Brother',
#  '945': 'The Duel at Silver Creek',
#  '946': 'Sex and the Teenage Mind',
#  '947': 'The Cincinnati Kid',
#  '948': 'Aap Mujhe Achche Lagne Lage',
#  '949': 'Henry Fool',
#  '950': 'Explosive Dance',
#  '951': 'Richard Rodgers: The Sweetest Sounds',
#  '952': 'My Favorite Wife',
#  '953': 'Fahrenheit 451',
#  '954': 'I Capture the Castle',
#  '955': 'Rhyme & Reason',
#  '956': 'Blankman',
#  '957': 'Lost in Space: Season 2: Vol. 1',
#  '958': 'World Cup Soccer Highlights: 1966-1974',
#  '959': 'Jay Jay the Jet Plane: Lessons for All Seasons',
#  '960': 'The Unforgiven',
#  '961': 'Love in the Afternoon',
#  '962': 'I Spy',
#  '963': 'A Streetcar Named Desire',
#  '964': 'The Tick: The Entire Series',
#  '965': 'Metropolitan Opera: Puccini: Tosca',
#  '966': 'Young and Dangerous 2',
#  '967': 'Main Hoon Na',
#  '968': 'Dottie Gets Spanked',
#  '969': 'Stripteaser',
#  '970': 'Yesterday Once More',
#  '971': 'Unprecedented: The 2000 Presidential Election',
#  '972': 'Ben Harper: Live at the Hollywood Bowl',
#  '973': 'Dr. Martin Luther King',
#  '974': 'The Devil and Daniel Webster',
#  '975': 'Convict 762',
#  '976': 'Tom and Jerry: Paws for a Holiday',
#  '977': 'Our Lady of the Assassins',
#  '978': 'Yi Yi',
#  '979': 'A Moment of Romance',
#  '980': 'The Swan Princess',
#  '981': 'How I Got into College',
#  '982': 'Dil Chahta Hai',
#  '983': 'Wishful Thinking',
#  '984': 'The Young Lions',
#  '985': 'The Mummy',
#  '986': 'The Trip',
#  '987': "Rescue from Gilligan's Island",
#  '988': 'Operation Pacific',
#  '989': 'The Door in the Floor',
#  '990': 'Meet John Doe',
#  '991': 'Burn Up Excess: Vol. 2: Crimes and Missed Demeanors',
#  '992': 'The Cowboys',
#  '993': 'The Shadow',
#  '994': 'Children of the Corn',
#  '995': 'Dark Town',
#  '996': 'Yojimbo',
#  '997': 'Miracle of the White Stallions',
#  '998': 'Frida: Bonus Material',
#  '999': 'The Favor',
#  '1000': 'Jim Breuer: Hardcore',
#  ...}

# %%
#Convert the data to a list of lists 
all_item_lists = list(user_dict.values())

# %%
#Get initial counts of the items
item_counts = count_items(all_item_lists)

# %%
#Number of users
len(all_item_lists)
# Out:
# 268298

# %% [markdown]
# ## 2.2 Preprocessing

# %%
#2.2 Hyperparameters
min_item_frequency = 15 # Keep only the items with more than this frequency in the data
max_items_for_user = 180 # Maximum amount of items to consider a user informative 
min_items_for_user = 2 # Minimum amount of items to consider a user informative

# %%
filtered_item_lists = filter_data(all_item_lists, item_counts, 
                                  min_item_freq = min_item_frequency, 
                                  max_items = max_items_for_user, 
                                  min_items = min_items_for_user)

filtered_item_counts = count_items(filtered_item_lists)

# %%
len(filtered_item_counts)
# Out:
# 133

# %%
#Convert each item_id to an index to be able to use with the model
#Also create a reverse link between the IDs and the indexes
items_to_idx, idx_to_items = items_vs_index(filtered_item_lists)
unique_item_size = len(items_to_idx)

#Format and convert the whole data as indexes instead of actual IDs
data_by_idx = [[items_to_idx[item] for item in item_list] for item_list in filtered_item_lists]
counts_by_idx = count_items(data_by_idx)

# %%
unique_item_size
# Out:
# 133

# %%
len(counts_by_idx)
# Out:
# 133

# %%
#Create a new dictionary with the item name according to new indexes
#This will make it easier to do a sanity check for the recommender and get actual names instead of indexes
names_by_idx = {}
for k,v in item_names.items():
    if k in items_to_idx:
        names_by_idx[items_to_idx[k]] = v

# %%
names_by_idx
# Out:
# {0: 'Pearl Harbor',
#  1: 'The Goonies',
#  2: 'Batman Returns',
#  3: 'From Dusk Till Dawn',
#  4: 'G.I. Jane',
#  5: 'Sexy Beast',
#  6: 'For a Few Dollars More',
#  7: 'South Park: Season 2',
#  8: 'Mighty Joe Young',
#  9: 'All About My Mother',
#  10: 'Pacific Heights',
#  11: 'Boat Trip',
#  12: 'Colors',
#  13: 'Before Night Falls',
#  14: 'Iron Will',
#  15: 'The Best Man',
#  16: "Cheech & Chong's Nice Dreams",
#  17: 'The Year of Living Dangerously',
#  18: 'Queer as Folk: Season 3',
#  19: 'The Grey Zone',
#  20: 'Romance',
#  21: 'Sudden Death',
#  22: 'The Candidate',
#  23: 'The Dead Zone: Season 1',
#  24: 'Dennis the Menace',
#  25: 'SpongeBob SquarePants: Season 1',
#  26: 'Sleuth',
#  27: 'Twilight',
#  28: 'Love Me If You Dare',
#  29: 'The Witches',
#  30: 'The Mechanic',
#  31: 'Dear God',
#  32: 'Samurai Jack',
#  33: 'Lady Jane',
#  34: 'The Heart of Me',
#  35: 'Life with Mikey',
#  36: 'The Adventures of Huck Finn',
#  37: 'Bus Stop',
#  38: 'Foxy Brown',
#  39: 'Mystery Science Theater 3000: Timechasers',
#  40: 'It Was a Wonderful Life',
#  41: 'The Five Obstructions',
#  42: "Man's Best Friend",
#  43: 'Destry Rides Again',
#  44: "Teacher's Pet",
#  45: 'Lois & Clark: The New Adventures of Superman: Season 1',
#  46: 'Tom & Viv',
#  47: 'Doctor Who: The Armageddon Factor',
#  48: 'Wicked',
#  49: 'S.F.W.',
#  50: 'The Good Mother',
#  51: 'Still Crazy',
#  52: 'Spring Forward',
#  53: "Three's Company: Season 4",
#  54: 'Rugrats: Decade in Diapers',
#  55: 'Waxwork / Waxwork II: Double Feature',
#  56: 'Black Moon Rising',
#  57: 'Just Looking',
#  58: 'Days of Being Wild',
#  59: 'One Tree Hill: Season 2',
#  60: 'Slow Burn',
#  61: 'Village of the Damned / Children of the Damned',
#  62: 'Sailor Moon S',
#  63: 'Pavilion of Women',
#  64: 'Phantasm IV: Oblivion',
#  65: 'Cedric the Entertainer: Starting Lineup 2',
#  66: 'Son of the Beach: Vol. 1',
#  67: 'The Mrs. Bradley Mysteries',
#  68: 'Evil Remains',
#  69: 'Blue Juice',
#  70: 'Max Dugan Returns',
#  71: 'Inner Senses',
#  73: 'Moving Violations',
#  74: "Boys' Shorts: The New Queer Cinema",
#  75: 'Regency House Party',
#  76: 'Gol Maal',
#  77: 'The Lady in Red',
#  78: 'Tune in Tomorrow',
#  79: 'Battle Athletes Victory: Vol. 8: The Human Race!',
#  80: 'Rumpelstiltskin',
#  81: 'The Master of Ballantrae',
#  82: 'National Geographic: 21 Days to Baghdad',
#  83: 'Massage Your Mate',
#  84: 'Tieta of Agreste',
#  85: 'Straightman',
#  86: 'Harold and the Purple Crayon',
#  87: "Kangaroo Jack: G'Day USA",
#  88: "I'll Remember April",
#  89: "Jancis Robinson's Wine Course",
#  90: 'WWE: Backlash 2005',
#  91: 'Coast to Coast',
#  92: 'The Whole Shebang',
#  93: "I'm Still Here . . . Damn It!",
#  94: 'The Sea Chase',
#  95: 'Second Time Around',
#  96: 'The Criminal',
#  97: 'The Illiterate One',
#  98: 'Rammstein: Lichtspielhaus',
#  99: "Violence in a Women's Prison",
#  100: 'Full Clip',
#  101: 'Armored Trooper Votoms Stage 1: Uoodo City',
#  102: 'Kojak: Season 1',
#  103: 'The Winter Guest',
#  104: "Lana's Rain",
#  105: 'Destiny',
#  106: 'Atomic Journeys: Welcome to Ground Zero',
#  107: 'Grand Tour: Disaster in Time',
#  108: '.Com for Murder',
#  109: 'WWE: The Best of Intercontinental Championship Matches',
#  110: 'Infested',
#  111: 'Heartwood',
#  112: 'Laurel & Hardy & Friends',
#  113: 'Stiletto Dance',
#  114: 'Fidelio: Beethoven: Royal Opera House',
#  115: "Don's Party",
#  116: 'The Elite',
#  117: 'Gunsmoke: The Last Apache',
#  118: 'Hester Street',
#  119: 'Love and Action in Chicago',
#  120: 'Morlang',
#  121: 'Magic of Fellini',
#  122: 'Virgin Machine',
#  123: 'Colonel Wolodyjowski',
#  124: 'Kylie Minogue: Body Language Live',
#  125: 'Here Comes Cookie / Love in Bloom / Six of a Kind: Triple Feature',
#  126: 'The Giallo Collection: The Bloodstained Shadow',
#  127: 'The Church',
#  128: 'Fox: The Blockbuster Years',
#  129: "Magic User's Club",
#  130: 'The Real Bruce Lee',
#  131: "Knocking On Death's Door",
#  132: 'Kakurenbo: Hide & Seek'}

# %%
#Split the data into train and test sets
trainset, testset = train_test(data_by_idx, test_size = 0.2)
trainset_counts = count_items(trainset)

# %%
#Make sure no item in testset is missing in trainset
missing_items = find_missing_items(trainset, testset)
# Out:
# No missing items in train set!

# %%
testset_counts = count_items(testset)

# %% [markdown]
# ## 2.3 Preparations

# %%
#2.3 Hyperparameters
power = 0.75 #power alpha for the negative samples distribution
rho = 1e-5 #frequency parameter for the sampling table

# %%
#Create the negative sampling distribution and the sampling table
neg_samples_list = create_item_unigram(trainset_counts, power)
s_t = samplingtable(trainset_counts, rho)

# %%
#Create all the couples for train and test sets
#These couples will be used for evaluation purposes

#Train set
all_train_couples, all_train_labels = create_all_SGNS_data(trainset, 
                                                           num_neg_samples = 0, #we don't need negative samples to evaluate
                                                           window_size = 1, #Only one item after each item as couples
                                                           sampling_table = s_t, #Not relevant
                                                           shuffle = False, #No need to shuffle
                                                           negative_samples_list= neg_samples_list, #Not relevant
                                                           loss = 'binary_ce', #Can be any
                                                           use_st = False #Need all the couples, no sampling
                                                          )

#Test set
all_test_couples, all_test_labels = create_all_SGNS_data(testset, 
                                                         num_neg_samples = 0, #we don't need negative samples to evaluate
                                                         window_size = 1, #Only one item after each item as couples
                                                         sampling_table = s_t, #Not relevant
                                                         shuffle = False, #No need to shuffle
                                                         negative_samples_list= neg_samples_list, #Not relevant
                                                         loss = 'binary_ce', #Can be any
                                                         use_st = False #Need all the couples, no sampling
                                                          )

# %% [markdown]
# # 3. Model 1 - (Loss: Binary Cross Entropy)

# %% [markdown]
# - Model: Skipgram with Negative Sampling
# - Activation: **Sigmoid**
# - Loss: **Binary Cross Entropy**
# - Optimizer: **SGD**
# - Negative Samples: **1**
# - Epochs: **150**
# - Batch size: **128**

# %%
#Model 1 Hyperparameters
items_size = len(trainset_counts.keys())
missing = len(counts_by_idx) - len(trainset_counts) # For missing value
embedding_dim = 50
loss = 'binary_ce'
opt = optimizers.SGD(lr=0.1)
metric = 'accuracy'

dual_embedding = True
bias = True

#Training hyperparameters
number_neg_samples = 1
win_size = 1
number_epochs = 50 # original 150
batch_size = 128
shuffle = True

# %%
I2V_bce = create_I2Vmodel(items_size, 
                          embed_dim = embedding_dim, 
                          loss = loss, 
                          model_optimizer = opt, 
                          model_metric = metric, 
                          dual_embedding = dual_embedding, 
                          bias = bias)

# %%
I2V_bce.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# context (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# target (InputLayer)             (None, 1)            0
# __________________________________________________________________________________________________
# item_embedding_u (Embedding)    (None, 1, 50)        6650        context[0][0]
# __________________________________________________________________________________________________
# bias_embedding_u (Embedding)    (None, 1, 1)         133         context[0][0]
# __________________________________________________________________________________________________
# item_embedding_v (Embedding)    (None, 1, 50)        6650        target[0][0]
# __________________________________________________________________________________________________
# bias_embedding_v (Embedding)    (None, 1, 1)         133         target[0][0]
# __________________________________________________________________________________________________
# u_concat (Concatenate)          (None, 1, 51)        0           item_embedding_u[0][0]
#                                                                  bias_embedding_u[0][0]
# __________________________________________________________________________________________________
# v_concat (Concatenate)          (None, 1, 51)        0           item_embedding_v[0][0]
#                                                                  bias_embedding_v[0][0]
# __________________________________________________________________________________________________
# dot_p (Dot)                     (None, 1, 1)         0           u_concat[0][0]
#                                                                  v_concat[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 1)            0           dot_p[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1)            0           flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            1           reshape_1[0][0]
# ==================================================================================================
# Total params: 13,567
# Trainable params: 13,434
# Non-trainable params: 133
# __________________________________________________________________________________________________

# %%
plot_model(I2V_bce, to_file='model.png', show_shapes=True, show_layer_names=True)
from IPython.display import Image
Image(retina=True, filename='model.png')

# %%
#Train the model
m_loss, acc, tr_auc, ts_auc, u_vecs, v_vecs, v_bias, u_bias = train(model = I2V_bce, 
                                                          traindata = trainset,
                                                          num_epochs = number_epochs, 
                                                          batch_size = batch_size, 
                                                          num_neg_samples = number_neg_samples, 
                                                          win_size = win_size, 
                                                          v = 2, 
                                                          shuffle = shuffle, 
                                                          neg_samples = neg_samples_list, 
                                                          s_t = s_t,  
                                                          loss = loss,
                                                          use_st = False)
# Out:
# Sampling data and creating skipgrams ...
# 5.02s
# Creating couples and labels for model train ...0.17s
# Sampling data and creating skipgrams ...
# 1.14s
# Creating couples and labels for model train ...0.04s
# Training item2vec model on 133 unique items and 100505 users
# Epoch 1: Epoch 1/1
#  - 4s - loss: 0.6442 - accuracy: 0.6669
# Saving item embeddings after epoch
# Epoch 2: Epoch 1/1
#  - 4s - loss: 0.5560 - accuracy: 0.7420
# Saving item embeddings after epoch
# Epoch 3: Epoch 1/1
#  - 4s - loss: 0.4968 - accuracy: 0.7830
# Saving item embeddings after epoch
# Epoch 4: Epoch 1/1
#  - 4s - loss: 0.4689 - accuracy: 0.7967
# Saving item embeddings after epoch
# Epoch 5: Epoch 1/1
#  - 4s - loss: 0.4523 - accuracy: 0.8036
# Saving item embeddings after epoch
# Epoch 6: Epoch 1/1
#  - 4s - loss: 0.4409 - accuracy: 0.8074
# Saving item embeddings after epoch
# Epoch 7: Epoch 1/1
#  - 4s - loss: 0.4325 - accuracy: 0.8108
# Saving item embeddings after epoch
# Epoch 8: Epoch 1/1
#  - 4s - loss: 0.4260 - accuracy: 0.8142
# Saving item embeddings after epoch
# Epoch 9: Epoch 1/1
#  - 4s - loss: 0.4208 - accuracy: 0.8161
# Saving item embeddings after epoch
# Epoch 10: Epoch 1/1
#  - 4s - loss: 0.4165 - accuracy: 0.8179
# Saving item embeddings after epoch
# Epoch 11: Epoch 1/1
#  - 4s - loss: 0.4129 - accuracy: 0.8190
# Saving item embeddings after epoch
# Epoch 12: Epoch 1/1
#  - 4s - loss: 0.4098 - accuracy: 0.8205
# Saving item embeddings after epoch
# Epoch 13: Epoch 1/1
#  - 4s - loss: 0.4072 - accuracy: 0.8211
# Saving item embeddings after epoch
# Epoch 14: Epoch 1/1
#  - 4s - loss: 0.4048 - accuracy: 0.8224
# Saving item embeddings after epoch
# Epoch 15: Epoch 1/1
#  - 4s - loss: 0.4028 - accuracy: 0.8231
# Saving item embeddings after epoch
# Epoch 16: Epoch 1/1
#  - 4s - loss: 0.4010 - accuracy: 0.8237
# Saving item embeddings after epoch
# Epoch 17: Epoch 1/1
#  - 4s - loss: 0.3993 - accuracy: 0.8242
# Saving item embeddings after epoch
# Epoch 18: Epoch 1/1
#  - 4s - loss: 0.3978 - accuracy: 0.8248
# Saving item embeddings after epoch
# Epoch 19: Epoch 1/1
#  - 4s - loss: 0.3965 - accuracy: 0.8252
# Saving item embeddings after epoch
# Epoch 20: Epoch 1/1
#  - 4s - loss: 0.3952 - accuracy: 0.8256
# Saving item embeddings after epoch
# Epoch 21: Epoch 1/1
#  - 4s - loss: 0.3941 - accuracy: 0.8259
# Saving item embeddings after epoch
# Epoch 22: Epoch 1/1
#  - 4s - loss: 0.3931 - accuracy: 0.8262
# Saving item embeddings after epoch
# Epoch 23: Epoch 1/1
#  - 4s - loss: 0.3921 - accuracy: 0.8265
# Saving item embeddings after epoch
# Epoch 24: Epoch 1/1
#  - 4s - loss: 0.3912 - accuracy: 0.8267
# Saving item embeddings after epoch
# Epoch 25: Epoch 1/1
#  - 4s - loss: 0.3904 - accuracy: 0.8270
# Saving item embeddings after epoch
# Epoch 26: Epoch 1/1
#  - 4s - loss: 0.3896 - accuracy: 0.8271
# Saving item embeddings after epoch
# Epoch 27: Epoch 1/1
#  - 4s - loss: 0.3888 - accuracy: 0.8277
# Saving item embeddings after epoch
# Epoch 28: Epoch 1/1
#  - 4s - loss: 0.3881 - accuracy: 0.8279
# Saving item embeddings after epoch
# Epoch 29: Epoch 1/1
#  - 4s - loss: 0.3875 - accuracy: 0.8280
# Saving item embeddings after epoch
# Epoch 30: Epoch 1/1
#  - 4s - loss: 0.3869 - accuracy: 0.8282
# Saving item embeddings after epoch
# Epoch 31: Epoch 1/1
#  - 4s - loss: 0.3863 - accuracy: 0.8282
# Saving item embeddings after epoch
# Epoch 32: Epoch 1/1
#  - 4s - loss: 0.3858 - accuracy: 0.8284
# Saving item embeddings after epoch
# Epoch 33: Epoch 1/1
#  - 4s - loss: 0.3853 - accuracy: 0.8285
# Saving item embeddings after epoch
# Epoch 34: Epoch 1/1
#  - 4s - loss: 0.3848 - accuracy: 0.8289
# Saving item embeddings after epoch
# Epoch 35: Epoch 1/1
#  - 4s - loss: 0.3843 - accuracy: 0.8290
# Saving item embeddings after epoch
# Epoch 36: Epoch 1/1
#  - 4s - loss: 0.3839 - accuracy: 0.8291
# Saving item embeddings after epoch
# Epoch 37: Epoch 1/1
#  - 4s - loss: 0.3835 - accuracy: 0.8292
# Saving item embeddings after epoch
# Epoch 38: Epoch 1/1
#  - 4s - loss: 0.3830 - accuracy: 0.8295
# Saving item embeddings after epoch
# Epoch 39: Epoch 1/1
#  - 4s - loss: 0.3826 - accuracy: 0.8293
# Saving item embeddings after epoch
# Epoch 40: Epoch 1/1
#  - 4s - loss: 0.3823 - accuracy: 0.8295
# Saving item embeddings after epoch
# Epoch 41: Epoch 1/1
#  - 4s - loss: 0.3820 - accuracy: 0.8296
# Saving item embeddings after epoch
# Epoch 42: Epoch 1/1
#  - 4s - loss: 0.3816 - accuracy: 0.8297
# Saving item embeddings after epoch
# Epoch 43: Epoch 1/1
#  - 4s - loss: 0.3813 - accuracy: 0.8299
# Saving item embeddings after epoch
# Epoch 44: Epoch 1/1
#  - 4s - loss: 0.3810 - accuracy: 0.8298
# Saving item embeddings after epoch
# Epoch 45: Epoch 1/1
#  - 4s - loss: 0.3807 - accuracy: 0.8300
# Saving item embeddings after epoch
# Epoch 46: Epoch 1/1
#  - 4s - loss: 0.3804 - accuracy: 0.8301
# Saving item embeddings after epoch
# Epoch 47: Epoch 1/1
#  - 4s - loss: 0.3801 - accuracy: 0.8301
# Saving item embeddings after epoch
# Epoch 48: Epoch 1/1
#  - 4s - loss: 0.3798 - accuracy: 0.8303
# Saving item embeddings after epoch
# Epoch 49: Epoch 1/1
#  - 4s - loss: 0.3796 - accuracy: 0.8302
# Saving item embeddings after epoch
# Epoch 50: Epoch 1/1
#  - 4s - loss: 0.3793 - accuracy: 0.8303
# Saving item embeddings after epoch

# %%
#Plot model metrics
plot_model_metrics(train_loss = m_loss, train_acc = acc, train_auc = tr_auc, test_auc = ts_auc)

# %% [markdown]
# ## 3.2 Model 1 Evaluation

# %%
u_vecs_n_bias = {}
v_vecs_n_bias = {}
for i in range(number_epochs):
    u_vecs_n_bias[i] = np.concatenate((u_vecs[i], u_bias[i]), axis=1)
    v_vecs_n_bias[i] = np.concatenate((v_vecs[i], v_bias[i]), axis=1)

# %% [markdown]
# #### MPR

# %%
#Check how the MPR value changes with each epoch 
#Assuming it will decrease with each epoch we don't need to see all the way to the end
#Just to make sure how the graph looks

train_mpr50 = []
test_mpr50 = []
all_items = list(counts_by_idx.keys())
n = number_epochs - 40
for i in range(n): 
    #Test Set
    print('MPR calculations on Test Set after epoch: ' + str(i+1) + '/' + str(n))
    pr50 = []
    for couple in all_test_couples:
        k_recommendations = get_k_random_items(couple, all_items, k=50)
        relevant_item_embeddings = []
        for item in k_recommendations:
            relevant_item_embeddings.append(v_vecs_n_bias[i][item])
        relevant_item_embeddings = np.array(relevant_item_embeddings)
        most_similar_index = get_topk_similar2(u_vecs_n_bias[i][couple[0]], relevant_item_embeddings)
        most_similar_items = []
        for idx in most_similar_index:
            most_similar_items.append(k_recommendations[idx])
            
        pr50.append(pr(couple[1], most_similar_items))

    test_mpr50.append(np.mean(pr50))
   
    #Train Set
    print('MPR calculations on Train Set after epoch:  ' + str(i+1) + '/' + str(n))
    pr50 = []
    for couple in all_train_couples:
        k_recommendations = get_k_random_items(couple, all_items, k=50)
        relevant_item_embeddings = []
        for item in k_recommendations:
            relevant_item_embeddings.append(v_vecs_n_bias[i][item])
        relevant_item_embeddings = np.array(relevant_item_embeddings)
        most_similar_index = get_topk_similar2(u_vecs_n_bias[i][couple[0]], relevant_item_embeddings)
        most_similar_items = []
        for idx in most_similar_index:
            most_similar_items.append(k_recommendations[idx])
            
        pr50.append(pr(couple[1], most_similar_items))
        
    train_mpr50.append(np.mean(pr50))

plt.plot(train_mpr50)
plt.plot(test_mpr50)
plt.title('MPR@50')
plt.ylabel('MPR@50')
plt.xlabel('epoch')
plt.legend(['Train', 'Test'])
plt.show()
# Out:
# MPR calculations on Test Set after epoch: 1/10
# MPR calculations on Train Set after epoch:  1/10
# MPR calculations on Test Set after epoch: 2/10
# MPR calculations on Train Set after epoch:  2/10
# MPR calculations on Test Set after epoch: 3/10
# MPR calculations on Train Set after epoch:  3/10
# MPR calculations on Test Set after epoch: 4/10
# MPR calculations on Train Set after epoch:  4/10
# MPR calculations on Test Set after epoch: 5/10
# MPR calculations on Train Set after epoch:  5/10
# MPR calculations on Test Set after epoch: 6/10
# MPR calculations on Train Set after epoch:  6/10
# MPR calculations on Test Set after epoch: 7/10
# MPR calculations on Train Set after epoch:  7/10
# MPR calculations on Test Set after epoch: 8/10
# MPR calculations on Train Set after epoch:  8/10
# MPR calculations on Test Set after epoch: 9/10
# MPR calculations on Train Set after epoch:  9/10
# MPR calculations on Test Set after epoch: 10/10
# MPR calculations on Train Set after epoch:  10/10

# %%
#Get the MPR of the last epoch only 
#According to the graph above we can assume that with each epoch the MPR decreases,
#So the lowest MPR should be for the last epoch

number_epochs = 30

all_items = list(counts_by_idx.keys())

pr50 = []
for couple in all_test_couples:
    k_recommendations = get_k_random_items(couple, all_items, k=50)
    relevant_item_embeddings = []
    for item in k_recommendations:
        relevant_item_embeddings.append(v_vecs_n_bias[number_epochs-1][item])
    relevant_item_embeddings = np.array(relevant_item_embeddings)
    most_similar_index = get_topk_similar2(u_vecs_n_bias[number_epochs-1][couple[0]], relevant_item_embeddings)
    most_similar_items = []
    for idx in most_similar_index:
        most_similar_items.append(k_recommendations[idx])

    pr50.append(pr(couple[1], most_similar_items))

test_mpr50_last = np.mean(pr50)

pr50 = []
for couple in all_train_couples:
    k_recommendations = get_k_random_items(couple, all_items, k=50)
    relevant_item_embeddings = []
    for item in k_recommendations:
        relevant_item_embeddings.append(v_vecs_n_bias[number_epochs-1][item])
    relevant_item_embeddings = np.array(relevant_item_embeddings)
    most_similar_index = get_topk_similar2(u_vecs_n_bias[number_epochs-1][couple[0]], relevant_item_embeddings)
    most_similar_items = []
    for idx in most_similar_index:
        most_similar_items.append(k_recommendations[idx])

    pr50.append(pr(couple[1], most_similar_items))

train_mpr50_last = np.mean(pr50)

print('Model 1 - Loss: Binary Cross Entropy')
print('Train Set MPR@50:   ', train_mpr50_last)
print('Test Set MPR@50:    ', test_mpr50_last)
# Out:
# Model 1 - Loss: Binary Cross Entropy
# Train Set MPR@50:    5.372506381330584
# Test Set MPR@50:     5.533616706708557

# %% [markdown]
# #### HR

# %%
train_hr20 = []
test_hr20 = []
all_items = list(counts_by_idx.keys())

n = 10 # original 10 times

for i in range(n): 
    #Test Set
    print('HR calculations on Test Set after epoch: ' + str(i+1) + '/' + str(n))
    hr20 = []
    for couple in all_test_couples:
        most_similar_items = get_topk_similar2(u_vecs_n_bias[i][couple[0]], v_vecs_n_bias[i], k=20)           
        hr20.append(hr(couple[1], most_similar_items))

    test_hr20.append((np.sum(hr20)/len(all_test_couples))*100)
   
    #Train Set
    print('HR calculations on Train Set after epoch:  ' + str(i+1) + '/' + str(n))
    hr20 = []
    for couple in all_train_couples:
        most_similar_items = get_topk_similar2(u_vecs_n_bias[i][couple[0]], v_vecs_n_bias[i], k=20)
        hr20.append(hr(couple[1], most_similar_items))
        
    train_hr20.append((np.sum(hr20)/len(all_train_couples))*100)

plt.plot(train_hr20)
plt.plot(test_hr20)
plt.title('HR@20')
plt.ylabel('HR@20')
plt.xlabel('epoch')
plt.legend(['Train', 'Test'])
plt.show()
# Out:
# HR calculations on Test Set after epoch: 1/10
# HR calculations on Train Set after epoch:  1/10
# HR calculations on Test Set after epoch: 2/10
# HR calculations on Train Set after epoch:  2/10
# HR calculations on Test Set after epoch: 3/10
# HR calculations on Train Set after epoch:  3/10
# HR calculations on Test Set after epoch: 4/10
# HR calculations on Train Set after epoch:  4/10
# HR calculations on Test Set after epoch: 5/10
# HR calculations on Train Set after epoch:  5/10
# HR calculations on Test Set after epoch: 6/10
# HR calculations on Train Set after epoch:  6/10
# HR calculations on Test Set after epoch: 7/10
# HR calculations on Train Set after epoch:  7/10
# HR calculations on Test Set after epoch: 8/10
# HR calculations on Train Set after epoch:  8/10
# HR calculations on Test Set after epoch: 9/10
# HR calculations on Train Set after epoch:  9/10
# HR calculations on Test Set after epoch: 10/10
# HR calculations on Train Set after epoch:  10/10

# %%
#Get the HR of the last epoch only (the higher the better)
#According to the graph above we can assume that with each epoch the HR increases,
#So the highest HR should be for the last epoch

number_epochs = 30

hr20 = []
for couple in all_test_couples:
    most_similar_items = get_topk_similar2(u_vecs_n_bias[number_epochs-1][couple[0]], v_vecs_n_bias[number_epochs-1], k=20)           
    hr20.append(hr(couple[1], most_similar_items))

test_hr20_last = (np.sum(hr20)/len(all_test_couples))*100

hr20 = []
for couple in all_train_couples:
    most_similar_items = get_topk_similar2(u_vecs_n_bias[number_epochs-1][couple[0]], v_vecs_n_bias[number_epochs-1], k=20)           
    hr20.append(hr(couple[1], most_similar_items))

train_hr20_last = (np.sum(hr20)/len(all_train_couples))*100

print('Model 1 - Loss: Binary Cross Entropy')
print('Train Set HR@20:   ', train_hr20_last)
print('Test Set HR@20:    ', test_hr20_last)
# Out:
# Model 1 - Loss: Binary Cross Entropy
# Train Set HR@20:    89.86406715912962
# Test Set HR@20:     89.60450933284051

# %%
number_epochs = 30

hr10 = []
for couple in all_test_couples:
    most_similar_items = get_topk_similar2(u_vecs_n_bias[number_epochs-1][couple[0]], v_vecs_n_bias[number_epochs-1], k=10)           
    hr10.append(hr(couple[1], most_similar_items))

test_hr10_last = (np.sum(hr10)/len(all_test_couples))*100

hr10 = []
for couple in all_train_couples:
    most_similar_items = get_topk_similar2(u_vecs_n_bias[number_epochs-1][couple[0]], v_vecs_n_bias[number_epochs-1], k=10)           
    hr10.append(hr(couple[1], most_similar_items))

train_hr10_last = (np.sum(hr10)/len(all_train_couples))*100

print('Model 1 - Loss: Binary Cross Entropy')
print('Train Set HR@10:   ', train_hr10_last)
print('Test Set HR@10:    ', test_hr10_last)
# Out:
# Model 1 - Loss: Binary Cross Entropy
# Train Set HR@10:    78.97777383724457
# Test Set HR@10:     78.69709850304935

# %% [markdown]
# # 4. Model 2 - (Loss: Categorical Cross Entropy)

# %% [markdown]
# - Model: Skipgram with Negative Sampling
# - Activation: **Softmax**
# - Loss: **Categorical Cross Entropy**
# - Optimizer: **SGD**
# - Negative Samples: **1**
# - Epochs: **150**
# - Batch size: **128**

# %%
#Model 2 Hyperparameters
items_size = len(trainset_counts.keys())
missing = len(counts_by_idx) - len(trainset_counts) # For missing value
embedding_dim2 = 50
loss2 = 'categorical_ce'
opt2 = optimizers.SGD(lr=0.1)
metric2 = 'accuracy'

dual_embedding = True
bias = True

#Training hyperparameters
number_neg_samples2 = 1
win_size2 = 1
number_epochs2 = 150
batch_size2 = 128
shuffle2 = True

# %%
I2V_cce = create_I2Vmodel(items_size, 
                          embed_dim = embedding_dim2, 
                          loss = loss2, 
                          model_optimizer = opt2, 
                          model_metric = metric2, 
                          dual_embedding = dual_embedding, 
                          bias = bias)

# %%
I2V_cce.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# context (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# target (InputLayer)             (None, 1)            0
# __________________________________________________________________________________________________
# item_embedding_u (Embedding)    (None, 1, 50)        6650        context[0][0]
# __________________________________________________________________________________________________
# bias_embedding_u (Embedding)    (None, 1, 1)         133         context[0][0]
# __________________________________________________________________________________________________
# item_embedding_v (Embedding)    (None, 1, 50)        6650        target[0][0]
# __________________________________________________________________________________________________
# bias_embedding_v (Embedding)    (None, 1, 1)         133         target[0][0]
# __________________________________________________________________________________________________
# u_concat (Concatenate)          (None, 1, 51)        0           item_embedding_u[0][0]
#                                                                  bias_embedding_u[0][0]
# __________________________________________________________________________________________________
# v_concat (Concatenate)          (None, 1, 51)        0           item_embedding_v[0][0]
#                                                                  bias_embedding_v[0][0]
# __________________________________________________________________________________________________
# dot_p (Dot)                     (None, 1, 1)         0           u_concat[0][0]
#                                                                  v_concat[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 1)            0           dot_p[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1)            0           flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 2)            2           reshape_2[0][0]
# ==================================================================================================
# Total params: 13,568
# Trainable params: 13,435
# Non-trainable params: 133
# __________________________________________________________________________________________________

# %%
plot_model(I2V_cce, to_file='model.png', show_shapes=True, show_layer_names=True)
from IPython.display import Image
Image(retina=True, filename='model.png')

# %%
#Train the model
m_loss2, acc2, tr_auc2, ts_auc2, u_vecs2, v_vecs2, v_bias2, u_bias2 = train(model = I2V_cce, 
                                                          traindata = trainset,
                                                          num_epochs = number_epochs2, 
                                                          batch_size = batch_size2, 
                                                          num_neg_samples = number_neg_samples2, 
                                                          win_size = win_size2, 
                                                          v = 2, 
                                                          shuffle = shuffle2, 
                                                          neg_samples = neg_samples_list, 
                                                          s_t = s_t,  
                                                          loss = loss2,
                                                          use_st = False)
# Out:
# Sampling data and creating skipgrams ...
# 5.21s
# Creating couples and labels for model train ...0.18s
# Sampling data and creating skipgrams ...
# 1.15s
# Creating couples and labels for model train ...0.04s
# Training item2vec model on 133 unique items and 100505 users
# Epoch 1: Epoch 1/1
#  - 4s - loss: 0.6224 - accuracy: 0.6822
# Saving item embeddings after epoch
# Epoch 2: Epoch 1/1
#  - 4s - loss: 0.5089 - accuracy: 0.7748
# Saving item embeddings after epoch
# Epoch 3: Epoch 1/1
#  - 4s - loss: 0.4632 - accuracy: 0.7996
# Saving item embeddings after epoch
# Epoch 4: Epoch 1/1
#  - 4s - loss: 0.4426 - accuracy: 0.8072
# Saving item embeddings after epoch
# Epoch 5: Epoch 1/1
#  - 4s - loss: 0.4303 - accuracy: 0.8111
# Saving item embeddings after epoch
# Epoch 6: Epoch 1/1
#  - 4s - loss: 0.4217 - accuracy: 0.8159
# Saving item embeddings after epoch
# Epoch 7: Epoch 1/1
#  - 4s - loss: 0.4153 - accuracy: 0.8184
# Saving item embeddings after epoch
# Epoch 8: Epoch 1/1
#  - 4s - loss: 0.4104 - accuracy: 0.8203
# Saving item embeddings after epoch
# Epoch 9: Epoch 1/1
#  - 4s - loss: 0.4064 - accuracy: 0.8217
# Saving item embeddings after epoch
# Epoch 10: Epoch 1/1
#  - 4s - loss: 0.4031 - accuracy: 0.8231
# Saving item embeddings after epoch
# Epoch 11: Epoch 1/1
#  - 4s - loss: 0.4003 - accuracy: 0.8240
# Saving item embeddings after epoch
# Epoch 12: Epoch 1/1
#  - 4s - loss: 0.3979 - accuracy: 0.8250
# Saving item embeddings after epoch
# Epoch 13: Epoch 1/1
#  - 4s - loss: 0.3958 - accuracy: 0.8257
# Saving item embeddings after epoch
# Epoch 14: Epoch 1/1
#  - 4s - loss: 0.3940 - accuracy: 0.8263
# Saving item embeddings after epoch
# Epoch 15: Epoch 1/1
#  - 4s - loss: 0.3924 - accuracy: 0.8271
# Saving item embeddings after epoch
# Epoch 16: Epoch 1/1
#  - 4s - loss: 0.3910 - accuracy: 0.8277
# Saving item embeddings after epoch
# Epoch 17: Epoch 1/1
#  - 4s - loss: 0.3897 - accuracy: 0.8281
# Saving item embeddings after epoch
# Epoch 18: Epoch 1/1
#  - 4s - loss: 0.3886 - accuracy: 0.8286
# Saving item embeddings after epoch
# Epoch 19: Epoch 1/1
#  - 4s - loss: 0.3875 - accuracy: 0.8288
# Saving item embeddings after epoch
# Epoch 20: Epoch 1/1
#  - 4s - loss: 0.3865 - accuracy: 0.8290
# Saving item embeddings after epoch
# Epoch 21: Epoch 1/1
#  - 4s - loss: 0.3856 - accuracy: 0.8293
# Saving item embeddings after epoch
# Epoch 22: Epoch 1/1
#  - 4s - loss: 0.3848 - accuracy: 0.8297
# Saving item embeddings after epoch
# Epoch 23: Epoch 1/1
#  - 4s - loss: 0.3841 - accuracy: 0.8297
# Saving item embeddings after epoch
# Epoch 24: Epoch 1/1
#  - 4s - loss: 0.3834 - accuracy: 0.8299
# Saving item embeddings after epoch
# Epoch 25: Epoch 1/1
#  - 4s - loss: 0.3828 - accuracy: 0.8303
# Saving item embeddings after epoch
# Epoch 26: Epoch 1/1
#  - 4s - loss: 0.3822 - accuracy: 0.8305
# Saving item embeddings after epoch
# Epoch 27: Epoch 1/1
#  - 4s - loss: 0.3815 - accuracy: 0.8305
# Saving item embeddings after epoch
# Epoch 28: Epoch 1/1
#  - 4s - loss: 0.3811 - accuracy: 0.8308
# Saving item embeddings after epoch
# Epoch 29: Epoch 1/1
#  - 4s - loss: 0.3806 - accuracy: 0.8310
# Saving item embeddings after epoch
# Epoch 30: Epoch 1/1
#  - 4s - loss: 0.3801 - accuracy: 0.8312
# Saving item embeddings after epoch
# Epoch 31: Epoch 1/1
#  - 4s - loss: 0.3796 - accuracy: 0.8313
# Saving item embeddings after epoch
# Epoch 32: Epoch 1/1
#  - 4s - loss: 0.3792 - accuracy: 0.8314
# Saving item embeddings after epoch
# Epoch 33: Epoch 1/1
#  - 4s - loss: 0.3788 - accuracy: 0.8316
# Saving item embeddings after epoch
# Epoch 34: Epoch 1/1
#  - 4s - loss: 0.3784 - accuracy: 0.8316
# Saving item embeddings after epoch
# Epoch 35: Epoch 1/1
#  - 4s - loss: 0.3781 - accuracy: 0.8317
# Saving item embeddings after epoch
# Epoch 36: Epoch 1/1
#  - 4s - loss: 0.3777 - accuracy: 0.8318
# Saving item embeddings after epoch
# Epoch 37: Epoch 1/1
#  - 4s - loss: 0.3774 - accuracy: 0.8317
# Saving item embeddings after epoch
# Epoch 38: Epoch 1/1
#  - 4s - loss: 0.3771 - accuracy: 0.8319
# Saving item embeddings after epoch
# Epoch 39: Epoch 1/1
#  - 4s - loss: 0.3768 - accuracy: 0.8320
# Saving item embeddings after epoch
# Epoch 40: Epoch 1/1
#  - 4s - loss: 0.3765 - accuracy: 0.8320
# Saving item embeddings after epoch
# Epoch 41: Epoch 1/1
#  - 4s - loss: 0.3762 - accuracy: 0.8321
# Saving item embeddings after epoch
# Epoch 42: Epoch 1/1
#  - 4s - loss: 0.3759 - accuracy: 0.8322
# Saving item embeddings after epoch
# Epoch 43: Epoch 1/1
#  - 4s - loss: 0.3756 - accuracy: 0.8322
# Saving item embeddings after epoch
# Epoch 44: Epoch 1/1
#  - 4s - loss: 0.3754 - accuracy: 0.8322
# Saving item embeddings after epoch
# Epoch 45: Epoch 1/1
#  - 4s - loss: 0.3751 - accuracy: 0.8322
# Saving item embeddings after epoch
# Epoch 46: Epoch 1/1
#  - 4s - loss: 0.3749 - accuracy: 0.8325
# Saving item embeddings after epoch
# Epoch 47: Epoch 1/1
#  - 4s - loss: 0.3747 - accuracy: 0.8323
# Saving item embeddings after epoch
# Epoch 48: Epoch 1/1
#  - 4s - loss: 0.3745 - accuracy: 0.8325
# Saving item embeddings after epoch
# Epoch 49: Epoch 1/1
#  - 4s - loss: 0.3743 - accuracy: 0.8326
# Saving item embeddings after epoch
# Epoch 50: Epoch 1/1
#  - 4s - loss: 0.3741 - accuracy: 0.8326
# Saving item embeddings after epoch
# Epoch 51: Epoch 1/1
#  - 4s - loss: 0.3738 - accuracy: 0.8326
# Saving item embeddings after epoch
# Epoch 52: Epoch 1/1
#  - 4s - loss: 0.3737 - accuracy: 0.8327
# Saving item embeddings after epoch
# Epoch 53: Epoch 1/1
#  - 4s - loss: 0.3735 - accuracy: 0.8329
# Saving item embeddings after epoch
# Epoch 54: Epoch 1/1
#  - 4s - loss: 0.3733 - accuracy: 0.8328
# Saving item embeddings after epoch
# Epoch 55: Epoch 1/1
#  - 4s - loss: 0.3731 - accuracy: 0.8330
# Saving item embeddings after epoch
# Epoch 56: Epoch 1/1
#  - 4s - loss: 0.3729 - accuracy: 0.8331
# Saving item embeddings after epoch
# Epoch 57: Epoch 1/1
#  - 4s - loss: 0.3728 - accuracy: 0.8330
# Saving item embeddings after epoch
# Epoch 58: Epoch 1/1
#  - 4s - loss: 0.3726 - accuracy: 0.8329
# Saving item embeddings after epoch
# Epoch 59: Epoch 1/1
#  - 4s - loss: 0.3725 - accuracy: 0.8331
# Saving item embeddings after epoch
# Epoch 60: Epoch 1/1
#  - 4s - loss: 0.3723 - accuracy: 0.8331
# Saving item embeddings after epoch
# Epoch 61: Epoch 1/1
#  - 4s - loss: 0.3722 - accuracy: 0.8333
# Saving item embeddings after epoch
# Epoch 62: Epoch 1/1
#  - 4s - loss: 0.3720 - accuracy: 0.8333
# Saving item embeddings after epoch
# Epoch 63: Epoch 1/1
#  - 4s - loss: 0.3719 - accuracy: 0.8333
# Saving item embeddings after epoch
# Epoch 64: Epoch 1/1
#  - 4s - loss: 0.3717 - accuracy: 0.8333
# Saving item embeddings after epoch
# Epoch 65: Epoch 1/1
#  - 4s - loss: 0.3716 - accuracy: 0.8333
# Saving item embeddings after epoch
# Epoch 66: Epoch 1/1
#  - 4s - loss: 0.3714 - accuracy: 0.8333
# Saving item embeddings after epoch
# Epoch 67: Epoch 1/1
#  - 4s - loss: 0.3713 - accuracy: 0.8335
# Saving item embeddings after epoch
# Epoch 68: Epoch 1/1
#  - 4s - loss: 0.3712 - accuracy: 0.8333
# Saving item embeddings after epoch
# Epoch 69: Epoch 1/1
#  - 4s - loss: 0.3711 - accuracy: 0.8335
# Saving item embeddings after epoch
# Epoch 70: Epoch 1/1
#  - 4s - loss: 0.3709 - accuracy: 0.8335
# Saving item embeddings after epoch
# Epoch 71: Epoch 1/1
#  - 4s - loss: 0.3709 - accuracy: 0.8337
# Saving item embeddings after epoch
# Epoch 72: Epoch 1/1
#  - 4s - loss: 0.3707 - accuracy: 0.8336
# Saving item embeddings after epoch
# Epoch 73: Epoch 1/1
#  - 4s - loss: 0.3706 - accuracy: 0.8334
# Saving item embeddings after epoch
# Epoch 74: Epoch 1/1
#  - 4s - loss: 0.3705 - accuracy: 0.8336
# Saving item embeddings after epoch
# Epoch 75: Epoch 1/1
#  - 4s - loss: 0.3704 - accuracy: 0.8336
# Saving item embeddings after epoch
# Epoch 76: Epoch 1/1
#  - 4s - loss: 0.3703 - accuracy: 0.8336
# Saving item embeddings after epoch
# Epoch 77: Epoch 1/1
#  - 4s - loss: 0.3702 - accuracy: 0.8336
# Saving item embeddings after epoch
# Epoch 78: Epoch 1/1
#  - 4s - loss: 0.3701 - accuracy: 0.8336
# Saving item embeddings after epoch
# Epoch 79: Epoch 1/1
#  - 4s - loss: 0.3700 - accuracy: 0.8337
# Saving item embeddings after epoch
# Epoch 80: Epoch 1/1
#  - 4s - loss: 0.3699 - accuracy: 0.8336
# Saving item embeddings after epoch
# Epoch 81: Epoch 1/1
#  - 4s - loss: 0.3698 - accuracy: 0.8336
# Saving item embeddings after epoch
# Epoch 82: Epoch 1/1
#  - 4s - loss: 0.3697 - accuracy: 0.8337
# Saving item embeddings after epoch
# Epoch 83: Epoch 1/1
#  - 4s - loss: 0.3696 - accuracy: 0.8337
# Saving item embeddings after epoch
# Epoch 84: Epoch 1/1
#  - 4s - loss: 0.3695 - accuracy: 0.8337
# Saving item embeddings after epoch
# Epoch 85: Epoch 1/1
#  - 4s - loss: 0.3694 - accuracy: 0.8337
# Saving item embeddings after epoch
# Epoch 86: Epoch 1/1
#  - 4s - loss: 0.3693 - accuracy: 0.8339
# Saving item embeddings after epoch
# Epoch 87: Epoch 1/1
#  - 4s - loss: 0.3693 - accuracy: 0.8340
# Saving item embeddings after epoch
# Epoch 88: Epoch 1/1
#  - 4s - loss: 0.3692 - accuracy: 0.8339
# Saving item embeddings after epoch
# Epoch 89: Epoch 1/1
#  - 4s - loss: 0.3691 - accuracy: 0.8339
# Saving item embeddings after epoch
# Epoch 90: Epoch 1/1
#  - 4s - loss: 0.3690 - accuracy: 0.8339
# Saving item embeddings after epoch
# Epoch 91: Epoch 1/1
#  - 4s - loss: 0.3690 - accuracy: 0.8339
# Saving item embeddings after epoch
# Epoch 92: Epoch 1/1
#  - 4s - loss: 0.3688 - accuracy: 0.8338
# Saving item embeddings after epoch
# Epoch 93: Epoch 1/1
#  - 4s - loss: 0.3687 - accuracy: 0.8340
# Saving item embeddings after epoch
# Epoch 94: Epoch 1/1
#  - 4s - loss: 0.3687 - accuracy: 0.8339
# Saving item embeddings after epoch
# Epoch 95: Epoch 1/1
#  - 4s - loss: 0.3686 - accuracy: 0.8340
# Saving item embeddings after epoch
# Epoch 96: Epoch 1/1
#  - 4s - loss: 0.3685 - accuracy: 0.8341
# Saving item embeddings after epoch
# Epoch 97: Epoch 1/1
#  - 4s - loss: 0.3685 - accuracy: 0.8341
# Saving item embeddings after epoch
# Epoch 98: Epoch 1/1
#  - 4s - loss: 0.3684 - accuracy: 0.8340
# Saving item embeddings after epoch
# Epoch 99: Epoch 1/1
#  - 4s - loss: 0.3683 - accuracy: 0.8342
# Saving item embeddings after epoch
# Epoch 100: Epoch 1/1
#  - 4s - loss: 0.3683 - accuracy: 0.8342
# Saving item embeddings after epoch
# Epoch 101: Epoch 1/1
#  - 4s - loss: 0.3682 - accuracy: 0.8342
# Saving item embeddings after epoch
# Epoch 102: Epoch 1/1
#  - 4s - loss: 0.3681 - accuracy: 0.8341
# Saving item embeddings after epoch
# Epoch 103: Epoch 1/1
#  - 4s - loss: 0.3680 - accuracy: 0.8341
# Saving item embeddings after epoch
# Epoch 104: Epoch 1/1
#  - 4s - loss: 0.3680 - accuracy: 0.8340
# Saving item embeddings after epoch
# Epoch 105: Epoch 1/1
#  - 4s - loss: 0.3679 - accuracy: 0.8341
# Saving item embeddings after epoch
# Epoch 106: Epoch 1/1
#  - 4s - loss: 0.3678 - accuracy: 0.8342
# Saving item embeddings after epoch
# Epoch 107: Epoch 1/1
#  - 4s - loss: 0.3678 - accuracy: 0.8342
# Saving item embeddings after epoch
# Epoch 108: Epoch 1/1
#  - 4s - loss: 0.3678 - accuracy: 0.8343
# Saving item embeddings after epoch
# Epoch 109: Epoch 1/1
#  - 4s - loss: 0.3677 - accuracy: 0.8342
# Saving item embeddings after epoch
# Epoch 110: Epoch 1/1
#  - 4s - loss: 0.3676 - accuracy: 0.8342
# Saving item embeddings after epoch
# Epoch 111: Epoch 1/1
#  - 4s - loss: 0.3676 - accuracy: 0.8343
# Saving item embeddings after epoch
# Epoch 112: Epoch 1/1
#  - 4s - loss: 0.3675 - accuracy: 0.8342
# Saving item embeddings after epoch
# Epoch 113: Epoch 1/1
#  - 4s - loss: 0.3674 - accuracy: 0.8343
# Saving item embeddings after epoch
# Epoch 114: Epoch 1/1
#  - 4s - loss: 0.3674 - accuracy: 0.8342
# Saving item embeddings after epoch
# Epoch 115: Epoch 1/1
#  - 4s - loss: 0.3673 - accuracy: 0.8344
# Saving item embeddings after epoch
# Epoch 116: Epoch 1/1
#  - 4s - loss: 0.3673 - accuracy: 0.8344
# Saving item embeddings after epoch
# Epoch 117: Epoch 1/1
#  - 4s - loss: 0.3672 - accuracy: 0.8342
# Saving item embeddings after epoch
# Epoch 118: Epoch 1/1
#  - 4s - loss: 0.3672 - accuracy: 0.8345
# Saving item embeddings after epoch
# Epoch 119: Epoch 1/1
#  - 4s - loss: 0.3671 - accuracy: 0.8344
# Saving item embeddings after epoch
# Epoch 120: Epoch 1/1
#  - 4s - loss: 0.3671 - accuracy: 0.8344
# Saving item embeddings after epoch
# Epoch 121: Epoch 1/1
#  - 4s - loss: 0.3670 - accuracy: 0.8345
# Saving item embeddings after epoch
# Epoch 122: Epoch 1/1
#  - 4s - loss: 0.3670 - accuracy: 0.8344
# Saving item embeddings after epoch
# Epoch 123: Epoch 1/1
#  - 4s - loss: 0.3669 - accuracy: 0.8345
# Saving item embeddings after epoch
# Epoch 124: Epoch 1/1
#  - 4s - loss: 0.3669 - accuracy: 0.8344
# Saving item embeddings after epoch
# Epoch 125: Epoch 1/1
#  - 4s - loss: 0.3668 - accuracy: 0.8344
# Saving item embeddings after epoch
# Epoch 126: Epoch 1/1
#  - 4s - loss: 0.3668 - accuracy: 0.8344
# Saving item embeddings after epoch
# Epoch 127: Epoch 1/1
#  - 4s - loss: 0.3667 - accuracy: 0.8345
# Saving item embeddings after epoch
# Epoch 128: Epoch 1/1
#  - 4s - loss: 0.3667 - accuracy: 0.8344
# Saving item embeddings after epoch
# Epoch 129: Epoch 1/1
#  - 4s - loss: 0.3666 - accuracy: 0.8345
# Saving item embeddings after epoch
# Epoch 130: Epoch 1/1
#  - 4s - loss: 0.3666 - accuracy: 0.8345
# Saving item embeddings after epoch
# Epoch 131: Epoch 1/1
#  - 4s - loss: 0.3665 - accuracy: 0.8344
# Saving item embeddings after epoch
# Epoch 132: Epoch 1/1
#  - 4s - loss: 0.3665 - accuracy: 0.8344
# Saving item embeddings after epoch
# Epoch 133: Epoch 1/1
#  - 4s - loss: 0.3665 - accuracy: 0.8345
# Saving item embeddings after epoch
# Epoch 134: Epoch 1/1
#  - 4s - loss: 0.3664 - accuracy: 0.8346
# Saving item embeddings after epoch
# Epoch 135: Epoch 1/1
#  - 4s - loss: 0.3664 - accuracy: 0.8346
# Saving item embeddings after epoch
# Epoch 136: Epoch 1/1
#  - 4s - loss: 0.3664 - accuracy: 0.8346
# Saving item embeddings after epoch
# Epoch 137: Epoch 1/1
#  - 4s - loss: 0.3663 - accuracy: 0.8345
# Saving item embeddings after epoch
# Epoch 138: Epoch 1/1
#  - 4s - loss: 0.3663 - accuracy: 0.8345
# Saving item embeddings after epoch
# Epoch 139: Epoch 1/1
#  - 4s - loss: 0.3662 - accuracy: 0.8347
# Saving item embeddings after epoch
# Epoch 140: Epoch 1/1
#  - 4s - loss: 0.3662 - accuracy: 0.8346
# Saving item embeddings after epoch
# Epoch 141: Epoch 1/1
#  - 4s - loss: 0.3661 - accuracy: 0.8344
# Saving item embeddings after epoch
# Epoch 142: Epoch 1/1
#  - 4s - loss: 0.3661 - accuracy: 0.8346
# Saving item embeddings after epoch
# Epoch 143: Epoch 1/1
#  - 4s - loss: 0.3660 - accuracy: 0.8346
# Saving item embeddings after epoch
# Epoch 144: Epoch 1/1
#  - 4s - loss: 0.3660 - accuracy: 0.8347
# Saving item embeddings after epoch
# Epoch 145: Epoch 1/1
#  - 4s - loss: 0.3660 - accuracy: 0.8345
# Saving item embeddings after epoch
# Epoch 146: Epoch 1/1
#  - 4s - loss: 0.3659 - accuracy: 0.8346
# Saving item embeddings after epoch
# Epoch 147: Epoch 1/1
#  - 4s - loss: 0.3659 - accuracy: 0.8346
# Saving item embeddings after epoch
# Epoch 148: Epoch 1/1
#  - 4s - loss: 0.3659 - accuracy: 0.8347
# Saving item embeddings after epoch
# Epoch 149: Epoch 1/1
#  - 4s - loss: 0.3658 - accuracy: 0.8345
# Saving item embeddings after epoch
# Epoch 150: Epoch 1/1
#  - 4s - loss: 0.3658 - accuracy: 0.8347
# Saving item embeddings after epoch

# %%
#Plot model metrics
plot_model_metrics(train_loss = m_loss2, train_acc = acc2, train_auc = tr_auc2, test_auc = ts_auc2)

# %% [markdown]
# ## 4.2 Model 2 Evaluation

# %%
u_vecs_n_bias2 = {}
v_vecs_n_bias2 = {}
for i in range(number_epochs2):
    u_vecs_n_bias2[i] = np.concatenate((u_vecs2[i], u_bias2[i]), axis=1)
    v_vecs_n_bias2[i] = np.concatenate((v_vecs2[i], v_bias2[i]), axis=1)

# %% [markdown]
# #### MPR

# %%
train_mpr50_2 = []
test_mpr50_2 = []
all_items = list(counts_by_idx.keys())
n=number_epochs2 -100
for i in range(n): 
    #Test Set
    print('MPR calculations on Test Set after epoch: ' + str(i+1) + '/' + str(n))
    pr50 = []
    for couple in all_test_couples:
        k_recommendations = get_k_random_items(couple, all_items, k=50)
        relevant_item_embeddings = []
        for item in k_recommendations:
            relevant_item_embeddings.append(v_vecs_n_bias2[i][item])
        relevant_item_embeddings = np.array(relevant_item_embeddings)
        most_similar_index = get_topk_similar2(u_vecs_n_bias2[i][couple[0]], relevant_item_embeddings)
        most_similar_items = []
        for idx in most_similar_index:
            most_similar_items.append(k_recommendations[idx])
            
        pr50.append(pr(couple[1], most_similar_items))

    test_mpr50_2.append(np.mean(pr50))
   
    #Train Set
    print('MPR calculations on Train Set after epoch:  ' + str(i+1) + '/' + str(n))
    pr50 = []
    for couple in all_train_couples:
        k_recommendations = get_k_random_items(couple, all_items, k=50)
        relevant_item_embeddings = []
        for item in k_recommendations:
            relevant_item_embeddings.append(v_vecs_n_bias2[i][item])
        relevant_item_embeddings = np.array(relevant_item_embeddings)
        most_similar_index = get_topk_similar2(u_vecs_n_bias2[i][couple[0]], relevant_item_embeddings)
        most_similar_items = []
        for idx in most_similar_index:
            most_similar_items.append(k_recommendations[idx])
            
        pr50.append(pr(couple[1], most_similar_items))
        
    train_mpr50_2.append(np.mean(pr50))

plt.plot(train_mpr50_2)
plt.plot(test_mpr50_2)
plt.title('MPR@50')
plt.ylabel('MPR@50')
plt.xlabel('epoch')
plt.legend(['Train', 'Test'])
plt.show()
# Out:
# MPR calculations on Test Set after epoch: 1/50
# MPR calculations on Train Set after epoch:  1/50
# MPR calculations on Test Set after epoch: 2/50
# MPR calculations on Train Set after epoch:  2/50
# MPR calculations on Test Set after epoch: 3/50
# MPR calculations on Train Set after epoch:  3/50
# MPR calculations on Test Set after epoch: 4/50
# MPR calculations on Train Set after epoch:  4/50
# MPR calculations on Test Set after epoch: 5/50
# MPR calculations on Train Set after epoch:  5/50
# MPR calculations on Test Set after epoch: 6/50
# MPR calculations on Train Set after epoch:  6/50
# MPR calculations on Test Set after epoch: 7/50
# MPR calculations on Train Set after epoch:  7/50
# MPR calculations on Test Set after epoch: 8/50
# MPR calculations on Train Set after epoch:  8/50
# MPR calculations on Test Set after epoch: 9/50
# MPR calculations on Train Set after epoch:  9/50
# MPR calculations on Test Set after epoch: 10/50
# MPR calculations on Train Set after epoch:  10/50
# MPR calculations on Test Set after epoch: 11/50
# MPR calculations on Train Set after epoch:  11/50
# MPR calculations on Test Set after epoch: 12/50
# MPR calculations on Train Set after epoch:  12/50
# MPR calculations on Test Set after epoch: 13/50
# MPR calculations on Train Set after epoch:  13/50
# MPR calculations on Test Set after epoch: 14/50
# MPR calculations on Train Set after epoch:  14/50
# MPR calculations on Test Set after epoch: 15/50
# MPR calculations on Train Set after epoch:  15/50
# MPR calculations on Test Set after epoch: 16/50
# MPR calculations on Train Set after epoch:  16/50
# MPR calculations on Test Set after epoch: 17/50
# MPR calculations on Train Set after epoch:  17/50
# MPR calculations on Test Set after epoch: 18/50
# MPR calculations on Train Set after epoch:  18/50
# MPR calculations on Test Set after epoch: 19/50
# MPR calculations on Train Set after epoch:  19/50
# MPR calculations on Test Set after epoch: 20/50
# MPR calculations on Train Set after epoch:  20/50
# MPR calculations on Test Set after epoch: 21/50
# MPR calculations on Train Set after epoch:  21/50
# MPR calculations on Test Set after epoch: 22/50
# MPR calculations on Train Set after epoch:  22/50
# MPR calculations on Test Set after epoch: 23/50
# MPR calculations on Train Set after epoch:  23/50
# MPR calculations on Test Set after epoch: 24/50
# MPR calculations on Train Set after epoch:  24/50
# MPR calculations on Test Set after epoch: 25/50
# MPR calculations on Train Set after epoch:  25/50
# MPR calculations on Test Set after epoch: 26/50
# MPR calculations on Train Set after epoch:  26/50
# MPR calculations on Test Set after epoch: 27/50
# MPR calculations on Train Set after epoch:  27/50
# MPR calculations on Test Set after epoch: 28/50
# MPR calculations on Train Set after epoch:  28/50
# MPR calculations on Test Set after epoch: 29/50
# MPR calculations on Train Set after epoch:  29/50
# MPR calculations on Test Set after epoch: 30/50
# MPR calculations on Train Set after epoch:  30/50
# MPR calculations on Test Set after epoch: 31/50
# MPR calculations on Train Set after epoch:  31/50
# MPR calculations on Test Set after epoch: 32/50
# MPR calculations on Train Set after epoch:  32/50
# MPR calculations on Test Set after epoch: 33/50
# MPR calculations on Train Set after epoch:  33/50
# MPR calculations on Test Set after epoch: 34/50
# MPR calculations on Train Set after epoch:  34/50
# MPR calculations on Test Set after epoch: 35/50
# MPR calculations on Train Set after epoch:  35/50
# MPR calculations on Test Set after epoch: 36/50
# MPR calculations on Train Set after epoch:  36/50
# MPR calculations on Test Set after epoch: 37/50
# MPR calculations on Train Set after epoch:  37/50
# MPR calculations on Test Set after epoch: 38/50
# MPR calculations on Train Set after epoch:  38/50
# MPR calculations on Test Set after epoch: 39/50
# MPR calculations on Train Set after epoch:  39/50
# MPR calculations on Test Set after epoch: 40/50
# MPR calculations on Train Set after epoch:  40/50
# MPR calculations on Test Set after epoch: 41/50
# MPR calculations on Train Set after epoch:  41/50
# MPR calculations on Test Set after epoch: 42/50
# MPR calculations on Train Set after epoch:  42/50
# MPR calculations on Test Set after epoch: 43/50
# MPR calculations on Train Set after epoch:  43/50
# MPR calculations on Test Set after epoch: 44/50
# MPR calculations on Train Set after epoch:  44/50
# MPR calculations on Test Set after epoch: 45/50
# MPR calculations on Train Set after epoch:  45/50
# MPR calculations on Test Set after epoch: 46/50
# MPR calculations on Train Set after epoch:  46/50
# MPR calculations on Test Set after epoch: 47/50
# MPR calculations on Train Set after epoch:  47/50
# MPR calculations on Test Set after epoch: 48/50
# MPR calculations on Train Set after epoch:  48/50
# MPR calculations on Test Set after epoch: 49/50
# MPR calculations on Train Set after epoch:  49/50
# MPR calculations on Test Set after epoch: 50/50
# MPR calculations on Train Set after epoch:  50/50

# %%
#Get the MPR of the last epoch only 
#According to the graph above we can assume that with each epoch the MPR decreases,
#So the lowest MPR should be for the last epoch

number_epochs2 = 100

all_items = list(counts_by_idx.keys())

pr50_2 = []
for couple in all_test_couples:
    k_recommendations2 = get_k_random_items(couple, all_items, k=50)
    relevant_item_embeddings2 = []
    for item in k_recommendations2:
        relevant_item_embeddings2.append(v_vecs_n_bias2[number_epochs2-1][item])
    relevant_item_embeddings2 = np.array(relevant_item_embeddings2)
    most_similar_index2 = get_topk_similar2(u_vecs_n_bias2[number_epochs2-1][couple[0]], relevant_item_embeddings2)
    most_similar_items2 = []
    for idx in most_similar_index2:
        most_similar_items2.append(k_recommendations2[idx])

    pr50_2.append(pr(couple[1], most_similar_items2))

test_mpr50_2_last = np.mean(pr50_2)

pr50_2 = []
for couple in all_train_couples:
    k_recommendations2 = get_k_random_items(couple, all_items, k=50)
    relevant_item_embeddings2 = []
    for item in k_recommendations2:
        relevant_item_embeddings2.append(v_vecs_n_bias2[number_epochs2-1][item])
    relevant_item_embeddings2 = np.array(relevant_item_embeddings2)
    most_similar_index2 = get_topk_similar2(u_vecs_n_bias2[number_epochs2-1][couple[0]], relevant_item_embeddings2)
    most_similar_items2 = []
    for idx in most_similar_index2:
        most_similar_items2.append(k_recommendations2[idx])

    pr50_2.append(pr(couple[1], most_similar_items2))

train_mpr50_2_last = np.mean(pr50_2)

print('Model 2 - Loss: Categorical Cross Entropy')
print('Train Set MPR:   ', train_mpr50_2_last)
print('Test Set MPR :    ', test_mpr50_2_last)
# Out:
# Model 2 - Loss: Categorical Cross Entropy
# Train Set MPR:    5.221370341162032
# Test Set MPR :     5.40025873221216

# %% [markdown]
# #### HR

# %%
train_hr20_2 = []
test_hr20_2 = []

n = 10

for i in range(n): 
    #Test Set
    print('HR calculations on Test Set after epoch: ' + str(i+1) + '/' + str(n))
    hr20 = []
    for couple in all_test_couples:
        most_similar_items = get_topk_similar2(u_vecs_n_bias2[i][couple[0]], v_vecs_n_bias2[i], k=20)           
        hr20.append(hr(couple[1], most_similar_items))

    test_hr20_2.append((np.sum(hr20)/len(all_test_couples))*100)
   
    #Train Set
    print('HR calculations on Train Set after epoch:  ' + str(i+1) + '/' + str(n))
    hr20 = []
    for couple in all_train_couples:
        most_similar_items = get_topk_similar2(u_vecs_n_bias2[i][couple[0]], v_vecs_n_bias2[i], k=20)
        hr20.append(hr(couple[1], most_similar_items))
        
    train_hr20_2.append((np.sum(hr20)/len(all_train_couples))*100)

plt.plot(train_hr20_2)
plt.plot(test_hr20_2)
plt.title('HR@20')
plt.ylabel('HR@20')
plt.xlabel('epoch')
plt.legend(['Train', 'Test'])
plt.show()
# Out:
# HR calculations on Test Set after epoch: 1/10
# HR calculations on Train Set after epoch:  1/10
# HR calculations on Test Set after epoch: 2/10
# HR calculations on Train Set after epoch:  2/10
# HR calculations on Test Set after epoch: 3/10
# HR calculations on Train Set after epoch:  3/10
# HR calculations on Test Set after epoch: 4/10
# HR calculations on Train Set after epoch:  4/10
# HR calculations on Test Set after epoch: 5/10
# HR calculations on Train Set after epoch:  5/10
# HR calculations on Test Set after epoch: 6/10
# HR calculations on Train Set after epoch:  6/10
# HR calculations on Test Set after epoch: 7/10
# HR calculations on Train Set after epoch:  7/10
# HR calculations on Test Set after epoch: 8/10
# HR calculations on Train Set after epoch:  8/10
# HR calculations on Test Set after epoch: 9/10
# HR calculations on Train Set after epoch:  9/10
# HR calculations on Test Set after epoch: 10/10
# HR calculations on Train Set after epoch:  10/10

# %%
#Get the HR of the last epoch only (the higher the better)
#According to the graph above we can assume that with each epoch the HR increases,
#So the highest HR should be for the last epoch

number_epochs2 = 100

hr20_2 = []
for couple in all_test_couples:
    most_similar_items2 = get_topk_similar2(u_vecs_n_bias2[number_epochs2-1][couple[0]],
                                            v_vecs_n_bias2[number_epochs2-1],
                                            k=20)           
    hr20_2.append(hr(couple[1], most_similar_items2))

test_hr20_2_last = (np.sum(hr20_2)/len(all_test_couples))*100

hr20_2 = []
for couple in all_train_couples:
    most_similar_items2 = get_topk_similar2(u_vecs_n_bias2[number_epochs2-1][couple[0]],
                                            v_vecs_n_bias2[number_epochs2-1],
                                            k=20)           
    hr20_2.append(hr(couple[1], most_similar_items2))

train_hr20_2_last = (np.sum(hr20_2)/len(all_train_couples))*100

print('Model 2 - Loss: Categorical Cross Entropy')
print('Train Set HR@20:   ', train_hr20_2_last)
print('Test Set HR@20:    ', test_hr20_2_last)
# Out:
# Model 2 - Loss: Categorical Cross Entropy
# Train Set HR@20:    89.3885588692329
# Test Set HR@20:     89.16836074662724

# %%
number_epochs2 = 100

hr10_2 = []
for couple in all_test_couples:
    most_similar_items2 = get_topk_similar2(u_vecs_n_bias2[number_epochs2-1][couple[0]],
                                            v_vecs_n_bias2[number_epochs2-1],
                                            k=10)           
    hr10_2.append(hr(couple[1], most_similar_items2))

test_hr10_2_last = (np.sum(hr10_2)/len(all_test_couples))*100

hr10_2 = []
for couple in all_train_couples:
    most_similar_items2 = get_topk_similar2(u_vecs_n_bias2[number_epochs2-1][couple[0]],
                                            v_vecs_n_bias2[number_epochs-1],
                                            k=10)           
    hr10_2.append(hr(couple[1], most_similar_items2))

train_hr10_2_last = (np.sum(hr10_2)/len(all_train_couples))*100

print('Model 2 - Loss: Categorical Cross Entropy')
print('Train Set HR@10:   ', train_hr10_2_last)
print('Test Set HR@10:    ', test_hr10_2_last)
# Out:
# Model 2 - Loss: Categorical Cross Entropy
# Train Set HR@10:    79.14249849507927
# Test Set HR@10:     77.44779153576049

# %%
number_epochs2 = 100

hr20 = []
for couple in all_test_couples:
    most_similar_items = get_topk_similar2(u_vecs_n_bias2[number_epochs2-1][couple[0]], v_vecs_n_bias2[number_epochs2-1], k=20)           
    hr20.append(hr(couple[1], most_similar_items))

test_hr20_2_last2 = (np.sum(hr20)/len(all_test_couples))*100

hr20 = []
for couple in all_train_couples:
    most_similar_items = get_topk_similar2(u_vecs_n_bias2[number_epochs2-1][couple[0]], v_vecs_n_bias2[number_epochs2-1], k=20)           
    hr20.append(hr(couple[1], most_similar_items))

train_hr20_2_last2 = (np.sum(hr20)/len(all_train_couples))*100

print('Train Set HR@20:   ', train_hr20_2_last2)
print('Test Set HR@20:    ', test_hr20_2_last2)
# Out:
# Train Set HR@20:    89.3885588692329
# Test Set HR@20:     89.16836074662724

# %%
number_epochs2 = 100

hr10_2 = []
for couple in all_test_couples:
    most_similar_items2 = get_topk_similar2(u_vecs_n_bias2[number_epochs2-1][couple[0]],
                                            v_vecs_n_bias2[number_epochs2-1],
                                            k=10)           
    hr10_2.append(hr(couple[1], most_similar_items2))

test_hr10_2_last2 = (np.sum(hr10_2)/len(all_test_couples))*100

hr10_2 = []
for couple in all_train_couples:
    most_similar_items2 = get_topk_similar2(u_vecs_n_bias2[number_epochs2-1][couple[0]],
                                            v_vecs_n_bias2[number_epochs2-1],
                                            k=10)           
    hr10_2.append(hr(couple[1], most_similar_items2))

train_hr10_2_last2 = (np.sum(hr10_2)/len(all_train_couples))*100

print('Model 2 - Loss: Categorical Cross Entropy')
print('Train Set HR@10:   ', train_hr10_2_last2)
print('Test Set HR@10:    ', test_hr10_2_last2)
# Out:
# Model 2 - Loss: Categorical Cross Entropy
# Train Set HR@10:    77.73090617227493
# Test Set HR@10:     77.44779153576049

# %% [markdown]
# # 5. Model 3 - (Loss: Hinge)

# %% [markdown]
# - Model: Skipgram with Negative Sampling
# - Activation: **Linear**
# - Loss: **Hinge**
# - Optimizer: **SGD**
# - Negative Samples: **1**
# - Epochs: **50**
# - Batch size: **128**

# %%
#Model 3 Hyperparameters
items_size = len(trainset_counts.keys())
embedding_dim3 = 50
loss3 = 'hinge'
opt3 = optimizers.SGD(lr=0.1)
metric3 = 'accuracy'

dual_embedding = True
bias = True

#Training hyperparameters
number_neg_samples3 = 1
win_size3 = 1
number_epochs3 = 150
batch_size3 = 128
shuffle3 = True

# %%
I2V_h = create_I2Vmodel(items_size, 
                          embed_dim = embedding_dim3, 
                          loss = loss3, 
                          model_optimizer = opt3, 
                          model_metric = metric3, 
                          dual_embedding = dual_embedding, 
                          bias = bias)

# %%
I2V_h.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# context (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# target (InputLayer)             (None, 1)            0
# __________________________________________________________________________________________________
# item_embedding_u (Embedding)    (None, 1, 50)        6650        context[0][0]
# __________________________________________________________________________________________________
# bias_embedding_u (Embedding)    (None, 1, 1)         133         context[0][0]
# __________________________________________________________________________________________________
# item_embedding_v (Embedding)    (None, 1, 50)        6650        target[0][0]
# __________________________________________________________________________________________________
# bias_embedding_v (Embedding)    (None, 1, 1)         133         target[0][0]
# __________________________________________________________________________________________________
# u_concat (Concatenate)          (None, 1, 51)        0           item_embedding_u[0][0]
#                                                                  bias_embedding_u[0][0]
# __________________________________________________________________________________________________
# v_concat (Concatenate)          (None, 1, 51)        0           item_embedding_v[0][0]
#                                                                  bias_embedding_v[0][0]
# __________________________________________________________________________________________________
# dot_p (Dot)                     (None, 1, 1)         0           u_concat[0][0]
#                                                                  v_concat[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 1)            0           dot_p[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 1)            0           flatten_3[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            1           reshape_3[0][0]
# ==================================================================================================
# Total params: 13,567
# Trainable params: 13,434
# Non-trainable params: 133
# __________________________________________________________________________________________________

# %%
plot_model(I2V_h, to_file='model.png', show_shapes=True, show_layer_names=True)
from IPython.display import Image
Image(retina=True, filename='model.png')

# %%
#Train the model
m_loss3, acc3, tr_auc3, ts_auc3, u_vecs3, v_vecs3, v_bias3, u_bias3 = train(model = I2V_h, 
                                                          traindata = trainset,
                                                          num_epochs = number_epochs3, 
                                                          batch_size = batch_size3, 
                                                          num_neg_samples = number_neg_samples3, 
                                                          win_size = win_size3, 
                                                          v = 2, 
                                                          shuffle = shuffle3, 
                                                          neg_samples = neg_samples_list, 
                                                          s_t = s_t,  
                                                          loss = loss3,
                                                          use_st = False)
# Out:
# Sampling data and creating skipgrams ...
# 5.34s
# Creating couples and labels for model train ...0.19s
# Sampling data and creating skipgrams ...
# 1.15s
# Creating couples and labels for model train ...0.05s
# Training item2vec model on 133 unique items and 100505 users
# Epoch 1: Epoch 1/1
#  - 4s - loss: 0.6610 - accuracy: 0.4496
# Saving item embeddings after epoch
# Epoch 2: Epoch 1/1
#  - 4s - loss: 0.4143 - accuracy: 0.6733
# Saving item embeddings after epoch
# Epoch 3: Epoch 1/1
#  - 4s - loss: 0.3874 - accuracy: 0.6987
# Saving item embeddings after epoch
# Epoch 4: Epoch 1/1
#  - 4s - loss: 0.3762 - accuracy: 0.7075
# Saving item embeddings after epoch
# Epoch 5: Epoch 1/1
#  - 4s - loss: 0.3690 - accuracy: 0.7123
# Saving item embeddings after epoch
# Epoch 6: Epoch 1/1
#  - 4s - loss: 0.3641 - accuracy: 0.7187
# Saving item embeddings after epoch
# Epoch 7: Epoch 1/1
#  - 4s - loss: 0.3604 - accuracy: 0.7259
# Saving item embeddings after epoch
# Epoch 8: Epoch 1/1
#  - 4s - loss: 0.3578 - accuracy: 0.7300
# Saving item embeddings after epoch
# Epoch 9: Epoch 1/1
#  - 4s - loss: 0.3558 - accuracy: 0.7384
# Saving item embeddings after epoch
# Epoch 10: Epoch 1/1
#  - 4s - loss: 0.3541 - accuracy: 0.7462
# Saving item embeddings after epoch
# Epoch 11: Epoch 1/1
#  - 4s - loss: 0.3527 - accuracy: 0.7506
# Saving item embeddings after epoch
# Epoch 12: Epoch 1/1
#  - 4s - loss: 0.3515 - accuracy: 0.7543
# Saving item embeddings after epoch
# Epoch 13: Epoch 1/1
#  - 4s - loss: 0.3504 - accuracy: 0.7565
# Saving item embeddings after epoch
# Epoch 14: Epoch 1/1
#  - 4s - loss: 0.3495 - accuracy: 0.7573
# Saving item embeddings after epoch
# Epoch 15: Epoch 1/1
#  - 4s - loss: 0.3487 - accuracy: 0.7587
# Saving item embeddings after epoch
# Epoch 16: Epoch 1/1
#  - 4s - loss: 0.3480 - accuracy: 0.7602
# Saving item embeddings after epoch
# Epoch 17: Epoch 1/1
#  - 4s - loss: 0.3473 - accuracy: 0.7608
# Saving item embeddings after epoch
# Epoch 18: Epoch 1/1
#  - 4s - loss: 0.3468 - accuracy: 0.7624
# Saving item embeddings after epoch
# Epoch 19: Epoch 1/1
#  - 4s - loss: 0.3462 - accuracy: 0.7628
# Saving item embeddings after epoch
# Epoch 20: Epoch 1/1
#  - 4s - loss: 0.3457 - accuracy: 0.7633
# Saving item embeddings after epoch
# Epoch 21: Epoch 1/1
#  - 4s - loss: 0.3453 - accuracy: 0.7638
# Saving item embeddings after epoch
# Epoch 22: Epoch 1/1
#  - 4s - loss: 0.3448 - accuracy: 0.7641
# Saving item embeddings after epoch
# Epoch 23: Epoch 1/1
#  - 4s - loss: 0.3445 - accuracy: 0.7641
# Saving item embeddings after epoch
# Epoch 24: Epoch 1/1
#  - 4s - loss: 0.3441 - accuracy: 0.7645
# Saving item embeddings after epoch
# Epoch 25: Epoch 1/1
#  - 4s - loss: 0.3438 - accuracy: 0.7660
# Saving item embeddings after epoch
# Epoch 26: Epoch 1/1
#  - 4s - loss: 0.3435 - accuracy: 0.7660
# Saving item embeddings after epoch
# Epoch 27: Epoch 1/1
#  - 4s - loss: 0.3431 - accuracy: 0.7665
# Saving item embeddings after epoch
# Epoch 28: Epoch 1/1
#  - 4s - loss: 0.3429 - accuracy: 0.7664
# Saving item embeddings after epoch
# Epoch 29: Epoch 1/1
#  - 4s - loss: 0.3426 - accuracy: 0.7657
# Saving item embeddings after epoch
# Epoch 30: Epoch 1/1
#  - 4s - loss: 0.3423 - accuracy: 0.7659
# Saving item embeddings after epoch
# Epoch 31: Epoch 1/1
#  - 4s - loss: 0.3421 - accuracy: 0.7661
# Saving item embeddings after epoch
# Epoch 32: Epoch 1/1
#  - 4s - loss: 0.3418 - accuracy: 0.7666
# Saving item embeddings after epoch
# Epoch 33: Epoch 1/1
#  - 4s - loss: 0.3416 - accuracy: 0.7684
# Saving item embeddings after epoch
# Epoch 34: Epoch 1/1
#  - 4s - loss: 0.3414 - accuracy: 0.7698
# Saving item embeddings after epoch
# Epoch 35: Epoch 1/1
#  - 4s - loss: 0.3412 - accuracy: 0.7707
# Saving item embeddings after epoch
# Epoch 36: Epoch 1/1
#  - 4s - loss: 0.3410 - accuracy: 0.7720
# Saving item embeddings after epoch
# Epoch 37: Epoch 1/1
#  - 4s - loss: 0.3408 - accuracy: 0.7725
# Saving item embeddings after epoch
# Epoch 38: Epoch 1/1
#  - 4s - loss: 0.3406 - accuracy: 0.7727
# Saving item embeddings after epoch
# Epoch 39: Epoch 1/1
#  - 4s - loss: 0.3404 - accuracy: 0.7729
# Saving item embeddings after epoch
# Epoch 40: Epoch 1/1
#  - 4s - loss: 0.3403 - accuracy: 0.7735
# Saving item embeddings after epoch
# Epoch 41: Epoch 1/1
#  - 4s - loss: 0.3401 - accuracy: 0.7736
# Saving item embeddings after epoch
# Epoch 42: Epoch 1/1
#  - 4s - loss: 0.3399 - accuracy: 0.7742
# Saving item embeddings after epoch
# Epoch 43: Epoch 1/1
#  - 4s - loss: 0.3398 - accuracy: 0.7746
# Saving item embeddings after epoch
# Epoch 44: Epoch 1/1
#  - 4s - loss: 0.3396 - accuracy: 0.7760
# Saving item embeddings after epoch
# Epoch 45: Epoch 1/1
#  - 4s - loss: 0.3395 - accuracy: 0.7760
# Saving item embeddings after epoch
# Epoch 46: Epoch 1/1
#  - 4s - loss: 0.3394 - accuracy: 0.7770
# Saving item embeddings after epoch
# Epoch 47: Epoch 1/1
#  - 4s - loss: 0.3392 - accuracy: 0.7772
# Saving item embeddings after epoch
# Epoch 48: Epoch 1/1
#  - 4s - loss: 0.3391 - accuracy: 0.7775
# Saving item embeddings after epoch
# Epoch 49: Epoch 1/1
#  - 4s - loss: 0.3390 - accuracy: 0.7771
# Saving item embeddings after epoch
# Epoch 50: Epoch 1/1
#  - 4s - loss: 0.3388 - accuracy: 0.7774
# Saving item embeddings after epoch
# Epoch 51: Epoch 1/1
#  - 4s - loss: 0.3387 - accuracy: 0.7775
# Saving item embeddings after epoch
# Epoch 52: Epoch 1/1
#  - 4s - loss: 0.3386 - accuracy: 0.7775
# Saving item embeddings after epoch
# Epoch 53: Epoch 1/1
#  - 4s - loss: 0.3385 - accuracy: 0.7774
# Saving item embeddings after epoch
# Epoch 54: Epoch 1/1
#  - 4s - loss: 0.3384 - accuracy: 0.7774
# Saving item embeddings after epoch
# Epoch 55: Epoch 1/1
#  - 4s - loss: 0.3382 - accuracy: 0.7777
# Saving item embeddings after epoch
# Epoch 56: Epoch 1/1
#  - 4s - loss: 0.3382 - accuracy: 0.7781
# Saving item embeddings after epoch
# Epoch 57: Epoch 1/1
#  - 4s - loss: 0.3380 - accuracy: 0.7783
# Saving item embeddings after epoch
# Epoch 58: Epoch 1/1
#  - 4s - loss: 0.3379 - accuracy: 0.7787
# Saving item embeddings after epoch
# Epoch 59: Epoch 1/1
#  - 4s - loss: 0.3379 - accuracy: 0.7787
# Saving item embeddings after epoch
# Epoch 60: Epoch 1/1
#  - 4s - loss: 0.3378 - accuracy: 0.7789
# Saving item embeddings after epoch
# Epoch 61: Epoch 1/1
#  - 4s - loss: 0.3377 - accuracy: 0.7796
# Saving item embeddings after epoch
# Epoch 62: Epoch 1/1
#  - 4s - loss: 0.3376 - accuracy: 0.7797
# Saving item embeddings after epoch
# Epoch 63: Epoch 1/1
#  - 4s - loss: 0.3375 - accuracy: 0.7804
# Saving item embeddings after epoch
# Epoch 64: Epoch 1/1
#  - 4s - loss: 0.3374 - accuracy: 0.7803
# Saving item embeddings after epoch
# Epoch 65: Epoch 1/1
#  - 4s - loss: 0.3373 - accuracy: 0.7807
# Saving item embeddings after epoch
# Epoch 66: Epoch 1/1
#  - 4s - loss: 0.3373 - accuracy: 0.7804
# Saving item embeddings after epoch
# Epoch 67: Epoch 1/1
#  - 4s - loss: 0.3371 - accuracy: 0.7807
# Saving item embeddings after epoch
# Epoch 68: Epoch 1/1
#  - 4s - loss: 0.3371 - accuracy: 0.7812
# Saving item embeddings after epoch
# Epoch 69: Epoch 1/1
#  - 4s - loss: 0.3370 - accuracy: 0.7815
# Saving item embeddings after epoch
# Epoch 70: Epoch 1/1
#  - 4s - loss: 0.3369 - accuracy: 0.7813
# Saving item embeddings after epoch
# Epoch 71: Epoch 1/1
#  - 4s - loss: 0.3368 - accuracy: 0.7811
# Saving item embeddings after epoch
# Epoch 72: Epoch 1/1
#  - 4s - loss: 0.3368 - accuracy: 0.7813
# Saving item embeddings after epoch
# Epoch 73: Epoch 1/1
#  - 4s - loss: 0.3367 - accuracy: 0.7809
# Saving item embeddings after epoch
# Epoch 74: Epoch 1/1
#  - 4s - loss: 0.3366 - accuracy: 0.7807
# Saving item embeddings after epoch
# Epoch 75: Epoch 1/1
#  - 4s - loss: 0.3366 - accuracy: 0.7807
# Saving item embeddings after epoch
# Epoch 76: Epoch 1/1
#  - 4s - loss: 0.3365 - accuracy: 0.7806
# Saving item embeddings after epoch
# Epoch 77: Epoch 1/1
#  - 4s - loss: 0.3365 - accuracy: 0.7805
# Saving item embeddings after epoch
# Epoch 78: Epoch 1/1
#  - 4s - loss: 0.3364 - accuracy: 0.7806
# Saving item embeddings after epoch
# Epoch 79: Epoch 1/1
#  - 4s - loss: 0.3364 - accuracy: 0.7806
# Saving item embeddings after epoch
# Epoch 80: Epoch 1/1
#  - 4s - loss: 0.3363 - accuracy: 0.7803
# Saving item embeddings after epoch
# Epoch 81: Epoch 1/1
#  - 4s - loss: 0.3362 - accuracy: 0.7804
# Saving item embeddings after epoch
# Epoch 82: Epoch 1/1
#  - 4s - loss: 0.3362 - accuracy: 0.7798
# Saving item embeddings after epoch
# Epoch 83: Epoch 1/1
#  - 4s - loss: 0.3361 - accuracy: 0.7801
# Saving item embeddings after epoch
# Epoch 84: Epoch 1/1
#  - 4s - loss: 0.3361 - accuracy: 0.7802
# Saving item embeddings after epoch
# Epoch 85: Epoch 1/1
#  - 4s - loss: 0.3360 - accuracy: 0.7799
# Saving item embeddings after epoch
# Epoch 86: Epoch 1/1
#  - 4s - loss: 0.3360 - accuracy: 0.7809
# Saving item embeddings after epoch
# Epoch 87: Epoch 1/1
#  - 4s - loss: 0.3359 - accuracy: 0.7803
# Saving item embeddings after epoch
# Epoch 88: Epoch 1/1
#  - 4s - loss: 0.3358 - accuracy: 0.7793
# Saving item embeddings after epoch
# Epoch 89: Epoch 1/1
#  - 4s - loss: 0.3358 - accuracy: 0.7803
# Saving item embeddings after epoch
# Epoch 90: Epoch 1/1
#  - 4s - loss: 0.3357 - accuracy: 0.7802
# Saving item embeddings after epoch
# Epoch 91: Epoch 1/1
#  - 4s - loss: 0.3357 - accuracy: 0.7798
# Saving item embeddings after epoch
# Epoch 92: Epoch 1/1
#  - 4s - loss: 0.3356 - accuracy: 0.7802
# Saving item embeddings after epoch
# Epoch 93: Epoch 1/1
#  - 4s - loss: 0.3356 - accuracy: 0.7804
# Saving item embeddings after epoch
# Epoch 94: Epoch 1/1
#  - 4s - loss: 0.3355 - accuracy: 0.7802
# Saving item embeddings after epoch
# Epoch 95: Epoch 1/1
#  - 4s - loss: 0.3355 - accuracy: 0.7798
# Saving item embeddings after epoch
# Epoch 96: Epoch 1/1
#  - 4s - loss: 0.3355 - accuracy: 0.7801
# Saving item embeddings after epoch
# Epoch 97: Epoch 1/1
#  - 4s - loss: 0.3354 - accuracy: 0.7803
# Saving item embeddings after epoch
# Epoch 98: Epoch 1/1
#  - 4s - loss: 0.3354 - accuracy: 0.7806
# Saving item embeddings after epoch
# Epoch 99: Epoch 1/1
#  - 4s - loss: 0.3353 - accuracy: 0.7803
# Saving item embeddings after epoch
# Epoch 100: Epoch 1/1
#  - 4s - loss: 0.3353 - accuracy: 0.7813
# Saving item embeddings after epoch
# Epoch 101: Epoch 1/1
#  - 4s - loss: 0.3353 - accuracy: 0.7819
# Saving item embeddings after epoch
# Epoch 102: Epoch 1/1
#  - 4s - loss: 0.3352 - accuracy: 0.7815
# Saving item embeddings after epoch
# Epoch 103: Epoch 1/1
#  - 4s - loss: 0.3352 - accuracy: 0.7826
# Saving item embeddings after epoch
# Epoch 104: Epoch 1/1
#  - 4s - loss: 0.3351 - accuracy: 0.7820
# Saving item embeddings after epoch
# Epoch 105: Epoch 1/1
#  - 4s - loss: 0.3351 - accuracy: 0.7824
# Saving item embeddings after epoch
# Epoch 106: Epoch 1/1
#  - 4s - loss: 0.3351 - accuracy: 0.7823
# Saving item embeddings after epoch
# Epoch 107: Epoch 1/1
#  - 4s - loss: 0.3350 - accuracy: 0.7825
# Saving item embeddings after epoch
# Epoch 108: Epoch 1/1
#  - 4s - loss: 0.3350 - accuracy: 0.7830
# Saving item embeddings after epoch
# Epoch 109: Epoch 1/1
#  - 4s - loss: 0.3350 - accuracy: 0.7828
# Saving item embeddings after epoch
# Epoch 110: Epoch 1/1
#  - 4s - loss: 0.3349 - accuracy: 0.7825
# Saving item embeddings after epoch
# Epoch 111: Epoch 1/1
#  - 4s - loss: 0.3349 - accuracy: 0.7823
# Saving item embeddings after epoch
# Epoch 112: Epoch 1/1
#  - 4s - loss: 0.3348 - accuracy: 0.7827
# Saving item embeddings after epoch
# Epoch 113: Epoch 1/1
#  - 4s - loss: 0.3348 - accuracy: 0.7825
# Saving item embeddings after epoch
# Epoch 114: Epoch 1/1
#  - 4s - loss: 0.3348 - accuracy: 0.7826
# Saving item embeddings after epoch
# Epoch 115: Epoch 1/1
#  - 4s - loss: 0.3347 - accuracy: 0.7826
# Saving item embeddings after epoch
# Epoch 116: Epoch 1/1
#  - 4s - loss: 0.3347 - accuracy: 0.7826
# Saving item embeddings after epoch
# Epoch 117: Epoch 1/1
#  - 4s - loss: 0.3347 - accuracy: 0.7828
# Saving item embeddings after epoch
# Epoch 118: Epoch 1/1
#  - 4s - loss: 0.3347 - accuracy: 0.7822
# Saving item embeddings after epoch
# Epoch 119: Epoch 1/1
#  - 4s - loss: 0.3346 - accuracy: 0.7826
# Saving item embeddings after epoch
# Epoch 120: Epoch 1/1
#  - 4s - loss: 0.3346 - accuracy: 0.7828
# Saving item embeddings after epoch
# Epoch 121: Epoch 1/1
#  - 4s - loss: 0.3346 - accuracy: 0.7824
# Saving item embeddings after epoch
# Epoch 122: Epoch 1/1
#  - 4s - loss: 0.3345 - accuracy: 0.7824
# Saving item embeddings after epoch
# Epoch 123: Epoch 1/1
#  - 4s - loss: 0.3345 - accuracy: 0.7825
# Saving item embeddings after epoch
# Epoch 124: Epoch 1/1
#  - 4s - loss: 0.3345 - accuracy: 0.7827
# Saving item embeddings after epoch
# Epoch 125: Epoch 1/1
#  - 4s - loss: 0.3345 - accuracy: 0.7826
# Saving item embeddings after epoch
# Epoch 126: Epoch 1/1
#  - 5s - loss: 0.3344 - accuracy: 0.7827
# Saving item embeddings after epoch
# Epoch 127: Epoch 1/1
#  - 4s - loss: 0.3344 - accuracy: 0.7825
# Saving item embeddings after epoch
# Epoch 128: Epoch 1/1
#  - 4s - loss: 0.3344 - accuracy: 0.7825
# Saving item embeddings after epoch
# Epoch 129: Epoch 1/1
#  - 4s - loss: 0.3343 - accuracy: 0.7825
# Saving item embeddings after epoch
# Epoch 130: Epoch 1/1
#  - 4s - loss: 0.3343 - accuracy: 0.7823
# Saving item embeddings after epoch
# Epoch 131: Epoch 1/1
#  - 4s - loss: 0.3343 - accuracy: 0.7824
# Saving item embeddings after epoch
# Epoch 132: Epoch 1/1
#  - 4s - loss: 0.3343 - accuracy: 0.7823
# Saving item embeddings after epoch
# Epoch 133: Epoch 1/1
#  - 4s - loss: 0.3342 - accuracy: 0.7823
# Saving item embeddings after epoch
# Epoch 134: Epoch 1/1
#  - 4s - loss: 0.3342 - accuracy: 0.7821
# Saving item embeddings after epoch
# Epoch 135: Epoch 1/1
#  - 4s - loss: 0.3342 - accuracy: 0.7819
# Saving item embeddings after epoch
# Epoch 136: Epoch 1/1
#  - 4s - loss: 0.3342 - accuracy: 0.7820
# Saving item embeddings after epoch
# Epoch 137: Epoch 1/1
#  - 4s - loss: 0.3342 - accuracy: 0.7816
# Saving item embeddings after epoch
# Epoch 138: Epoch 1/1
#  - 4s - loss: 0.3341 - accuracy: 0.7814
# Saving item embeddings after epoch
# Epoch 139: Epoch 1/1
#  - 4s - loss: 0.3341 - accuracy: 0.7810
# Saving item embeddings after epoch
# Epoch 140: Epoch 1/1
#  - 4s - loss: 0.3341 - accuracy: 0.7812
# Saving item embeddings after epoch
# Epoch 141: Epoch 1/1
#  - 4s - loss: 0.3341 - accuracy: 0.7810
# Saving item embeddings after epoch
# Epoch 142: Epoch 1/1
#  - 4s - loss: 0.3340 - accuracy: 0.7812
# Saving item embeddings after epoch
# Epoch 143: Epoch 1/1
#  - 4s - loss: 0.3340 - accuracy: 0.7811
# Saving item embeddings after epoch
# Epoch 144: Epoch 1/1
#  - 4s - loss: 0.3340 - accuracy: 0.7807
# Saving item embeddings after epoch
# Epoch 145: Epoch 1/1
#  - 4s - loss: 0.3340 - accuracy: 0.7808
# Saving item embeddings after epoch
# Epoch 146: Epoch 1/1
#  - 4s - loss: 0.3339 - accuracy: 0.7807
# Saving item embeddings after epoch
# Epoch 147: Epoch 1/1
#  - 4s - loss: 0.3339 - accuracy: 0.7808
# Saving item embeddings after epoch
# Epoch 148: Epoch 1/1
#  - 4s - loss: 0.3339 - accuracy: 0.7806
# Saving item embeddings after epoch
# Epoch 149: Epoch 1/1
#  - 4s - loss: 0.3339 - accuracy: 0.7805
# Saving item embeddings after epoch
# Epoch 150: Epoch 1/1
#  - 4s - loss: 0.3339 - accuracy: 0.7804
# Saving item embeddings after epoch

# %%
#Plot model metrics
plot_model_metrics(train_loss = m_loss3, train_acc = acc3, train_auc = tr_auc3, test_auc = ts_auc3)

# %% [markdown]
# ## 5.2 Model 3 Evaluation

# %%
u_vecs_n_bias3 = {}
v_vecs_n_bias3 = {}
for i in range(number_epochs3):
    u_vecs_n_bias3[i] = np.concatenate((u_vecs3[i], u_bias3[i]), axis=1)
    v_vecs_n_bias3[i] = np.concatenate((v_vecs3[i], v_bias3[i]), axis=1)

# %% [markdown]
# #### MPR

# %%
train_mpr50_3 = []
test_mpr50_3 = []
all_items = list(counts_by_idx.keys())
n=number_epochs3- 100
for i in range(n): 
    #Test Set
    print('MPR calculations on Test Set after epoch: ' + str(i+1) + '/' + str(n))
    pr50 = []
    for couple in all_test_couples:
        k_recommendations = get_k_random_items(couple, all_items, k=50)
        relevant_item_embeddings = []
        for item in k_recommendations:
            relevant_item_embeddings.append(v_vecs_n_bias3[i][item])
        relevant_item_embeddings = np.array(relevant_item_embeddings)
        most_similar_index = get_topk_similar2(u_vecs_n_bias3[i][couple[0]], relevant_item_embeddings)
        most_similar_items = []
        for idx in most_similar_index:
            most_similar_items.append(k_recommendations[idx])
            
        pr50.append(pr(couple[1], most_similar_items))

    test_mpr50_3.append(np.mean(pr50))
   
    #Train Set
    print('MPR calculations on Train Set after epoch:  ' + str(i+1) + '/' + str(n))
    pr50 = []
    for couple in all_train_couples:
        k_recommendations = get_k_random_items(couple, all_items, k=50)
        relevant_item_embeddings = []
        for item in k_recommendations:
            relevant_item_embeddings.append(v_vecs_n_bias3[i][item])
        relevant_item_embeddings = np.array(relevant_item_embeddings)
        most_similar_index = get_topk_similar2(u_vecs_n_bias3[i][couple[0]], relevant_item_embeddings)
        most_similar_items = []
        for idx in most_similar_index:
            most_similar_items.append(k_recommendations[idx])
            
        pr50.append(pr(couple[1], most_similar_items))
        
    train_mpr50_3.append(np.mean(pr50))

plt.plot(train_mpr50_3)
plt.plot(test_mpr50_3)
plt.title('MPR@50')
plt.ylabel('MPR@50')
plt.xlabel('epoch')
plt.legend(['Train', 'Test'])
plt.show()
# Out:
# MPR calculations on Test Set after epoch: 1/50
# MPR calculations on Train Set after epoch:  1/50
# MPR calculations on Test Set after epoch: 2/50
# MPR calculations on Train Set after epoch:  2/50
# MPR calculations on Test Set after epoch: 3/50
# MPR calculations on Train Set after epoch:  3/50
# MPR calculations on Test Set after epoch: 4/50
# MPR calculations on Train Set after epoch:  4/50
# MPR calculations on Test Set after epoch: 5/50
# MPR calculations on Train Set after epoch:  5/50
# MPR calculations on Test Set after epoch: 6/50
# MPR calculations on Train Set after epoch:  6/50
# MPR calculations on Test Set after epoch: 7/50
# MPR calculations on Train Set after epoch:  7/50
# MPR calculations on Test Set after epoch: 8/50
# MPR calculations on Train Set after epoch:  8/50
# MPR calculations on Test Set after epoch: 9/50
# MPR calculations on Train Set after epoch:  9/50
# MPR calculations on Test Set after epoch: 10/50
# MPR calculations on Train Set after epoch:  10/50
# MPR calculations on Test Set after epoch: 11/50
# MPR calculations on Train Set after epoch:  11/50
# MPR calculations on Test Set after epoch: 12/50
# MPR calculations on Train Set after epoch:  12/50
# MPR calculations on Test Set after epoch: 13/50
# MPR calculations on Train Set after epoch:  13/50
# MPR calculations on Test Set after epoch: 14/50
# MPR calculations on Train Set after epoch:  14/50
# MPR calculations on Test Set after epoch: 15/50
# MPR calculations on Train Set after epoch:  15/50
# MPR calculations on Test Set after epoch: 16/50
# MPR calculations on Train Set after epoch:  16/50
# MPR calculations on Test Set after epoch: 17/50
# MPR calculations on Train Set after epoch:  17/50
# MPR calculations on Test Set after epoch: 18/50
# MPR calculations on Train Set after epoch:  18/50
# MPR calculations on Test Set after epoch: 19/50
# MPR calculations on Train Set after epoch:  19/50
# MPR calculations on Test Set after epoch: 20/50
# MPR calculations on Train Set after epoch:  20/50
# MPR calculations on Test Set after epoch: 21/50
# MPR calculations on Train Set after epoch:  21/50
# MPR calculations on Test Set after epoch: 22/50
# MPR calculations on Train Set after epoch:  22/50
# MPR calculations on Test Set after epoch: 23/50
# MPR calculations on Train Set after epoch:  23/50
# MPR calculations on Test Set after epoch: 24/50
# MPR calculations on Train Set after epoch:  24/50
# MPR calculations on Test Set after epoch: 25/50
# MPR calculations on Train Set after epoch:  25/50
# MPR calculations on Test Set after epoch: 26/50
# MPR calculations on Train Set after epoch:  26/50
# MPR calculations on Test Set after epoch: 27/50
# MPR calculations on Train Set after epoch:  27/50
# MPR calculations on Test Set after epoch: 28/50
# MPR calculations on Train Set after epoch:  28/50
# MPR calculations on Test Set after epoch: 29/50
# MPR calculations on Train Set after epoch:  29/50
# MPR calculations on Test Set after epoch: 30/50
# MPR calculations on Train Set after epoch:  30/50
# MPR calculations on Test Set after epoch: 31/50
# MPR calculations on Train Set after epoch:  31/50
# MPR calculations on Test Set after epoch: 32/50
# MPR calculations on Train Set after epoch:  32/50
# MPR calculations on Test Set after epoch: 33/50
# MPR calculations on Train Set after epoch:  33/50
# MPR calculations on Test Set after epoch: 34/50
# MPR calculations on Train Set after epoch:  34/50
# MPR calculations on Test Set after epoch: 35/50
# MPR calculations on Train Set after epoch:  35/50
# MPR calculations on Test Set after epoch: 36/50
# MPR calculations on Train Set after epoch:  36/50
# MPR calculations on Test Set after epoch: 37/50
# MPR calculations on Train Set after epoch:  37/50
# MPR calculations on Test Set after epoch: 38/50
# MPR calculations on Train Set after epoch:  38/50
# MPR calculations on Test Set after epoch: 39/50
# MPR calculations on Train Set after epoch:  39/50
# MPR calculations on Test Set after epoch: 40/50
# MPR calculations on Train Set after epoch:  40/50
# MPR calculations on Test Set after epoch: 41/50
# MPR calculations on Train Set after epoch:  41/50
# MPR calculations on Test Set after epoch: 42/50
# MPR calculations on Train Set after epoch:  42/50
# MPR calculations on Test Set after epoch: 43/50
# MPR calculations on Train Set after epoch:  43/50
# MPR calculations on Test Set after epoch: 44/50
# MPR calculations on Train Set after epoch:  44/50
# MPR calculations on Test Set after epoch: 45/50
# MPR calculations on Train Set after epoch:  45/50
# MPR calculations on Test Set after epoch: 46/50
# MPR calculations on Train Set after epoch:  46/50
# MPR calculations on Test Set after epoch: 47/50
# MPR calculations on Train Set after epoch:  47/50
# MPR calculations on Test Set after epoch: 48/50
# MPR calculations on Train Set after epoch:  48/50
# MPR calculations on Test Set after epoch: 49/50
# MPR calculations on Train Set after epoch:  49/50
# MPR calculations on Test Set after epoch: 50/50
# MPR calculations on Train Set after epoch:  50/50

# %%
#Get the MPR of the last epoch only 
#According to the graph above we can assume that with each epoch the MPR decreases,
#So the lowest MPR should be for the last epoch

number_epochs3 = 100

all_items = list(counts_by_idx.keys())

pr50_3 = []
for couple in all_test_couples:
    k_recommendations3 = get_k_random_items(couple, all_items, k=50)
    relevant_item_embeddings3 = []
    for item in k_recommendations3:
        relevant_item_embeddings3.append(v_vecs_n_bias3[number_epochs3-1][item])
    relevant_item_embeddings3 = np.array(relevant_item_embeddings3)
    most_similar_index3 = get_topk_similar2(u_vecs_n_bias3[number_epochs3-1][couple[0]], relevant_item_embeddings3)
    most_similar_items3 = []
    for idx in most_similar_index3:
        most_similar_items3.append(k_recommendations3[idx])

    pr50_3.append(pr(couple[1], most_similar_items3))

test_mpr50_3_last = np.mean(pr50_3)

pr50_3 = []
for couple in all_train_couples:
    k_recommendations3 = get_k_random_items(couple, all_items, k=50)
    relevant_item_embeddings3 = []
    for item in k_recommendations3:
        relevant_item_embeddings3.append(v_vecs_n_bias3[number_epochs3-1][item])
    relevant_item_embeddings3 = np.array(relevant_item_embeddings3)
    most_similar_index3 = get_topk_similar2(u_vecs_n_bias3[number_epochs3-1][couple[0]], relevant_item_embeddings3)
    most_similar_items3 = []
    for idx in most_similar_index3:
        most_similar_items3.append(k_recommendations3[idx])

    pr50_3.append(pr(couple[1], most_similar_items3))

train_mpr50_3_last = np.mean(pr50_3)

print('Model 3 - Loss: Hinge')
print('Train Set MPR:   ', train_mpr50_3_last)
print('Test Set MPR :    ', test_mpr50_3_last)
# Out:
# Model 3 - Loss: Hinge
# Train Set MPR:    7.2238342113981995
# Test Set MPR :     7.486379597116984

# %% [markdown]
# #### HR

# %%
train_hr20_3 = []
test_hr20_3 = []

n = 10

for i in range(n): 
    #Test Set
    print('HR calculations on Test Set after epoch: ' + str(i+1) + '/' + str(n))
    hr20 = []
    for couple in all_test_couples:
        most_similar_items = get_topk_similar2(u_vecs_n_bias3[i][couple[0]], v_vecs_n_bias3[i], k=20)           
        hr20.append(hr(couple[1], most_similar_items))

    test_hr20_3.append((np.sum(hr20)/len(all_test_couples))*100)
   
    #Train Set
    print('HR calculations on Train Set after epoch:  ' + str(i+1) + '/' + str(n))
    hr20 = []
    for couple in all_train_couples:
        most_similar_items = get_topk_similar2(u_vecs_n_bias3[i][couple[0]], v_vecs_n_bias3[i], k=20)
        hr20.append(hr(couple[1], most_similar_items))
        
    train_hr20_3.append((np.sum(hr20)/len(all_train_couples))*100)

plt.plot(train_hr20_3)
plt.plot(test_hr20_3)
plt.title('HR@20')
plt.ylabel('HR@20')
plt.xlabel('epoch')
plt.legend(['Train', 'Test'])
plt.show()
# Out:
# HR calculations on Test Set after epoch: 1/10
# HR calculations on Train Set after epoch:  1/10
# HR calculations on Test Set after epoch: 2/10
# HR calculations on Train Set after epoch:  2/10
# HR calculations on Test Set after epoch: 3/10
# HR calculations on Train Set after epoch:  3/10
# HR calculations on Test Set after epoch: 4/10
# HR calculations on Train Set after epoch:  4/10
# HR calculations on Test Set after epoch: 5/10
# HR calculations on Train Set after epoch:  5/10
# HR calculations on Test Set after epoch: 6/10
# HR calculations on Train Set after epoch:  6/10
# HR calculations on Test Set after epoch: 7/10
# HR calculations on Train Set after epoch:  7/10
# HR calculations on Test Set after epoch: 8/10
# HR calculations on Train Set after epoch:  8/10
# HR calculations on Test Set after epoch: 9/10
# HR calculations on Train Set after epoch:  9/10
# HR calculations on Test Set after epoch: 10/10
# HR calculations on Train Set after epoch:  10/10

# %%
#Get the HR of the last epoch only (the higher the better)
#According to the graph above we can assume that with each epoch the HR increases,
#So the highest HR should be for the last epoch

number_epochs3 = 100

hr20_3 = []
for couple in all_test_couples:
    most_similar_items3 = get_topk_similar2(u_vecs_n_bias3[number_epochs3-1][couple[0]],
                                            v_vecs_n_bias3[number_epochs3-1], k=20)           
    hr20_3.append(hr(couple[1], most_similar_items3))

test_hr20_3_last = (np.sum(hr20_3)/len(all_test_couples))*100

hr20_3 = []
for couple in all_train_couples:
    most_similar_items3 = get_topk_similar2(u_vecs_n_bias3[number_epochs3-1][couple[0]],
                                            v_vecs_n_bias3[number_epochs3-1], k=20)           
    hr20_3.append(hr(couple[1], most_similar_items3))

train_hr20_3_last = (np.sum(hr20_3)/len(all_train_couples))*100

print('Model 3 - Loss: Hinge')
print('Train Set HR@20:   ', train_hr20_3_last)
print('Test Set HR@20:    ', test_hr20_3_last)
# Out:
# Model 3 - Loss: Hinge
# Train Set HR@20:    88.45994110976821
# Test Set HR@20:     88.0798373683238

# %%
number_epochs3 = 100

hr10_3 = []
for couple in all_test_couples:
    most_similar_items3 = get_topk_similar2(u_vecs_n_bias3[number_epochs3-1][couple[0]],
                                            v_vecs_n_bias3[number_epochs3-1],
                                            k=10)           
    hr10_3.append(hr(couple[1], most_similar_items3))

test_hr10_3_last = (np.sum(hr10_3)/len(all_test_couples))*100

hr10_3 = []
for couple in all_train_couples:
    most_similar_items3 = get_topk_similar2(u_vecs_n_bias3[number_epochs3-1][couple[0]],
                                            v_vecs_n_bias3[number_epochs3-1],
                                            k=10)           
    hr10_3.append(hr(couple[1], most_similar_items3))

train_hr10_3_last = (np.sum(hr10_3)/len(all_train_couples))*100

print('Model 3 - Loss: Hinge')
print('Train Set HR@10:   ', train_hr10_3_last)
print('Test Set HR@10:    ', test_hr10_3_last)
# Out:
# Model 3 - Loss: Hinge
# Train Set HR@10:    69.32014913881203
# Test Set HR@10:     68.77656625392719

# %% [markdown]
# # 6. Baseline Method 1 - ItemPop

# %% [markdown]
# #### MPR

# %%
all_items = list(counts_by_idx.keys())
sorted_by_popularity = counts_by_idx.most_common()

#Test Set
pr50_b1 = []
for i, couple in enumerate(all_test_couples):
    k_recommendations_b1 = get_k_random_items(couple, all_items, k=50)
    relevant_items_b1 = []
    for item in k_recommendations_b1:
        relevant_items_b1.append(sorted_by_popularity[item])
    most_popular_b1 = list(reversed(sorted(relevant_items_b1, key=lambda x: x[1])))
    most_popular_b1 = [x[0] for x in most_popular_b1]

    pr50_b1.append(pr(couple[1], most_popular_b1))

test_mpr50_b1 = np.mean(pr50_b1)

#Train Set
pr50_b1 = []
for i,couple in enumerate(all_train_couples):
    k_recommendations_b1 = get_k_random_items(couple, all_items, k=50)
    relevant_items_b1 = []
    for item in k_recommendations_b1:
        relevant_items_b1.append(sorted_by_popularity[item])
    most_popular_b1 = list(reversed(sorted(relevant_items_b1, key=lambda x: x[1])))
    most_popular_b1 = [x[0] for x in most_popular_b1]

    pr50_b1.append(pr(couple[1], most_popular_b1))

train_mpr50_b1 = np.mean(pr50_b1)

print('Baseline Method 1 - ItemPop')
print('Train Set MPR:   ', train_mpr50_b1)
print('Test Set MPR:    ', test_mpr50_b1)
# Out:
# Baseline Method 1 - ItemPop
# Train Set MPR:    11.660620540651525
# Test Set MPR:     11.776751062650158

# %% [markdown]
# #### HR

# %%
train_popular = trainset_counts.most_common()
test_popular = testset_counts.most_common()

k=20

#Test Set
hr20_b1 = []
for couple in all_test_couples:
    k_recommendations_b1 = test_popular[:k]
    most_popular_b1 = [x[0] for x in k_recommendations_b1]

    hr20_b1.append(hr(couple[1], most_popular_b1))

test_hr20_b1 = (np.sum(hr20_b1)/len(all_test_couples))*100

#Train Set
hr20 = []
for couple in all_train_couples:
    k_recommendations_b1 = train_popular[:k]
    most_popular_b1 = [x[0] for x in k_recommendations_b1]

    hr20_b1.append(hr(couple[1], most_popular_b1))

train_hr20_b1 = (np.sum(hr20_b1)/len(all_test_couples))*100

print('Baseline Method 1 - ItemPop')
print('Train Set HR@20:   ', train_hr20_b1)
print('Test Set HR@20:    ', test_hr20_b1)
# Out:
# Baseline Method 1 - ItemPop
# Train Set HR@20:    359.54352245425986
# Test Set HR@20:     72.28053964147108

# %%
k=10

#Test Set
hr10_b1 = []
for couple in all_test_couples:
    k_recommendations_b1 = test_popular[:k]
    most_popular_b1 = [x[0] for x in k_recommendations_b1]

    hr10_b1.append(hr(couple[1], most_popular_b1))

test_hr10_b1 = (np.sum(hr10_b1)/len(all_test_couples))*100

#Train Set
hr10 = []
for couple in all_train_couples:
    k_recommendations_b1 = train_popular[:k]
    most_popular_b1 = [x[0] for x in k_recommendations_b1]

    hr10_b1.append(hr(couple[1], most_popular_b1))

train_hr10_b1 = (np.sum(hr10_b1)/len(all_test_couples))*100

print('Baseline Method 1 - ItemPop')
print('Train Set HR@10:   ', train_hr10_b1)
print('Test Set HR@10:    ', test_hr10_b1)
# Out:
# Baseline Method 1 - ItemPop
# Train Set HR@10:    272.7887636296433
# Test Set HR@10:     54.830900018480875

# %% [markdown]
# #### AUC

# %%
all_items = list(counts_by_idx.keys())
sorted_by_popularity = counts_by_idx.most_common()

#Test Set
pred_b1 = []
actuals_b1 = []
for i, couple in enumerate(all_test_couples):
    k_recommendations_b1 = get_k_random_items(couple, all_items, k=50)
    relevant_items_b1 = []
    for item in k_recommendations_b1:
        relevant_items_b1.append(sorted_by_popularity[item])
    most_popular_b1 = list(reversed(sorted(relevant_items_b1, key=lambda x: x[1])))
    most_popular_b1 = [x[0] for x in most_popular_b1]
    if most_popular_b1[0] == couple[1]:
        pred_b1.append(1)
        actuals_b1.append(1)
    else:
        pred_b1.append(1)
        actuals_b1.append(0)
        

test_auc_b1 = roc_auc_score(actuals_b1, pred_b1)


#Train Set
pred_b1 = []
actuals_b1 = []
for i, couple in enumerate(all_train_couples):
    k_recommendations_b1 = get_k_random_items(couple, all_items, k=50)
    relevant_items_b1 = []
    for item in k_recommendations_b1:
        relevant_items_b1.append(sorted_by_popularity[item])
    most_popular_b1 = list(reversed(sorted(relevant_items_b1, key=lambda x: x[1])))
    most_popular_b1 = [x[0] for x in most_popular_b1]
    if most_popular_b1[0] == couple[1]:
        pred_b1.append(1)
        actuals_b1.append(1)
    else:
        pred_b1.append(1)
        actuals_b1.append(0)
        

train_auc_b1 = roc_auc_score(actuals_b1, pred_b1)

print('Baseline Method 1 - ItemPop')
print('Train Set AUC:   ', train_auc_b1)
print('Test Set AUC:    ', test_auc_b1)
# Out:
# Baseline Method 1 - ItemPop
# Train Set AUC:    0.5
# Test Set AUC:     0.5

# %% [markdown]
# # 7. Baseline Method 2 - Random

# %% [markdown]
# The metrics of the "random" method is already computed in the results table.

# %% [markdown]
# # 8. Baseline Method 3 - BPR

# %% [markdown]
# https://arxiv.org/pdf/1708.05031.pdf

# %% [markdown]
# # 9. Results & Comparison

# %%
#Dictionary of all the results
results = {
            'Binary Cross Entropy' : {
                'MPR': test_mpr50_last,
                'AUC': ts_auc[-1],
                'HR@20': test_hr20_last,
                'HR@10': test_hr10_last
            },
            'Categorical Cross Entropy': {
                'MPR': test_mpr50_2_last,
                'AUC': ts_auc2[-1],
                'HR@20': test_hr20_2_last2,
                'HR@10': test_hr10_2_last2
            },
           'Hinge': {
               'MPR': test_mpr50_3_last,
               'AUC': ts_auc3[-1],
               'HR@20': test_hr20_3_last,
               'HR@10': test_hr10_3_last
           },
           'Baseline 1 - Most Popular': {
               'MPR': test_mpr50_b1,
               'AUC': test_auc_b1,
               'HR@20': test_hr20_b1,
               'HR@10': test_hr10_b1
           },
           'Baseline 2 - Random': {
               'MPR': 0.5,
               'AUC': 0.5,
               'HR@20': 20/len(counts_by_idx),
               'HR@10': 10/len(counts_by_idx)
           },
           'Baseline 3 - BPR': {
               'MPR': 'TBD',
               'AUC': 'TBD',
               'HR@20': 'TBD',
               'HR@10': 'TBD'
           }
}

#Show it as a table
results = pd.DataFrame(results).T
results
# Out:
#                                MPR       AUC     HR@20     HR@10
# Binary Cross Entropy       5.53362  0.906321   89.6045   78.6971
# Categorical Cross Entropy  5.40026  0.908808   89.1684   77.4478
# Hinge                      7.48638  0.887579   88.0798   68.7766
# Baseline 1 - Most Popular  11.7768       0.5   72.2805   54.8309
# Baseline 2 - Random            0.5       0.5  0.150376  0.075188
# Baseline 3 - BPR               TBD       TBD       TBD       TBD

# %% [markdown]
# # 10. Visualization

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import pairwise_distances

# %%
"""
def get_genre_data(genres_file_name):
    #Get genre data
    flat_item_list = [item for item_list in filtered_item_lists for item in item_list]
    print(flat_item_list)
    genres_by_idx = {}
    with open(genres_file_name) as data:
        for line in data:
            line = [x.strip() for x in line.split(',')]
            print(line)
            #line = line.split(',')
            item_genre = line[2]
            print(item_genre)
            item = line[0]
            print(item)
            if item in flat_item_list:
                item_idx = items_to_idx[item]
                genres_by_idx[item_idx] =  item_genre
                print(genres_by_idx)
    return (genres_by_idx)
"""
# Out:
# "\ndef get_genre_data(genres_file_name):\n    #Get genre data\n    flat_item_list = [item for item_list in filtered_item_lists for item in item_list]\n    print(flat_item_list)\n    genres_by_idx = {}\n    with open(genres_file_name) as data:\n        for line in data:\n            line = [x.strip() for x in line.split(',')]\n            print(line)\n            #line = line.split(',')\n            item_genre = line[2]\n            print(item_genre)\n            item = line[0]\n            print(item)\n            if item in flat_item_list:\n                item_idx = items_to_idx[item]\n                genres_by_idx[item_idx] =  item_genre\n                print(genres_by_idx)\n    return (genres_by_idx)\n"

# %%
def get_genre_data(genres_file_name):
    #Get genre data
    flat_item_list = [item for item_list in filtered_item_lists for item in item_list]
    genres_by_idx = {}
    with open(genres_file_name, encoding='latin1') as data:
        for line in data:
            line = line.split(',')
            item_genre = line[2][:-1].split('\n')
            item = line[0]
            if item in flat_item_list:
                item_idx = items_to_idx[item]
                genres_by_idx[item_idx] =  item_genre
    return (genres_by_idx)

# %%
genres_file = '/content/Movie_data.txt'
genre_data = get_genre_data(genres_file_name = genres_file)

# %%
genre_data
# Out:
# {0: ['Pearl Harbor'],
#  1: ['The Goonies'],
#  2: ['Batman Returns'],
#  3: ['From Dusk Till Dawn'],
#  4: ['G.I. Jane'],
#  5: ['Sexy Beast'],
#  6: ['For a Few Dollars More'],
#  7: ['South Park: Season 2'],
#  8: ['Mighty Joe Young'],
#  9: ['All About My Mother'],
#  10: ['Pacific Heights'],
#  11: ['Boat Trip'],
#  12: ['Colors'],
#  13: ['Before Night Falls'],
#  14: ['Iron Will'],
#  15: ['The Best Man'],
#  16: ["Cheech & Chong's Nice Dreams"],
#  17: ['The Year of Living Dangerously'],
#  18: ['Queer as Folk: Season 3'],
#  19: ['The Grey Zone'],
#  20: ['Romance'],
#  21: ['Sudden Death'],
#  22: ['The Candidate'],
#  23: ['The Dead Zone: Season 1'],
#  24: ['Dennis the Menace'],
#  25: ['SpongeBob SquarePants: Season 1'],
#  26: ['Sleuth'],
#  27: ['Twilight'],
#  28: ['Love Me If You Dare'],
#  29: ['The Witches'],
#  30: ['The Mechanic'],
#  31: ['Dear God'],
#  32: ['Samurai Jack'],
#  33: ['Lady Jane'],
#  34: ['The Heart of Me'],
#  35: ['Life with Mikey'],
#  36: ['The Adventures of Huck Finn'],
#  37: ['Bus Stop'],
#  38: ['Foxy Brown'],
#  39: ['Mystery Science Theater 3000: Timechasers'],
#  40: ['It Was a Wonderful Life'],
#  41: ['The Five Obstructions'],
#  42: ["Man's Best Friend"],
#  43: ['Destry Rides Again'],
#  44: ["Teacher's Pet"],
#  45: ['Lois & Clark: The New Adventures of Superman: Season 1'],
#  46: ['Tom & Viv'],
#  47: ['Doctor Who: The Armageddon Factor'],
#  48: ['Wicked'],
#  49: ['S.F.W.'],
#  50: ['The Good Mother'],
#  51: ['Still Crazy'],
#  52: ['Spring Forward'],
#  53: ["Three's Company: Season 4"],
#  54: ['Rugrats: Decade in Diapers'],
#  55: ['Waxwork / Waxwork II: Double Feature'],
#  56: ['Black Moon Rising'],
#  57: ['Just Looking'],
#  58: ['Days of Being Wild'],
#  59: ['One Tree Hill: Season 2'],
#  60: ['Slow Burn'],
#  61: ['Village of the Damned / Children of the Damned'],
#  62: ['Sailor Moon S'],
#  63: ['Pavilion of Women'],
#  64: ['Phantasm IV: Oblivion'],
#  65: ['Cedric the Entertainer: Starting Lineup 2'],
#  66: ['Son of the Beach: Vol. 1'],
#  67: ['The Mrs. Bradley Mysteries'],
#  68: ['Evil Remains'],
#  69: ['Blue Juice'],
#  70: ['Max Dugan Returns'],
#  71: ['Inner Senses'],
#  73: ['Moving Violations'],
#  74: ["Boys' Shorts: The New Queer Cinema"],
#  75: ['Regency House Party'],
#  76: ['Gol Maal'],
#  77: ['The Lady in Red'],
#  78: ['Tune in Tomorrow'],
#  79: ['Battle Athletes Victory: Vol. 8: The Human Race!'],
#  80: ['Rumpelstiltskin'],
#  81: ['The Master of Ballantrae'],
#  82: ['National Geographic: 21 Days to Baghdad'],
#  83: ['Massage Your Mate'],
#  84: ['Tieta of Agreste'],
#  85: ['Straightman'],
#  86: ['Harold and the Purple Crayon'],
#  87: ["Kangaroo Jack: G'Day USA"],
#  88: ["I'll Remember April"],
#  89: ["Jancis Robinson's Wine Course"],
#  90: ['WWE: Backlash 2005'],
#  91: ['Coast to Coast'],
#  92: ['The Whole Shebang'],
#  93: ["I'm Still Here . . . Damn It!"],
#  94: ['The Sea Chase'],
#  95: ['Second Time Around'],
#  96: ['The Criminal'],
#  97: ['The Illiterate One'],
#  98: ['Rammstein: Lichtspielhaus'],
#  99: ["Violence in a Women's Prison"],
#  100: ['Full Clip'],
#  101: ['Armored Trooper Votoms Stage 1: Uoodo City'],
#  102: ['Kojak: Season 1'],
#  103: ['The Winter Guest'],
#  104: ["Lana's Rain"],
#  105: ['Destiny'],
#  106: ['Atomic Journeys: Welcome to Ground Zero'],
#  107: ['Grand Tour: Disaster in Time'],
#  108: ['.Com for Murder'],
#  109: ['WWE: The Best of Intercontinental Championship Matches'],
#  110: ['Infested'],
#  111: ['Heartwood'],
#  112: ['Laurel & Hardy & Friends'],
#  113: ['Stiletto Dance'],
#  114: ['Fidelio: Beethoven: Royal Opera House'],
#  115: ["Don's Party"],
#  116: ['The Elite'],
#  117: ['Gunsmoke: The Last Apache'],
#  118: ['Hester Street'],
#  119: ['Love and Action in Chicago'],
#  120: ['Morlang'],
#  121: ['Magic of Fellini'],
#  122: ['Virgin Machine'],
#  123: ['Colonel Wolodyjowski'],
#  124: ['Kylie Minogue: Body Language Live'],
#  125: ['Here Comes Cookie / Love in Bloom / Six of a Kind: Triple Feature'],
#  126: ['The Giallo Collection: The Bloodstained Shadow'],
#  127: ['The Church'],
#  128: ['Fox: The Blockbuster Years'],
#  129: ["Magic User's Club"],
#  130: ['The Real Bruce Lee'],
#  131: ["Knocking On Death's Door"],
#  132: ['Kakurenbo: Hide & Seek']}

# %%
genre_counts = Counter([genre for genre_list in list(genre_data.values()) for genre in genre_list])

# %%
most_common_genres = genre_counts.most_common(8)
most_common_genres
# Out:
# [('Blue Juice', 1),
#  ('Sailor Moon S', 1),
#  ('Fidelio: Beethoven: Royal Opera House', 1),
#  ('Massage Your Mate', 1),
#  ('Moving Violations', 1),
#  ('Tieta of Agreste', 1),
#  ("Cheech & Chong's Nice Dreams", 1),
#  ('Lady Jane', 1)]

# %%
genre_idxs, genre_topk = get_topk_each_genre(genre_data, top_k = 20)

# %%
genre_idxs
# Out:
# {'.Com for Murder': 0,
#  'All About My Mother': 1,
#  'Armored Trooper Votoms Stage 1: Uoodo City': 2,
#  'Atomic Journeys: Welcome to Ground Zero': 3,
#  'Batman Returns': 4,
#  'Battle Athletes Victory: Vol. 8: The Human Race!': 5,
#  'Before Night Falls': 6,
#  'Black Moon Rising': 7,
#  'Blue Juice': 8,
#  'Boat Trip': 9,
#  "Boys' Shorts: The New Queer Cinema": 10,
#  'Bus Stop': 11,
#  'Cedric the Entertainer: Starting Lineup 2': 12,
#  "Cheech & Chong's Nice Dreams": 13,
#  'Coast to Coast': 14,
#  'Colonel Wolodyjowski': 15,
#  'Colors': 16,
#  'Days of Being Wild': 17,
#  'Dear God': 18,
#  'Dennis the Menace': 19,
#  'Destiny': 20,
#  'Destry Rides Again': 21,
#  'Doctor Who: The Armageddon Factor': 22,
#  "Don's Party": 23,
#  'Evil Remains': 24,
#  'Fidelio: Beethoven: Royal Opera House': 25,
#  'For a Few Dollars More': 26,
#  'Fox: The Blockbuster Years': 27,
#  'Foxy Brown': 28,
#  'From Dusk Till Dawn': 29,
#  'Full Clip': 30,
#  'G.I. Jane': 31,
#  'Gol Maal': 32,
#  'Grand Tour: Disaster in Time': 33,
#  'Gunsmoke: The Last Apache': 34,
#  'Harold and the Purple Crayon': 35,
#  'Heartwood': 36,
#  'Here Comes Cookie / Love in Bloom / Six of a Kind: Triple Feature': 37,
#  'Hester Street': 38,
#  "I'll Remember April": 39,
#  "I'm Still Here . . . Damn It!": 40,
#  'Infested': 41,
#  'Inner Senses': 42,
#  'Iron Will': 43,
#  'It Was a Wonderful Life': 44,
#  "Jancis Robinson's Wine Course": 45,
#  'Just Looking': 46,
#  'Kakurenbo: Hide & Seek': 47,
#  "Kangaroo Jack: G'Day USA": 48,
#  "Knocking On Death's Door": 49,
#  'Kojak: Season 1': 50,
#  'Kylie Minogue: Body Language Live': 51,
#  'Lady Jane': 52,
#  "Lana's Rain": 53,
#  'Laurel & Hardy & Friends': 54,
#  'Life with Mikey': 55,
#  'Lois & Clark: The New Adventures of Superman: Season 1': 56,
#  'Love Me If You Dare': 57,
#  'Love and Action in Chicago': 58,
#  "Magic User's Club": 59,
#  'Magic of Fellini': 60,
#  "Man's Best Friend": 61,
#  'Massage Your Mate': 62,
#  'Max Dugan Returns': 63,
#  'Mighty Joe Young': 64,
#  'Morlang': 65,
#  'Moving Violations': 66,
#  'Mystery Science Theater 3000: Timechasers': 67,
#  'National Geographic: 21 Days to Baghdad': 68,
#  'One Tree Hill: Season 2': 69,
#  'Pacific Heights': 70,
#  'Pavilion of Women': 71,
#  'Pearl Harbor': 72,
#  'Phantasm IV: Oblivion': 73,
#  'Queer as Folk: Season 3': 74,
#  'Rammstein: Lichtspielhaus': 75,
#  'Regency House Party': 76,
#  'Romance': 77,
#  'Rugrats: Decade in Diapers': 78,
#  'Rumpelstiltskin': 79,
#  'S.F.W.': 80,
#  'Sailor Moon S': 81,
#  'Samurai Jack': 82,
#  'Second Time Around': 83,
#  'Sexy Beast': 84,
#  'Sleuth': 85,
#  'Slow Burn': 86,
#  'Son of the Beach: Vol. 1': 87,
#  'South Park: Season 2': 88,
#  'SpongeBob SquarePants: Season 1': 89,
#  'Spring Forward': 90,
#  'Stiletto Dance': 91,
#  'Still Crazy': 92,
#  'Straightman': 93,
#  'Sudden Death': 94,
#  "Teacher's Pet": 95,
#  'The Adventures of Huck Finn': 96,
#  'The Best Man': 97,
#  'The Candidate': 98,
#  'The Church': 99,
#  'The Criminal': 100,
#  'The Dead Zone: Season 1': 101,
#  'The Elite': 102,
#  'The Five Obstructions': 103,
#  'The Giallo Collection: The Bloodstained Shadow': 104,
#  'The Good Mother': 105,
#  'The Goonies': 106,
#  'The Grey Zone': 107,
#  'The Heart of Me': 108,
#  'The Illiterate One': 109,
#  'The Lady in Red': 110,
#  'The Master of Ballantrae': 111,
#  'The Mechanic': 112,
#  'The Mrs. Bradley Mysteries': 113,
#  'The Real Bruce Lee': 114,
#  'The Sea Chase': 115,
#  'The Whole Shebang': 116,
#  'The Winter Guest': 117,
#  'The Witches': 118,
#  'The Year of Living Dangerously': 119,
#  "Three's Company: Season 4": 120,
#  'Tieta of Agreste': 121,
#  'Tom & Viv': 122,
#  'Tune in Tomorrow': 123,
#  'Twilight': 124,
#  'Village of the Damned / Children of the Damned': 125,
#  "Violence in a Women's Prison": 126,
#  'Virgin Machine': 127,
#  'WWE: Backlash 2005': 128,
#  'WWE: The Best of Intercontinental Championship Matches': 129,
#  'Waxwork / Waxwork II: Double Feature': 130,
#  'Wicked': 131}

# %%
genre_idx = list(genre_idxs)

# %%
for key in most_common_genres:
    print(genre_topk[genre_idxs[key[0]]])
# Out:
# [69]
# [62]
# [114]
# [83]
# [73]
# [84]
# [16]
# [33]

# %% [markdown]
# ## 8.1 Model 1

# %%
from sklearn.preprocessing import LabelEncoder

# %%
number_epochs = 50
top_k_popular = 100

u_emb = u_vecs_n_bias[number_epochs-1][0:top_k_popular]
v_emb = v_vecs_n_bias[number_epochs-1][0:top_k_popular]

u_emb_no_bias = []
v_emb_no_bias = []
for emb in u_emb:
    u_emb_no_bias.append(emb[:-1])
for emb in v_emb:
    v_emb_no_bias.append(emb[:-1])

# %%
def tsne_plot(item_embeddings, genres_by_idx, topk_pop):
    # Creates and TSNE model and plots it    
    # item_embeddings = either u vectors or v_vectors (including the bias)   
    emb = item_embeddings[number_epochs-1][0:topk_pop]
    
    #Remove the bias from the embedding vector
    emb_no_bias = []
    for e in emb:
        emb_no_bias.append(e[:-1])
    
    labels = []
    embs = []
    colors = []

    for i,item in enumerate(emb_no_bias):
        embs.append(emb_no_bias[i])
        labels.append(i)
        colors.append(genres_by_idx[i])
        #print(embs)
    
    tsne_model = TSNE(n_components=2, random_state=23)
    new_values = tsne_model.fit_transform(embs)
    #print(new_values)

    x = []
    y = []
    for value in new_values:
        x.append(value[0])
        y.append(value[1])
        #print(x,y)
        
#     plt.figure(figsize=(16, 16))
#     for i in range(len(x)):
#         plt.scatter(x[i],y[i])
#         plt.annotate(str(colors[i]), xy=(x[i],y[i]))
    
    plt.scatter(x,y, c= colors)
        
    plt.show()

# %%
dat = LabelEncoder().fit_transform(genre_idx)

# %%
tsne_plot(u_vecs_n_bias,dat,100)

# %%
def tsne_plot(x, colors):
    # choose a color palette with seaborn.
    num_classes = len(np.unique(colors))
    palette = np.array(sns.color_palette("hls", num_classes))

    # create a scatter plot.
    f = plt.figure(figsize=(8, 8))
    ax = plt.subplot(aspect='equal')
    sc = ax.scatter(x[:,0], x[:,1], lw=0, s=40, c=palette[colors.astype(np.int)])
    plt.xlim(-25, 25)
    plt.ylim(-25, 25)
    ax.axis('off')
    ax.axis('tight')

    # add the labels for each digit corresponding to the label
    txts = []

    for i in range(num_classes):

        # Position of each label at median of data points.

        xtext, ytext = np.median(x[colors == i, :], axis=0)
        txt = ax.text(xtext, ytext, str(i), fontsize=24)
        txt.set_path_effects([
            PathEffects.Stroke(linewidth=5, foreground="w"),
            PathEffects.Normal()])
        txts.append(txt)

    return f, ax, sc, txts

# %%
x_subset = trainset[0:20]
y_subset = testset[0:20]

# %%
from sklearn.manifold import TSNE
import time
time_start = time.time()

tsne = TSNE(random_state=None).fit(x_subset)

#print 't-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start)


#then pass the parameter for visualization function which is fashion_scatter
tsne_plot(tsne, y_subset)
